# %% [markdown]
# # Train Numberbatch or Glove

# %%
import numpy as np
import pandas as pd 
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.layers import (
    Dense,
    Input,
    LSTM,
    Embedding,
    Dropout,
    Activation,
    SpatialDropout1D
)
from tensorflow.keras.models import Model, load_model
from tensorflow.keras.callbacks import ModelCheckpoint
from ast import literal_eval
from sklearn.model_selection import train_test_split
# Out:
# /Users/sebastiancorrea/anaconda3/lib/python3.6/importlib/_bootstrap.py:219: RuntimeWarning: compiletime version 3.5 of module 'tensorflow.python.framework.fast_tensor_util' does not match runtime version 3.6
#   return f(*args, **kwds)

# %%
df = pd.read_csv('../data/pandas_data_frame.csv', index_col=0)
all_data = df.where((pd.notnull(df)), '')
all_data['hashtag'] = all_data['hashtag'].apply(literal_eval)

full_text = all_data['tidy_tweet'][(all_data['label']==1.0) | (all_data['label']==0.0)]
y = all_data['label'][(all_data['label']==1.0) | (all_data['label']==0.0)]

# %%
tk = Tokenizer(lower=True, filters='')
tk.fit_on_texts(full_text)

train_tokenized = tk.texts_to_sequences(full_text)
max_len = 120
X = pad_sequences(train_tokenized, maxlen=max_len)

x_train, x_val, y_train, y_val = train_test_split(X, y, random_state=1992, test_size=0.2)

print(x_train.shape,y_train.shape)
print(x_val.shape,y_val.shape)
# Out:
# (25569, 19) (25569,)
# (6393, 19) (6393,)

# %%
import pickle

# saving
with open('../model_wehigts/tokenizer.pickle', 'wb') as handle:
    pickle.dump(tk, handle, protocol=pickle.HIGHEST_PROTOCOL)

# %%
embedding_path = '../data/vectors/numberbatch-17.06.txt'
embed_size = 300

max_features = 30000

def get_coefs(word,*arr):
    return word, np.asarray(arr, dtype='float32')

embedding_index = dict(get_coefs(*o.strip().split(" ")) for o in open(embedding_path))

# %%
word_index = tk.word_index
nb_words = min(max_features, len(word_index))
embedding_matrix = np.zeros((nb_words + 1, embed_size))

for word, i in word_index.items():
    if i >= max_features: continue
    embedding_vector = embedding_index.get(word)
    if embedding_vector is not None: embedding_matrix[i] = embedding_vector

# %%
import sys
sys.path.append("../") 
from personal_library.sce_keras.loss_functions import f1_loss
from personal_library.sce_keras.metrics_functions import f1
from personal_library.sce_keras.callbacks import (
    LearningRateDecay,
    WarmUpCosineDecayScheduler
)


num_classes = 1
batch_size = 32
epochs = 200
learnRate = 0.001
lstm_out = 200
warmup_epoch = 20

lrate_decay = LearningRateDecay(epochs, learnRate).step_decay
warm_up_lr = WarmUpCosineDecayScheduler(learning_rate_base=learnRate,
                                        warmup_learning_rate=0,
                                        warmup_epoch=warmup_epoch,
                                        hold_base_rate_steps=5,
                                        verbose=0)

checkpoint_path = "../model_wehigts/8_w.hdf5"
checkpoint_path1 = "../model_wehigts/8_ch.hdf5"
checkpointer = ModelCheckpoint(filepath=checkpoint_path,
                               monitor='val_loss', verbose=2,
                               save_best_only=True, mode='min')
checkpointer1 = ModelCheckpoint(filepath=checkpoint_path1,
                               monitor='val_loss', verbose=2,
                               save_best_only=False, mode='min')

inp = Input(shape = (max_len,))
x = Embedding(nb_words+1, embed_size, weights = [embedding_matrix], trainable=False)(inp)
x = SpatialDropout1D(0.3)(x)
x = LSTM(lstm_out, dropout=0.5, recurrent_dropout=0.5)(x)
x = Dense(1, activation = "sigmoid")(x)

model = Model(inputs=inp, outputs=x)
model.summary()

# 'binary_crossentropy'
model.compile(loss=f1_loss, 
              optimizer='adam', 
              metrics=['accuracy', f1]) 

history = model.fit(x_train, y_train, 
                    batch_size=batch_size,
                    epochs=epochs,
                    verbose=1,
                    validation_data=(x_val, y_val),
                    callbacks=[checkpointer, checkpointer1, lrate_decay])
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_3 (InputLayer)         (None, 19)                0
# _________________________________________________________________
# embedding_2 (Embedding)      (None, 19, 300)           4550100
# _________________________________________________________________
# spatial_dropout1d_2 (Spatial (None, 19, 300)           0
# _________________________________________________________________
# lstm_2 (LSTM)                (None, 200)               400800
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 201
# =================================================================
# Total params: 4,951,101
# Trainable params: 401,001
# Non-trainable params: 4,550,100
# _________________________________________________________________
# Train on 25569 samples, validate on 6393 samples
# Epoch 1/200
# 25569/25569 [==============================] - 68s 3ms/step - loss: 0.8721 - acc: 0.0715 - f1: 0.1279 - val_loss: 0.8749 - val_acc: 0.0688 - val_f1: 0.1251
#
# Epoch 00001: val_loss improved from inf to 0.87493, saving model to ../model_wehigts/8_w.hdf5
#
# Epoch 00001: saving model to ../model_wehigts/8_ch.hdf5
# Epoch 2/200
# 25569/25569 [==============================] - 65s 3ms/step - loss: 0.8715 - acc: 0.0705 - f1: 0.1285 - val_loss: 0.8749 - val_acc: 0.0688 - val_f1: 0.1251
#
# Epoch 00002: val_loss improved from 0.87493 to 0.87493, saving model to ../model_wehigts/8_w.hdf5
#
# Epoch 00002: saving model to ../model_wehigts/8_ch.hdf5
# Epoch 3/200
# 25569/25569 [==============================] - 65s 3ms/step - loss: 0.8716 - acc: 0.0705 - f1: 0.1284 - val_loss: 0.8749 - val_acc: 0.0688 - val_f1: 0.1251
#
# Epoch 00003: val_loss did not improve from 0.87493
#
# Epoch 00003: saving model to ../model_wehigts/8_ch.hdf5
# Epoch 4/200
# 25569/25569 [==============================] - 64s 3ms/step - loss: 0.8730 - acc: 0.1057 - f1: 0.1270 - val_loss: 0.8749 - val_acc: 0.0688 - val_f1: 0.1251
#
# Epoch 00004: val_loss did not improve from 0.87493
#
# Epoch 00004: saving model to ../model_wehigts/8_ch.hdf5
# Epoch 5/200
# 25569/25569 [==============================] - 65s 3ms/step - loss: 0.8724 - acc: 0.1442 - f1: 0.1276 - val_loss: 0.8749 - val_acc: 0.0688 - val_f1: 0.1251
#
# Epoch 00005: val_loss did not improve from 0.87493
#
# Epoch 00005: saving model to ../model_wehigts/8_ch.hdf5
# Epoch 6/200
# 25569/25569 [==============================] - 65s 3ms/step - loss: 0.8716 - acc: 0.0705 - f1: 0.1284 - val_loss: 0.8749 - val_acc: 0.0688 - val_f1: 0.1251
#
# Epoch 00006: val_loss did not improve from 0.87493
#
# Epoch 00006: saving model to ../model_wehigts/8_ch.hdf5
# Epoch 7/200
# 25569/25569 [==============================] - 65s 3ms/step - loss: 0.8715 - acc: 0.0705 - f1: 0.1285 - val_loss: 0.8749 - val_acc: 0.0688 - val_f1: 0.1251
#
# Epoch 00007: val_loss did not improve from 0.87493
#
# Epoch 00007: saving model to ../model_wehigts/8_ch.hdf5
# Epoch 8/200
# 25569/25569 [==============================] - 66s 3ms/step - loss: 0.8717 - acc: 0.0705 - f1: 0.1283 - val_loss: 0.8749 - val_acc: 0.0688 - val_f1: 0.1251
#
# Epoch 00008: val_loss did not improve from 0.87493
#
# Epoch 00008: saving model to ../model_wehigts/8_ch.hdf5
# Epoch 9/200
# 25569/25569 [==============================] - 66s 3ms/step - loss: 0.8717 - acc: 0.0705 - f1: 0.1283 - val_loss: 0.8749 - val_acc: 0.0688 - val_f1: 0.1251
#
# Epoch 00009: val_loss did not improve from 0.87493
#
# Epoch 00009: saving model to ../model_wehigts/8_ch.hdf5
# Epoch 10/200
# 25569/25569 [==============================] - 66s 3ms/step - loss: 0.8717 - acc: 0.0705 - f1: 0.1283 - val_loss: 0.8749 - val_acc: 0.0688 - val_f1: 0.1251
#
# Epoch 00010: val_loss did not improve from 0.87493
#
# Epoch 00010: saving model to ../model_wehigts/8_ch.hdf5
# Epoch 11/200
# 25569/25569 [==============================] - 66s 3ms/step - loss: 0.8715 - acc: 0.0705 - f1: 0.1285 - val_loss: 0.8749 - val_acc: 0.0688 - val_f1: 0.1251
#
# Epoch 00011: val_loss did not improve from 0.87493
#
# Epoch 00011: saving model to ../model_wehigts/8_ch.hdf5
# Epoch 12/200
# 25569/25569 [==============================] - 66s 3ms/step - loss: 0.8716 - acc: 0.0705 - f1: 0.1284 - val_loss: 0.8749 - val_acc: 0.0688 - val_f1: 0.1251
#
# Epoch 00012: val_loss did not improve from 0.87493
#
# Epoch 00012: saving model to ../model_wehigts/8_ch.hdf5
# Epoch 13/200
# 25569/25569 [==============================] - 66s 3ms/step - loss: 0.8717 - acc: 0.0705 - f1: 0.1283 - val_loss: 0.8749 - val_acc: 0.0688 - val_f1: 0.1251
#
# Epoch 00013: val_loss did not improve from 0.87493
#
# Epoch 00013: saving model to ../model_wehigts/8_ch.hdf5
# Epoch 14/200
# 25569/25569 [==============================] - 66s 3ms/step - loss: 0.8715 - acc: 0.0705 - f1: 0.1285 - val_loss: 0.8749 - val_acc: 0.0688 - val_f1: 0.1251
#
# Epoch 00014: val_loss did not improve from 0.87493
#
# Epoch 00014: saving model to ../model_wehigts/8_ch.hdf5
# Epoch 15/200
# 25569/25569 [==============================] - 67s 3ms/step - loss: 0.8716 - acc: 0.0705 - f1: 0.1284 - val_loss: 0.8749 - val_acc: 0.0688 - val_f1: 0.1251
#
# Epoch 00015: val_loss did not improve from 0.87493
#
# Epoch 00015: saving model to ../model_wehigts/8_ch.hdf5
# Epoch 16/200
# 25569/25569 [==============================] - 66s 3ms/step - loss: 0.8716 - acc: 0.0705 - f1: 0.1284 - val_loss: 0.8749 - val_acc: 0.0688 - val_f1: 0.1251
#
# Epoch 00016: val_loss did not improve from 0.87493
#
# Epoch 00016: saving model to ../model_wehigts/8_ch.hdf5
# Epoch 17/200
# 25569/25569 [==============================] - 67s 3ms/step - loss: 0.8717 - acc: 0.0705 - f1: 0.1283 - val_loss: 0.8749 - val_acc: 0.0688 - val_f1: 0.1251
#
# Epoch 00017: val_loss did not improve from 0.87493
#
# Epoch 00017: saving model to ../model_wehigts/8_ch.hdf5
# Epoch 18/200
# 25569/25569 [==============================] - 67s 3ms/step - loss: 0.8718 - acc: 0.0705 - f1: 0.1282 - val_loss: 0.8749 - val_acc: 0.0688 - val_f1: 0.1251
#
# Epoch 00018: val_loss improved from 0.87493 to 0.87493, saving model to ../model_wehigts/8_w.hdf5
#
# Epoch 00018: saving model to ../model_wehigts/8_ch.hdf5
# Epoch 19/200
# 25569/25569 [==============================] - 67s 3ms/step - loss: 0.8717 - acc: 0.0705 - f1: 0.1283 - val_loss: 0.8749 - val_acc: 0.0688 - val_f1: 0.1251
#
# Epoch 00019: val_loss improved from 0.87493 to 0.87493, saving model to ../model_wehigts/8_w.hdf5
#
# Epoch 00019: saving model to ../model_wehigts/8_ch.hdf5
# Epoch 20/200
# 25569/25569 [==============================] - 67s 3ms/step - loss: 0.8714 - acc: 0.0705 - f1: 0.1286 - val_loss: 0.8749 - val_acc: 0.0688 - val_f1: 0.1251
#
# Epoch 00020: val_loss did not improve from 0.87493
#
# Epoch 00020: saving model to ../model_wehigts/8_ch.hdf5
# Epoch 21/200
# 25569/25569 [==============================] - 63s 2ms/step - loss: 0.8718 - acc: 0.0705 - f1: 0.1282 - val_loss: 0.8749 - val_acc: 0.0688 - val_f1: 0.1251
#
# Epoch 00021: val_loss improved from 0.87493 to 0.87493, saving model to ../model_wehigts/8_w.hdf5
#
# Epoch 00021: saving model to ../model_wehigts/8_ch.hdf5
# Epoch 22/200
# 25569/25569 [==============================] - 59s 2ms/step - loss: 0.8716 - acc: 0.0705 - f1: 0.1284 - val_loss: 0.8749 - val_acc: 0.0688 - val_f1: 0.1251
#
# Epoch 00022: val_loss did not improve from 0.87493
#
# Epoch 00022: saving model to ../model_wehigts/8_ch.hdf5
# Epoch 23/200
# 25569/25569 [==============================] - 59s 2ms/step - loss: 0.8715 - acc: 0.0705 - f1: 0.1285 - val_loss: 0.8749 - val_acc: 0.0688 - val_f1: 0.1251
#
# Epoch 00023: val_loss did not improve from 0.87493
#
# Epoch 00023: saving model to ../model_wehigts/8_ch.hdf5
# Epoch 24/200
# 25569/25569 [==============================] - 59s 2ms/step - loss: 0.8714 - acc: 0.0705 - f1: 0.1286 - val_loss: 0.8749 - val_acc: 0.0688 - val_f1: 0.1251
#
# Epoch 00024: val_loss did not improve from 0.87493
#
# Epoch 00024: saving model to ../model_wehigts/8_ch.hdf5
# Epoch 25/200
# 25569/25569 [==============================] - 60s 2ms/step - loss: 0.8717 - acc: 0.0705 - f1: 0.1283 - val_loss: 0.8749 - val_acc: 0.0688 - val_f1: 0.1251
#
# Epoch 00025: val_loss did not improve from 0.87493
#
# Epoch 00025: saving model to ../model_wehigts/8_ch.hdf5
# Epoch 26/200
# 25569/25569 [==============================] - 60s 2ms/step - loss: 0.8726 - acc: 0.0986 - f1: 0.1274 - val_loss: 0.8750 - val_acc: 0.0688 - val_f1: 0.1250
#
# Epoch 00026: val_loss did not improve from 0.87493
#
# Epoch 00026: saving model to ../model_wehigts/8_ch.hdf5
# Epoch 27/200
# 25569/25569 [==============================] - 59s 2ms/step - loss: 0.8718 - acc: 0.0759 - f1: 0.1282 - val_loss: 0.8749 - val_acc: 0.0688 - val_f1: 0.1251
#
# Epoch 00027: val_loss did not improve from 0.87493
#
# Epoch 00027: saving model to ../model_wehigts/8_ch.hdf5
# Epoch 28/200
# 25569/25569 [==============================] - 59s 2ms/step - loss: 0.8718 - acc: 0.0705 - f1: 0.1282 - val_loss: 0.8749 - val_acc: 0.0688 - val_f1: 0.1251
#
# Epoch 00028: val_loss did not improve from 0.87493
#
# Epoch 00028: saving model to ../model_wehigts/8_ch.hdf5
# Epoch 29/200
# 25569/25569 [==============================] - 59s 2ms/step - loss: 0.8717 - acc: 0.0705 - f1: 0.1283 - val_loss: 0.8749 - val_acc: 0.0688 - val_f1: 0.1251
#
# Epoch 00029: val_loss did not improve from 0.87493
#
# Epoch 00029: saving model to ../model_wehigts/8_ch.hdf5
# Epoch 30/200
# 25569/25569 [==============================] - 59s 2ms/step - loss: 0.8716 - acc: 0.0704 - f1: 0.1284 - val_loss: 0.8749 - val_acc: 0.0688 - val_f1: 0.1251
#
# Epoch 00030: val_loss did not improve from 0.87493
#
# Epoch 00030: saving model to ../model_wehigts/8_ch.hdf5
# Epoch 31/200
# 25569/25569 [==============================] - 59s 2ms/step - loss: 0.8718 - acc: 0.0705 - f1: 0.1282 - val_loss: 0.8749 - val_acc: 0.0688 - val_f1: 0.1251
#
# Epoch 00031: val_loss did not improve from 0.87493
#
# Epoch 00031: saving model to ../model_wehigts/8_ch.hdf5
# Epoch 32/200
# 25569/25569 [==============================] - 59s 2ms/step - loss: 0.8715 - acc: 0.0705 - f1: 0.1285 - val_loss: 0.8749 - val_acc: 0.0688 - val_f1: 0.1251
#
# Epoch 00032: val_loss did not improve from 0.87493
#
# Epoch 00032: saving model to ../model_wehigts/8_ch.hdf5
# Epoch 33/200
# 25569/25569 [==============================] - 59s 2ms/step - loss: 0.8716 - acc: 0.0705 - f1: 0.1284 - val_loss: 0.8749 - val_acc: 0.0688 - val_f1: 0.1251
#
# Epoch 00033: val_loss did not improve from 0.87493
#
# Epoch 00033: saving model to ../model_wehigts/8_ch.hdf5
# Epoch 34/200
# 25569/25569 [==============================] - 59s 2ms/step - loss: 0.8717 - acc: 0.0705 - f1: 0.1283 - val_loss: 0.8749 - val_acc: 0.0688 - val_f1: 0.1251
#
# Epoch 00034: val_loss did not improve from 0.87493
#
# Epoch 00034: saving model to ../model_wehigts/8_ch.hdf5
# Epoch 35/200
# 25569/25569 [==============================] - 59s 2ms/step - loss: 0.8715 - acc: 0.0705 - f1: 0.1285 - val_loss: 0.8749 - val_acc: 0.0688 - val_f1: 0.1251
#
# Epoch 00035: val_loss did not improve from 0.87493
#
# Epoch 00035: saving model to ../model_wehigts/8_ch.hdf5
# Epoch 36/200
# 25569/25569 [==============================] - 59s 2ms/step - loss: 0.8716 - acc: 0.0705 - f1: 0.1284 - val_loss: 0.8749 - val_acc: 0.0688 - val_f1: 0.1251
#
# Epoch 00036: val_loss did not improve from 0.87493
#
# Epoch 00036: saving model to ../model_wehigts/8_ch.hdf5
# Epoch 37/200
# 25569/25569 [==============================] - 59s 2ms/step - loss: 0.8717 - acc: 0.0705 - f1: 0.1283 - val_loss: 0.8749 - val_acc: 0.0688 - val_f1: 0.1251
#
# Epoch 00037: val_loss did not improve from 0.87493
#
# Epoch 00037: saving model to ../model_wehigts/8_ch.hdf5
# Epoch 38/200
# 25569/25569 [==============================] - 59s 2ms/step - loss: 0.8721 - acc: 0.0732 - f1: 0.1279 - val_loss: 0.8749 - val_acc: 0.0688 - val_f1: 0.1251
#
# Epoch 00038: val_loss did not improve from 0.87493
#
# Epoch 00038: saving model to ../model_wehigts/8_ch.hdf5
# Epoch 39/200
# 25569/25569 [==============================] - 59s 2ms/step - loss: 0.8717 - acc: 0.0705 - f1: 0.1283 - val_loss: 0.8749 - val_acc: 0.0688 - val_f1: 0.1251
#
# Epoch 00039: val_loss did not improve from 0.87493
#
# Epoch 00039: saving model to ../model_wehigts/8_ch.hdf5
# Epoch 40/200
# 25569/25569 [==============================] - 59s 2ms/step - loss: 0.8715 - acc: 0.0705 - f1: 0.1285 - val_loss: 0.8749 - val_acc: 0.0688 - val_f1: 0.1251
#
# Epoch 00040: val_loss did not improve from 0.87493
#
# Epoch 00040: saving model to ../model_wehigts/8_ch.hdf5
# Epoch 41/200
# 25569/25569 [==============================] - 59s 2ms/step - loss: 0.8716 - acc: 0.0705 - f1: 0.1284 - val_loss: 0.8749 - val_acc: 0.0688 - val_f1: 0.1251
#
# Epoch 00041: val_loss did not improve from 0.87493
#
# Epoch 00041: saving model to ../model_wehigts/8_ch.hdf5
# Epoch 42/200
# 25569/25569 [==============================] - 59s 2ms/step - loss: 0.8714 - acc: 0.0705 - f1: 0.1286 - val_loss: 0.8749 - val_acc: 0.0688 - val_f1: 0.1251
#
# Epoch 00042: val_loss did not improve from 0.87493
#
# Epoch 00042: saving model to ../model_wehigts/8_ch.hdf5
# Epoch 43/200
# 25569/25569 [==============================] - 59s 2ms/step - loss: 0.8715 - acc: 0.0705 - f1: 0.1285 - val_loss: 0.8749 - val_acc: 0.0688 - val_f1: 0.1251
#
# Epoch 00043: val_loss did not improve from 0.87493
#
# Epoch 00043: saving model to ../model_wehigts/8_ch.hdf5
# Epoch 44/200
# 25569/25569 [==============================] - 59s 2ms/step - loss: 0.8717 - acc: 0.0705 - f1: 0.1283 - val_loss: 0.8749 - val_acc: 0.0688 - val_f1: 0.1251
#
# Epoch 00044: val_loss did not improve from 0.87493
#
# Epoch 00044: saving model to ../model_wehigts/8_ch.hdf5
# Epoch 45/200
# 25569/25569 [==============================] - 59s 2ms/step - loss: 0.8718 - acc: 0.0705 - f1: 0.1282 - val_loss: 0.8749 - val_acc: 0.0688 - val_f1: 0.1251
#
# Epoch 00045: val_loss did not improve from 0.87493
#
# Epoch 00045: saving model to ../model_wehigts/8_ch.hdf5
# Epoch 46/200
# 25569/25569 [==============================] - 59s 2ms/step - loss: 0.8716 - acc: 0.0705 - f1: 0.1284 - val_loss: 0.8749 - val_acc: 0.0688 - val_f1: 0.1251
#
# Epoch 00046: val_loss did not improve from 0.87493
#
# Epoch 00046: saving model to ../model_wehigts/8_ch.hdf5
# Epoch 47/200
# 25569/25569 [==============================] - 59s 2ms/step - loss: 0.8714 - acc: 0.0705 - f1: 0.1286 - val_loss: 0.8749 - val_acc: 0.0688 - val_f1: 0.1251
#
# Epoch 00047: val_loss did not improve from 0.87493
#
# Epoch 00047: saving model to ../model_wehigts/8_ch.hdf5
# Epoch 48/200
# 25569/25569 [==============================] - 59s 2ms/step - loss: 0.8716 - acc: 0.0705 - f1: 0.1284 - val_loss: 0.8749 - val_acc: 0.0688 - val_f1: 0.1251
#
# Epoch 00048: val_loss did not improve from 0.87493
#
# Epoch 00048: saving model to ../model_wehigts/8_ch.hdf5
# Epoch 49/200
# 25569/25569 [==============================] - 59s 2ms/step - loss: 0.8718 - acc: 0.0705 - f1: 0.1282 - val_loss: 0.8749 - val_acc: 0.0688 - val_f1: 0.1251
#
# Epoch 00049: val_loss did not improve from 0.87493
#
# Epoch 00049: saving model to ../model_wehigts/8_ch.hdf5
# Epoch 50/200
# 25569/25569 [==============================] - 59s 2ms/step - loss: 0.8716 - acc: 0.0705 - f1: 0.1284 - val_loss: 0.8749 - val_acc: 0.0688 - val_f1: 0.1251
#
# Epoch 00050: val_loss did not improve from 0.87493
#
# Epoch 00050: saving model to ../model_wehigts/8_ch.hdf5
# Epoch 51/200
# 25569/25569 [==============================] - 59s 2ms/step - loss: 0.8715 - acc: 0.0705 - f1: 0.1285 - val_loss: 0.8749 - val_acc: 0.0688 - val_f1: 0.1251
#
# Epoch 00051: val_loss did not improve from 0.87493
#
# Epoch 00051: saving model to ../model_wehigts/8_ch.hdf5
# Epoch 52/200
# 25569/25569 [==============================] - 59s 2ms/step - loss: 0.8725 - acc: 0.0984 - f1: 0.1275 - val_loss: 0.8749 - val_acc: 0.0688 - val_f1: 0.1251
#
# Epoch 00052: val_loss did not improve from 0.87493
#
# Epoch 00052: saving model to ../model_wehigts/8_ch.hdf5
# Epoch 53/200
# 25569/25569 [==============================] - 59s 2ms/step - loss: 0.8719 - acc: 0.0708 - f1: 0.1281 - val_loss: 0.8749 - val_acc: 0.0688 - val_f1: 0.1251
#
# Epoch 00053: val_loss did not improve from 0.87493
#
# Epoch 00053: saving model to ../model_wehigts/8_ch.hdf5
# Epoch 54/200
# 25569/25569 [==============================] - 59s 2ms/step - loss: 0.8716 - acc: 0.0705 - f1: 0.1284 - val_loss: 0.8749 - val_acc: 0.0688 - val_f1: 0.1251
#
# Epoch 00054: val_loss did not improve from 0.87493
#
# Epoch 00054: saving model to ../model_wehigts/8_ch.hdf5
# Epoch 55/200
# 25569/25569 [==============================] - 61s 2ms/step - loss: 0.8716 - acc: 0.0705 - f1: 0.1284 - val_loss: 0.8749 - val_acc: 0.0688 - val_f1: 0.1251
#
# Epoch 00055: val_loss did not improve from 0.87493
#
# Epoch 00055: saving model to ../model_wehigts/8_ch.hdf5
# Epoch 56/200
# 25569/25569 [==============================] - 59s 2ms/step - loss: 0.8716 - acc: 0.0705 - f1: 0.1284 - val_loss: 0.8749 - val_acc: 0.0688 - val_f1: 0.1251
#
# Epoch 00056: val_loss did not improve from 0.87493
#
# Epoch 00056: saving model to ../model_wehigts/8_ch.hdf5
# Epoch 57/200
# 25569/25569 [==============================] - 60s 2ms/step - loss: 0.8713 - acc: 0.0705 - f1: 0.1287 - val_loss: 0.8749 - val_acc: 0.0688 - val_f1: 0.1251
#
# Epoch 00057: val_loss did not improve from 0.87493
#
# Epoch 00057: saving model to ../model_wehigts/8_ch.hdf5
# Epoch 58/200
# 25569/25569 [==============================] - 60s 2ms/step - loss: 0.8713 - acc: 0.0705 - f1: 0.1287 - val_loss: 0.8749 - val_acc: 0.0688 - val_f1: 0.1251
#
# Epoch 00058: val_loss did not improve from 0.87493
#
# Epoch 00058: saving model to ../model_wehigts/8_ch.hdf5
# Epoch 59/200
# 25569/25569 [==============================] - 59s 2ms/step - loss: 0.8716 - acc: 0.0705 - f1: 0.1284 - val_loss: 0.8749 - val_acc: 0.0688 - val_f1: 0.1251
#
# Epoch 00059: val_loss did not improve from 0.87493
#
# Epoch 00059: saving model to ../model_wehigts/8_ch.hdf5
# Epoch 60/200
# 25569/25569 [==============================] - 59s 2ms/step - loss: 0.8715 - acc: 0.0705 - f1: 0.1285 - val_loss: 0.8749 - val_acc: 0.0688 - val_f1: 0.1251
#
# Epoch 00060: val_loss did not improve from 0.87493
#
# Epoch 00060: saving model to ../model_wehigts/8_ch.hdf5
# Epoch 61/200
# 25569/25569 [==============================] - 59s 2ms/step - loss: 0.8716 - acc: 0.0705 - f1: 0.1284 - val_loss: 0.8749 - val_acc: 0.0688 - val_f1: 0.1251
#
# Epoch 00061: val_loss did not improve from 0.87493
#
# Epoch 00061: saving model to ../model_wehigts/8_ch.hdf5
# Epoch 62/200
# 25569/25569 [==============================] - 59s 2ms/step - loss: 0.8720 - acc: 0.0751 - f1: 0.1280 - val_loss: 0.8749 - val_acc: 0.0688 - val_f1: 0.1251
#
# Epoch 00062: val_loss did not improve from 0.87493
#
# Epoch 00062: saving model to ../model_wehigts/8_ch.hdf5
# Epoch 63/200
# 25569/25569 [==============================] - 59s 2ms/step - loss: 0.8716 - acc: 0.0705 - f1: 0.1284 - val_loss: 0.8749 - val_acc: 0.0688 - val_f1: 0.1251
#
# Epoch 00063: val_loss did not improve from 0.87493
#
# Epoch 00063: saving model to ../model_wehigts/8_ch.hdf5
# Epoch 64/200
# 25569/25569 [==============================] - 59s 2ms/step - loss: 0.8714 - acc: 0.0705 - f1: 0.1286 - val_loss: 0.8749 - val_acc: 0.0688 - val_f1: 0.1251
#
# Epoch 00064: val_loss did not improve from 0.87493
#
# Epoch 00064: saving model to ../model_wehigts/8_ch.hdf5
# Epoch 65/200
# 25569/25569 [==============================] - 59s 2ms/step - loss: 0.8714 - acc: 0.0705 - f1: 0.1286 - val_loss: 0.8749 - val_acc: 0.0688 - val_f1: 0.1251
#
# Epoch 00065: val_loss did not improve from 0.87493
#
# Epoch 00065: saving model to ../model_wehigts/8_ch.hdf5
# Epoch 66/200
# 25569/25569 [==============================] - 59s 2ms/step - loss: 0.8718 - acc: 0.0705 - f1: 0.1282 - val_loss: 0.8749 - val_acc: 0.0688 - val_f1: 0.1251
#
# Epoch 00066: val_loss did not improve from 0.87493
#
# Epoch 00066: saving model to ../model_wehigts/8_ch.hdf5
# Epoch 67/200
# 25569/25569 [==============================] - 59s 2ms/step - loss: 0.8733 - acc: 0.1413 - f1: 0.1267 - val_loss: 0.8749 - val_acc: 0.0688 - val_f1: 0.1251
#
# Epoch 00067: val_loss did not improve from 0.87493
#
# Epoch 00067: saving model to ../model_wehigts/8_ch.hdf5
# Epoch 68/200
# 25569/25569 [==============================] - 59s 2ms/step - loss: 0.8726 - acc: 0.0934 - f1: 0.1274 - val_loss: 0.8749 - val_acc: 0.0688 - val_f1: 0.1251
#
# Epoch 00068: val_loss did not improve from 0.87493
#
# Epoch 00068: saving model to ../model_wehigts/8_ch.hdf5
# Epoch 69/200
# 25569/25569 [==============================] - 59s 2ms/step - loss: 0.8714 - acc: 0.0767 - f1: 0.1286 - val_loss: 0.8749 - val_acc: 0.0688 - val_f1: 0.1251
#
# Epoch 00069: val_loss did not improve from 0.87493
#
# Epoch 00069: saving model to ../model_wehigts/8_ch.hdf5
# Epoch 70/200
# 25569/25569 [==============================] - 60s 2ms/step - loss: 0.8716 - acc: 0.0708 - f1: 0.1284 - val_loss: 0.8749 - val_acc: 0.0688 - val_f1: 0.1251
#
# Epoch 00070: val_loss did not improve from 0.87493
#
# Epoch 00070: saving model to ../model_wehigts/8_ch.hdf5
# Epoch 71/200
# 25569/25569 [==============================] - 59s 2ms/step - loss: 0.8717 - acc: 0.0706 - f1: 0.1283 - val_loss: 0.8749 - val_acc: 0.0688 - val_f1: 0.1251
#
# Epoch 00071: val_loss did not improve from 0.87493
#
# Epoch 00071: saving model to ../model_wehigts/8_ch.hdf5
# Epoch 72/200
# 25569/25569 [==============================] - 59s 2ms/step - loss: 0.8716 - acc: 0.0705 - f1: 0.1284 - val_loss: 0.8749 - val_acc: 0.0688 - val_f1: 0.1251
#
# Epoch 00072: val_loss did not improve from 0.87493
#
# Epoch 00072: saving model to ../model_wehigts/8_ch.hdf5
# Epoch 73/200
# 25569/25569 [==============================] - 59s 2ms/step - loss: 0.8715 - acc: 0.0706 - f1: 0.1285 - val_loss: 0.8749 - val_acc: 0.0688 - val_f1: 0.1251
#
# Epoch 00073: val_loss did not improve from 0.87493
#
# Epoch 00073: saving model to ../model_wehigts/8_ch.hdf5
# Epoch 74/200
# 25569/25569 [==============================] - 59s 2ms/step - loss: 0.8717 - acc: 0.0706 - f1: 0.1283 - val_loss: 0.8749 - val_acc: 0.0688 - val_f1: 0.1251
#
# Epoch 00074: val_loss did not improve from 0.87493
#
# Epoch 00074: saving model to ../model_wehigts/8_ch.hdf5
# Epoch 75/200
# 25569/25569 [==============================] - 59s 2ms/step - loss: 0.8716 - acc: 0.0706 - f1: 0.1284 - val_loss: 0.8749 - val_acc: 0.0688 - val_f1: 0.1251
#
# Epoch 00075: val_loss did not improve from 0.87493
#
# Epoch 00075: saving model to ../model_wehigts/8_ch.hdf5
# Epoch 76/200
# 25569/25569 [==============================] - 59s 2ms/step - loss: 0.8719 - acc: 0.0729 - f1: 0.1281 - val_loss: 0.8749 - val_acc: 0.0688 - val_f1: 0.1251
#
# Epoch 00076: val_loss did not improve from 0.87493
#
# Epoch 00076: saving model to ../model_wehigts/8_ch.hdf5
# Epoch 77/200
# 25569/25569 [==============================] - 59s 2ms/step - loss: 0.8736 - acc: 0.1453 - f1: 0.1264 - val_loss: 0.8749 - val_acc: 0.0688 - val_f1: 0.1251
#
# Epoch 00077: val_loss did not improve from 0.87493
#
# Epoch 00077: saving model to ../model_wehigts/8_ch.hdf5
# Epoch 78/200
# 25569/25569 [==============================] - 59s 2ms/step - loss: 0.8716 - acc: 0.0706 - f1: 0.1284 - val_loss: 0.8749 - val_acc: 0.0688 - val_f1: 0.1251
#
# Epoch 00078: val_loss did not improve from 0.87493
#
# Epoch 00078: saving model to ../model_wehigts/8_ch.hdf5
# Epoch 79/200
# 25569/25569 [==============================] - 59s 2ms/step - loss: 0.8720 - acc: 0.0705 - f1: 0.1280 - val_loss: 0.8749 - val_acc: 0.0688 - val_f1: 0.1251
#
# Epoch 00079: val_loss did not improve from 0.87493
#
# Epoch 00079: saving model to ../model_wehigts/8_ch.hdf5
# Epoch 80/200
# 25569/25569 [==============================] - 59s 2ms/step - loss: 0.8717 - acc: 0.0706 - f1: 0.1283 - val_loss: 0.8749 - val_acc: 0.0688 - val_f1: 0.1251
#
# Epoch 00080: val_loss did not improve from 0.87493
#
# Epoch 00080: saving model to ../model_wehigts/8_ch.hdf5
# Epoch 81/200
# 25569/25569 [==============================] - 59s 2ms/step - loss: 0.8720 - acc: 0.0714 - f1: 0.1280 - val_loss: 0.8749 - val_acc: 0.0688 - val_f1: 0.1251
#
# Epoch 00081: val_loss did not improve from 0.87493
#
# Epoch 00081: saving model to ../model_wehigts/8_ch.hdf5
# Epoch 82/200
# 25569/25569 [==============================] - 59s 2ms/step - loss: 0.8736 - acc: 0.1547 - f1: 0.1264 - val_loss: 0.8749 - val_acc: 0.0688 - val_f1: 0.1251
#
# Epoch 00082: val_loss did not improve from 0.87493
#
# Epoch 00082: saving model to ../model_wehigts/8_ch.hdf5
# Epoch 83/200
# 25569/25569 [==============================] - 59s 2ms/step - loss: 0.8726 - acc: 0.1318 - f1: 0.1274 - val_loss: 0.8770 - val_acc: 0.0688 - val_f1: 0.1230
#
# Epoch 00083: val_loss did not improve from 0.87493
#
# Epoch 00083: saving model to ../model_wehigts/8_ch.hdf5
# Epoch 84/200
# 25569/25569 [==============================] - 59s 2ms/step - loss: 0.8721 - acc: 0.0736 - f1: 0.1279 - val_loss: 0.8750 - val_acc: 0.0688 - val_f1: 0.1250
#
# Epoch 00084: val_loss did not improve from 0.87493
#
# Epoch 00084: saving model to ../model_wehigts/8_ch.hdf5
# Epoch 85/200
# 25569/25569 [==============================] - 59s 2ms/step - loss: 0.8719 - acc: 0.0705 - f1: 0.1281 - val_loss: 0.8750 - val_acc: 0.0688 - val_f1: 0.1250
#
# Epoch 00085: val_loss did not improve from 0.87493
#
# Epoch 00085: saving model to ../model_wehigts/8_ch.hdf5
# Epoch 86/200
# 25569/25569 [==============================] - 59s 2ms/step - loss: 0.8718 - acc: 0.0706 - f1: 0.1282 - val_loss: 0.8750 - val_acc: 0.0688 - val_f1: 0.1250
#
# Epoch 00086: val_loss did not improve from 0.87493
#
# Epoch 00086: saving model to ../model_wehigts/8_ch.hdf5
# Epoch 87/200
# 25569/25569 [==============================] - 59s 2ms/step - loss: 0.8717 - acc: 0.0705 - f1: 0.1283 - val_loss: 0.8749 - val_acc: 0.0688 - val_f1: 0.1251
#
# Epoch 00087: val_loss did not improve from 0.87493
#
# Epoch 00087: saving model to ../model_wehigts/8_ch.hdf5
# Epoch 88/200
# 25569/25569 [==============================] - 59s 2ms/step - loss: 0.8715 - acc: 0.0705 - f1: 0.1285 - val_loss: 0.8749 - val_acc: 0.0688 - val_f1: 0.1251
#
# Epoch 00088: val_loss did not improve from 0.87493
#
# Epoch 00088: saving model to ../model_wehigts/8_ch.hdf5
# Epoch 89/200
# 25569/25569 [==============================] - 59s 2ms/step - loss: 0.8720 - acc: 0.0704 - f1: 0.1280 - val_loss: 0.8750 - val_acc: 0.0688 - val_f1: 0.1250
#
# Epoch 00089: val_loss did not improve from 0.87493
#
# Epoch 00089: saving model to ../model_wehigts/8_ch.hdf5
# Epoch 90/200
# 25569/25569 [==============================] - 59s 2ms/step - loss: 0.8717 - acc: 0.0705 - f1: 0.1283 - val_loss: 0.8749 - val_acc: 0.0688 - val_f1: 0.1251
#
# Epoch 00090: val_loss did not improve from 0.87493
#
# Epoch 00090: saving model to ../model_wehigts/8_ch.hdf5
# Epoch 91/200
# 25569/25569 [==============================] - 59s 2ms/step - loss: 0.8715 - acc: 0.0705 - f1: 0.1285 - val_loss: 0.8749 - val_acc: 0.0688 - val_f1: 0.1251
#
# Epoch 00091: val_loss did not improve from 0.87493
#
# Epoch 00091: saving model to ../model_wehigts/8_ch.hdf5
# Epoch 92/200
# 25569/25569 [==============================] - 60s 2ms/step - loss: 0.8717 - acc: 0.0705 - f1: 0.1283 - val_loss: 0.8749 - val_acc: 0.0688 - val_f1: 0.1251
#
# Epoch 00092: val_loss did not improve from 0.87493
#
# Epoch 00092: saving model to ../model_wehigts/8_ch.hdf5
# Epoch 93/200
# 25569/25569 [==============================] - 59s 2ms/step - loss: 0.8715 - acc: 0.0706 - f1: 0.1285 - val_loss: 0.8749 - val_acc: 0.0688 - val_f1: 0.1251
#
# Epoch 00093: val_loss did not improve from 0.87493
#
# Epoch 00093: saving model to ../model_wehigts/8_ch.hdf5
# Epoch 94/200
# 25569/25569 [==============================] - 59s 2ms/step - loss: 0.8732 - acc: 0.1456 - f1: 0.1268 - val_loss: 0.8749 - val_acc: 0.0688 - val_f1: 0.1251
#
# Epoch 00094: val_loss did not improve from 0.87493
#
# Epoch 00094: saving model to ../model_wehigts/8_ch.hdf5
# Epoch 95/200
# 25569/25569 [==============================] - 59s 2ms/step - loss: 0.8719 - acc: 0.0734 - f1: 0.1281 - val_loss: 0.8749 - val_acc: 0.0688 - val_f1: 0.1251
#
# Epoch 00095: val_loss did not improve from 0.87493
#
# Epoch 00095: saving model to ../model_wehigts/8_ch.hdf5
# Epoch 96/200
# 25569/25569 [==============================] - 59s 2ms/step - loss: 0.8718 - acc: 0.0709 - f1: 0.1282 - val_loss: 0.8749 - val_acc: 0.0688 - val_f1: 0.1251
#
# Epoch 00096: val_loss did not improve from 0.87493
#
# Epoch 00096: saving model to ../model_wehigts/8_ch.hdf5
# Epoch 97/200
# 25569/25569 [==============================] - 59s 2ms/step - loss: 0.8713 - acc: 0.0705 - f1: 0.1287 - val_loss: 0.8749 - val_acc: 0.0688 - val_f1: 0.1251
#
# Epoch 00097: val_loss did not improve from 0.87493
#
# Epoch 00097: saving model to ../model_wehigts/8_ch.hdf5
# Epoch 98/200
# 25569/25569 [==============================] - 59s 2ms/step - loss: 0.8717 - acc: 0.0715 - f1: 0.1283 - val_loss: 0.8749 - val_acc: 0.0688 - val_f1: 0.1251
#
# Epoch 00098: val_loss did not improve from 0.87493
#
# Epoch 00098: saving model to ../model_wehigts/8_ch.hdf5
# Epoch 99/200
# 25569/25569 [==============================] - 59s 2ms/step - loss: 0.8732 - acc: 0.1047 - f1: 0.1268 - val_loss: 0.8749 - val_acc: 0.0688 - val_f1: 0.1251
#
# Epoch 00099: val_loss did not improve from 0.87493
#
# Epoch 00099: saving model to ../model_wehigts/8_ch.hdf5
# Epoch 100/200
# 25569/25569 [==============================] - 59s 2ms/step - loss: 0.8716 - acc: 0.0706 - f1: 0.1284 - val_loss: 0.8749 - val_acc: 0.0688 - val_f1: 0.1251
#
# Epoch 00100: val_loss did not improve from 0.87493
#
# Epoch 00100: saving model to ../model_wehigts/8_ch.hdf5
# Epoch 101/200
# 25569/25569 [==============================] - 60s 2ms/step - loss: 0.8716 - acc: 0.0705 - f1: 0.1284 - val_loss: 0.8749 - val_acc: 0.0688 - val_f1: 0.1251
#
# Epoch 00101: val_loss did not improve from 0.87493
#
# Epoch 00101: saving model to ../model_wehigts/8_ch.hdf5
# Epoch 102/200
# 25569/25569 [==============================] - 59s 2ms/step - loss: 0.8716 - acc: 0.0705 - f1: 0.1284 - val_loss: 0.8749 - val_acc: 0.0688 - val_f1: 0.1251
#
# Epoch 00102: val_loss did not improve from 0.87493
#
# Epoch 00102: saving model to ../model_wehigts/8_ch.hdf5
# Epoch 103/200
# 25569/25569 [==============================] - 59s 2ms/step - loss: 0.8715 - acc: 0.0705 - f1: 0.1285 - val_loss: 0.8749 - val_acc: 0.0688 - val_f1: 0.1251
#
# Epoch 00103: val_loss did not improve from 0.87493
#
# Epoch 00103: saving model to ../model_wehigts/8_ch.hdf5
# Epoch 104/200
# 25569/25569 [==============================] - 59s 2ms/step - loss: 0.8713 - acc: 0.0705 - f1: 0.1287 - val_loss: 0.8749 - val_acc: 0.0688 - val_f1: 0.1251
#
# Epoch 00104: val_loss did not improve from 0.87493
#
# Epoch 00104: saving model to ../model_wehigts/8_ch.hdf5
# Epoch 105/200
# 25569/25569 [==============================] - 59s 2ms/step - loss: 0.8718 - acc: 0.0705 - f1: 0.1282 - val_loss: 0.8749 - val_acc: 0.0688 - val_f1: 0.1251
#
# Epoch 00105: val_loss did not improve from 0.87493
#
# Epoch 00105: saving model to ../model_wehigts/8_ch.hdf5
# Epoch 106/200
# 25569/25569 [==============================] - 60s 2ms/step - loss: 0.8717 - acc: 0.0705 - f1: 0.1283 - val_loss: 0.8749 - val_acc: 0.0688 - val_f1: 0.1251
#
# Epoch 00106: val_loss did not improve from 0.87493
#
# Epoch 00106: saving model to ../model_wehigts/8_ch.hdf5
# Epoch 107/200
# 25569/25569 [==============================] - 59s 2ms/step - loss: 0.8715 - acc: 0.0705 - f1: 0.1285 - val_loss: 0.8749 - val_acc: 0.0688 - val_f1: 0.1251
#
# Epoch 00107: val_loss did not improve from 0.87493
#
# Epoch 00107: saving model to ../model_wehigts/8_ch.hdf5
# Epoch 108/200
# 25569/25569 [==============================] - 59s 2ms/step - loss: 0.8717 - acc: 0.0705 - f1: 0.1283 - val_loss: 0.8749 - val_acc: 0.0688 - val_f1: 0.1251
#
# Epoch 00108: val_loss did not improve from 0.87493
#
# Epoch 00108: saving model to ../model_wehigts/8_ch.hdf5
# Epoch 109/200
# 25569/25569 [==============================] - 59s 2ms/step - loss: 0.8718 - acc: 0.0706 - f1: 0.1282 - val_loss: 0.8749 - val_acc: 0.0688 - val_f1: 0.1251
#
# Epoch 00109: val_loss did not improve from 0.87493
#
# Epoch 00109: saving model to ../model_wehigts/8_ch.hdf5
# Epoch 110/200
# 25569/25569 [==============================] - 59s 2ms/step - loss: 0.8715 - acc: 0.0706 - f1: 0.1285 - val_loss: 0.8749 - val_acc: 0.0688 - val_f1: 0.1251
#
# Epoch 00110: val_loss did not improve from 0.87493
#
# Epoch 00110: saving model to ../model_wehigts/8_ch.hdf5
# Epoch 111/200
# 25569/25569 [==============================] - 60s 2ms/step - loss: 0.8718 - acc: 0.0705 - f1: 0.1282 - val_loss: 0.8749 - val_acc: 0.0688 - val_f1: 0.1251
#
# Epoch 00111: val_loss did not improve from 0.87493
#
# Epoch 00111: saving model to ../model_wehigts/8_ch.hdf5
# Epoch 112/200
# 25569/25569 [==============================] - 59s 2ms/step - loss: 0.8716 - acc: 0.0706 - f1: 0.1284 - val_loss: 0.8749 - val_acc: 0.0688 - val_f1: 0.1251
#
# Epoch 00112: val_loss did not improve from 0.87493
#
# Epoch 00112: saving model to ../model_wehigts/8_ch.hdf5
# Epoch 113/200
# 25569/25569 [==============================] - 59s 2ms/step - loss: 0.8717 - acc: 0.0705 - f1: 0.1283 - val_loss: 0.8749 - val_acc: 0.0688 - val_f1: 0.1251
#
# Epoch 00113: val_loss did not improve from 0.87493
#
# Epoch 00113: saving model to ../model_wehigts/8_ch.hdf5
# Epoch 114/200
# 25569/25569 [==============================] - 59s 2ms/step - loss: 0.8717 - acc: 0.0705 - f1: 0.1283 - val_loss: 0.8749 - val_acc: 0.0688 - val_f1: 0.1251
#
# Epoch 00114: val_loss did not improve from 0.87493
#
# Epoch 00114: saving model to ../model_wehigts/8_ch.hdf5
# Epoch 115/200
# 25569/25569 [==============================] - 59s 2ms/step - loss: 0.8717 - acc: 0.0706 - f1: 0.1283 - val_loss: 0.8749 - val_acc: 0.0688 - val_f1: 0.1251
#
# Epoch 00115: val_loss did not improve from 0.87493
#
# Epoch 00115: saving model to ../model_wehigts/8_ch.hdf5
# Epoch 116/200
# 25569/25569 [==============================] - 59s 2ms/step - loss: 0.8714 - acc: 0.0705 - f1: 0.1286 - val_loss: 0.8749 - val_acc: 0.0688 - val_f1: 0.1251
#
# Epoch 00116: val_loss did not improve from 0.87493
#
# Epoch 00116: saving model to ../model_wehigts/8_ch.hdf5
# Epoch 117/200
# 25569/25569 [==============================] - 60s 2ms/step - loss: 0.8715 - acc: 0.0705 - f1: 0.1285 - val_loss: 0.8749 - val_acc: 0.0688 - val_f1: 0.1251
#
# Epoch 00117: val_loss did not improve from 0.87493
#
# Epoch 00117: saving model to ../model_wehigts/8_ch.hdf5
# Epoch 118/200
# 25569/25569 [==============================] - 59s 2ms/step - loss: 0.8717 - acc: 0.0705 - f1: 0.1283 - val_loss: 0.8749 - val_acc: 0.0688 - val_f1: 0.1251
#
# Epoch 00118: val_loss did not improve from 0.87493
#
# Epoch 00118: saving model to ../model_wehigts/8_ch.hdf5
# Epoch 119/200
# 25569/25569 [==============================] - 59s 2ms/step - loss: 0.8717 - acc: 0.0705 - f1: 0.1283 - val_loss: 0.8749 - val_acc: 0.0688 - val_f1: 0.1251
#
# Epoch 00119: val_loss did not improve from 0.87493
#
# Epoch 00119: saving model to ../model_wehigts/8_ch.hdf5
# Epoch 120/200
# 25569/25569 [==============================] - 59s 2ms/step - loss: 0.8715 - acc: 0.0708 - f1: 0.1285 - val_loss: 0.8749 - val_acc: 0.0688 - val_f1: 0.1251
#
# Epoch 00120: val_loss did not improve from 0.87493
#
# Epoch 00120: saving model to ../model_wehigts/8_ch.hdf5
# Epoch 121/200
# 25569/25569 [==============================] - 60s 2ms/step - loss: 0.8716 - acc: 0.0704 - f1: 0.1284 - val_loss: 0.8749 - val_acc: 0.0688 - val_f1: 0.1251
#
# Epoch 00121: val_loss did not improve from 0.87493
#
# Epoch 00121: saving model to ../model_wehigts/8_ch.hdf5
# Epoch 122/200
# 25569/25569 [==============================] - 60s 2ms/step - loss: 0.8715 - acc: 0.0705 - f1: 0.1285 - val_loss: 0.8749 - val_acc: 0.0688 - val_f1: 0.1251
#
# Epoch 00122: val_loss did not improve from 0.87493
#
# Epoch 00122: saving model to ../model_wehigts/8_ch.hdf5
# Epoch 123/200
# 25569/25569 [==============================] - 59s 2ms/step - loss: 0.8716 - acc: 0.0705 - f1: 0.1284 - val_loss: 0.8749 - val_acc: 0.0688 - val_f1: 0.1251
#
# Epoch 00123: val_loss did not improve from 0.87493
#
# Epoch 00123: saving model to ../model_wehigts/8_ch.hdf5
# Epoch 124/200
# 25569/25569 [==============================] - 59s 2ms/step - loss: 0.8714 - acc: 0.0706 - f1: 0.1286 - val_loss: 0.8749 - val_acc: 0.0688 - val_f1: 0.1251
#
# Epoch 00124: val_loss did not improve from 0.87493
#
# Epoch 00124: saving model to ../model_wehigts/8_ch.hdf5
# Epoch 125/200
# 25569/25569 [==============================] - 59s 2ms/step - loss: 0.8714 - acc: 0.0705 - f1: 0.1286 - val_loss: 0.8749 - val_acc: 0.0688 - val_f1: 0.1251
#
# Epoch 00125: val_loss did not improve from 0.87493
#
# Epoch 00125: saving model to ../model_wehigts/8_ch.hdf5
# Epoch 126/200
# 25569/25569 [==============================] - 60s 2ms/step - loss: 0.8719 - acc: 0.0705 - f1: 0.1281 - val_loss: 0.8749 - val_acc: 0.0688 - val_f1: 0.1251
#
# Epoch 00126: val_loss did not improve from 0.87493
#
# Epoch 00126: saving model to ../model_wehigts/8_ch.hdf5
# Epoch 127/200
# 25569/25569 [==============================] - 59s 2ms/step - loss: 0.8718 - acc: 0.0706 - f1: 0.1282 - val_loss: 0.8749 - val_acc: 0.0688 - val_f1: 0.1251
#
# Epoch 00127: val_loss did not improve from 0.87493
#
# Epoch 00127: saving model to ../model_wehigts/8_ch.hdf5
# Epoch 128/200
# 25569/25569 [==============================] - 59s 2ms/step - loss: 0.8715 - acc: 0.0716 - f1: 0.1285 - val_loss: 0.8749 - val_acc: 0.0688 - val_f1: 0.1251
#
# Epoch 00128: val_loss did not improve from 0.87493
#
# Epoch 00128: saving model to ../model_wehigts/8_ch.hdf5
# Epoch 129/200
# 25569/25569 [==============================] - 59s 2ms/step - loss: 0.8718 - acc: 0.0741 - f1: 0.1282 - val_loss: 0.8749 - val_acc: 0.0688 - val_f1: 0.1251
#
# Epoch 00129: val_loss did not improve from 0.87493
#
# Epoch 00129: saving model to ../model_wehigts/8_ch.hdf5
# Epoch 130/200
# 25569/25569 [==============================] - 59s 2ms/step - loss: 0.8715 - acc: 0.0802 - f1: 0.1285 - val_loss: 0.8749 - val_acc: 0.0688 - val_f1: 0.1251
#
# Epoch 00130: val_loss did not improve from 0.87493
#
# Epoch 00130: saving model to ../model_wehigts/8_ch.hdf5
# Epoch 131/200
# 25569/25569 [==============================] - 60s 2ms/step - loss: 0.8716 - acc: 0.0750 - f1: 0.1284 - val_loss: 0.8749 - val_acc: 0.0688 - val_f1: 0.1251
#
# Epoch 00131: val_loss did not improve from 0.87493
#
# Epoch 00131: saving model to ../model_wehigts/8_ch.hdf5
# Epoch 132/200
# 25569/25569 [==============================] - 59s 2ms/step - loss: 0.8715 - acc: 0.0730 - f1: 0.1285 - val_loss: 0.8749 - val_acc: 0.0688 - val_f1: 0.1251
#
# Epoch 00132: val_loss did not improve from 0.87493
#
# Epoch 00132: saving model to ../model_wehigts/8_ch.hdf5
# Epoch 133/200
# 25569/25569 [==============================] - 59s 2ms/step - loss: 0.8722 - acc: 0.0732 - f1: 0.1278 - val_loss: 0.8749 - val_acc: 0.0688 - val_f1: 0.1251
#
# Epoch 00133: val_loss did not improve from 0.87493
#
# Epoch 00133: saving model to ../model_wehigts/8_ch.hdf5
# Epoch 134/200
# 25569/25569 [==============================] - 59s 2ms/step - loss: 0.8714 - acc: 0.0739 - f1: 0.1286 - val_loss: 0.8749 - val_acc: 0.0688 - val_f1: 0.1251
#
# Epoch 00134: val_loss did not improve from 0.87493
#
# Epoch 00134: saving model to ../model_wehigts/8_ch.hdf5
# Epoch 135/200
# 25569/25569 [==============================] - 59s 2ms/step - loss: 0.8718 - acc: 0.0752 - f1: 0.1282 - val_loss: 0.8749 - val_acc: 0.0688 - val_f1: 0.1251
#
# Epoch 00135: val_loss did not improve from 0.87493
#
# Epoch 00135: saving model to ../model_wehigts/8_ch.hdf5
# Epoch 136/200
# 25569/25569 [==============================] - 60s 2ms/step - loss: 0.8721 - acc: 0.0828 - f1: 0.1279 - val_loss: 0.8749 - val_acc: 0.0688 - val_f1: 0.1251
#
# Epoch 00136: val_loss did not improve from 0.87493
#
# Epoch 00136: saving model to ../model_wehigts/8_ch.hdf5
# Epoch 137/200
# 25569/25569 [==============================] - 59s 2ms/step - loss: 0.8719 - acc: 0.0729 - f1: 0.1281 - val_loss: 0.8749 - val_acc: 0.0688 - val_f1: 0.1251
#
# Epoch 00137: val_loss did not improve from 0.87493
#
# Epoch 00137: saving model to ../model_wehigts/8_ch.hdf5
# Epoch 138/200
# 25569/25569 [==============================] - 59s 2ms/step - loss: 0.8714 - acc: 0.0726 - f1: 0.1286 - val_loss: 0.8749 - val_acc: 0.0688 - val_f1: 0.1251
#
# Epoch 00138: val_loss did not improve from 0.87493
#
# Epoch 00138: saving model to ../model_wehigts/8_ch.hdf5
# Epoch 139/200
# 25569/25569 [==============================] - 59s 2ms/step - loss: 0.8717 - acc: 0.0769 - f1: 0.1283 - val_loss: 0.8749 - val_acc: 0.0688 - val_f1: 0.1251
#
# Epoch 00139: val_loss did not improve from 0.87493
#
# Epoch 00139: saving model to ../model_wehigts/8_ch.hdf5
# Epoch 140/200
# 25569/25569 [==============================] - 59s 2ms/step - loss: 0.8719 - acc: 0.0767 - f1: 0.1281 - val_loss: 0.8749 - val_acc: 0.0688 - val_f1: 0.1251
#
# Epoch 00140: val_loss did not improve from 0.87493
#
# Epoch 00140: saving model to ../model_wehigts/8_ch.hdf5
# Epoch 141/200
# 25569/25569 [==============================] - 60s 2ms/step - loss: 0.8715 - acc: 0.0804 - f1: 0.1285 - val_loss: 0.8749 - val_acc: 0.0688 - val_f1: 0.1251
#
# Epoch 00141: val_loss did not improve from 0.87493
#
# Epoch 00141: saving model to ../model_wehigts/8_ch.hdf5
# Epoch 142/200
# 25569/25569 [==============================] - 60s 2ms/step - loss: 0.8720 - acc: 0.0809 - f1: 0.1280 - val_loss: 0.8749 - val_acc: 0.0688 - val_f1: 0.1251
#
# Epoch 00142: val_loss did not improve from 0.87493
#
# Epoch 00142: saving model to ../model_wehigts/8_ch.hdf5
# Epoch 143/200
# 25569/25569 [==============================] - 60s 2ms/step - loss: 0.8723 - acc: 0.0766 - f1: 0.1277 - val_loss: 0.8749 - val_acc: 0.0688 - val_f1: 0.1251
#
# Epoch 00143: val_loss did not improve from 0.87493
#
# Epoch 00143: saving model to ../model_wehigts/8_ch.hdf5
# Epoch 144/200
# 25569/25569 [==============================] - 59s 2ms/step - loss: 0.8718 - acc: 0.0738 - f1: 0.1282 - val_loss: 0.8749 - val_acc: 0.0688 - val_f1: 0.1251
#
# Epoch 00144: val_loss did not improve from 0.87493
#
# Epoch 00144: saving model to ../model_wehigts/8_ch.hdf5
# Epoch 145/200
# 25569/25569 [==============================] - 59s 2ms/step - loss: 0.8721 - acc: 0.0740 - f1: 0.1279 - val_loss: 0.8749 - val_acc: 0.0688 - val_f1: 0.1251
#
# Epoch 00145: val_loss did not improve from 0.87493
#
# Epoch 00145: saving model to ../model_wehigts/8_ch.hdf5
# Epoch 146/200
# 25569/25569 [==============================] - 60s 2ms/step - loss: 0.8718 - acc: 0.0720 - f1: 0.1282 - val_loss: 0.8749 - val_acc: 0.0688 - val_f1: 0.1251
#
# Epoch 00146: val_loss did not improve from 0.87493
#
# Epoch 00146: saving model to ../model_wehigts/8_ch.hdf5
# Epoch 147/200
# 25569/25569 [==============================] - 60s 2ms/step - loss: 0.8715 - acc: 0.0712 - f1: 0.1285 - val_loss: 0.8749 - val_acc: 0.0688 - val_f1: 0.1251
#
# Epoch 00147: val_loss did not improve from 0.87493
#
# Epoch 00147: saving model to ../model_wehigts/8_ch.hdf5
# Epoch 148/200
# 25569/25569 [==============================] - 59s 2ms/step - loss: 0.8717 - acc: 0.0736 - f1: 0.1283 - val_loss: 0.8749 - val_acc: 0.0688 - val_f1: 0.1251
#
# Epoch 00148: val_loss did not improve from 0.87493
#
# Epoch 00148: saving model to ../model_wehigts/8_ch.hdf5
# Epoch 149/200
# 25569/25569 [==============================] - 59s 2ms/step - loss: 0.8717 - acc: 0.0742 - f1: 0.1283 - val_loss: 0.8749 - val_acc: 0.0688 - val_f1: 0.1251
#
# Epoch 00149: val_loss did not improve from 0.87493
#
# Epoch 00149: saving model to ../model_wehigts/8_ch.hdf5
# Epoch 150/200
# 25569/25569 [==============================] - 59s 2ms/step - loss: 0.8719 - acc: 0.0733 - f1: 0.1281 - val_loss: 0.8749 - val_acc: 0.0688 - val_f1: 0.1251
#
# Epoch 00150: val_loss did not improve from 0.87493
#
# Epoch 00150: saving model to ../model_wehigts/8_ch.hdf5
# Epoch 151/200
# 25569/25569 [==============================] - 60s 2ms/step - loss: 0.8717 - acc: 0.0723 - f1: 0.1283 - val_loss: 0.8749 - val_acc: 0.0688 - val_f1: 0.1251
#
# Epoch 00151: val_loss did not improve from 0.87493
#
# Epoch 00151: saving model to ../model_wehigts/8_ch.hdf5
# Epoch 152/200
# 25569/25569 [==============================] - 60s 2ms/step - loss: 0.8717 - acc: 0.0739 - f1: 0.1283 - val_loss: 0.8749 - val_acc: 0.0688 - val_f1: 0.1251
#
# Epoch 00152: val_loss did not improve from 0.87493
#
# Epoch 00152: saving model to ../model_wehigts/8_ch.hdf5
# Epoch 153/200
# 25569/25569 [==============================] - 59s 2ms/step - loss: 0.8716 - acc: 0.0740 - f1: 0.1284 - val_loss: 0.8749 - val_acc: 0.0688 - val_f1: 0.1251
#
# Epoch 00153: val_loss did not improve from 0.87493
#
# Epoch 00153: saving model to ../model_wehigts/8_ch.hdf5
# Epoch 154/200
# 25569/25569 [==============================] - 59s 2ms/step - loss: 0.8718 - acc: 0.0746 - f1: 0.1282 - val_loss: 0.8749 - val_acc: 0.0688 - val_f1: 0.1251
#
# Epoch 00154: val_loss did not improve from 0.87493
#
# Epoch 00154: saving model to ../model_wehigts/8_ch.hdf5
# Epoch 155/200
# 25569/25569 [==============================] - 59s 2ms/step - loss: 0.8719 - acc: 0.0740 - f1: 0.1281 - val_loss: 0.8749 - val_acc: 0.0688 - val_f1: 0.1251
#
# Epoch 00155: val_loss did not improve from 0.87493
#
# Epoch 00155: saving model to ../model_wehigts/8_ch.hdf5
# Epoch 156/200
# 25569/25569 [==============================] - 60s 2ms/step - loss: 0.8716 - acc: 0.0746 - f1: 0.1284 - val_loss: 0.8749 - val_acc: 0.0688 - val_f1: 0.1251
#
# Epoch 00156: val_loss did not improve from 0.87493
#
# Epoch 00156: saving model to ../model_wehigts/8_ch.hdf5
# Epoch 157/200
# 25569/25569 [==============================] - 60s 2ms/step - loss: 0.8719 - acc: 0.0745 - f1: 0.1281 - val_loss: 0.8749 - val_acc: 0.0688 - val_f1: 0.1251
#
# Epoch 00157: val_loss did not improve from 0.87493
#
# Epoch 00157: saving model to ../model_wehigts/8_ch.hdf5
# Epoch 158/200
# 25569/25569 [==============================] - 60s 2ms/step - loss: 0.8719 - acc: 0.0738 - f1: 0.1281 - val_loss: 0.8749 - val_acc: 0.0688 - val_f1: 0.1251
#
# Epoch 00158: val_loss did not improve from 0.87493
#
# Epoch 00158: saving model to ../model_wehigts/8_ch.hdf5
# Epoch 159/200
# 25569/25569 [==============================] - 59s 2ms/step - loss: 0.8718 - acc: 0.0745 - f1: 0.1282 - val_loss: 0.8749 - val_acc: 0.0688 - val_f1: 0.1251
#
# Epoch 00159: val_loss did not improve from 0.87493
#
# Epoch 00159: saving model to ../model_wehigts/8_ch.hdf5
# Epoch 160/200
# 25569/25569 [==============================] - 59s 2ms/step - loss: 0.8716 - acc: 0.0750 - f1: 0.1284 - val_loss: 0.8749 - val_acc: 0.0688 - val_f1: 0.1251
#
# Epoch 00160: val_loss did not improve from 0.87493
#
# Epoch 00160: saving model to ../model_wehigts/8_ch.hdf5
# Epoch 161/200
# 25569/25569 [==============================] - 60s 2ms/step - loss: 0.8717 - acc: 0.0756 - f1: 0.1283 - val_loss: 0.8749 - val_acc: 0.0688 - val_f1: 0.1251
#
# Epoch 00161: val_loss did not improve from 0.87493
#
# Epoch 00161: saving model to ../model_wehigts/8_ch.hdf5
# Epoch 162/200
# 25569/25569 [==============================] - 60s 2ms/step - loss: 0.8717 - acc: 0.0747 - f1: 0.1283 - val_loss: 0.8749 - val_acc: 0.0688 - val_f1: 0.1251
#
# Epoch 00162: val_loss did not improve from 0.87493
#
# Epoch 00162: saving model to ../model_wehigts/8_ch.hdf5
# Epoch 163/200
# 25569/25569 [==============================] - 59s 2ms/step - loss: 0.8720 - acc: 0.0756 - f1: 0.1280 - val_loss: 0.8749 - val_acc: 0.0688 - val_f1: 0.1251
#
# Epoch 00163: val_loss did not improve from 0.87493
#
# Epoch 00163: saving model to ../model_wehigts/8_ch.hdf5
# Epoch 164/200
# 25569/25569 [==============================] - 59s 2ms/step - loss: 0.8721 - acc: 0.0756 - f1: 0.1279 - val_loss: 0.8749 - val_acc: 0.0688 - val_f1: 0.1251
#
# Epoch 00164: val_loss did not improve from 0.87493
#
# Epoch 00164: saving model to ../model_wehigts/8_ch.hdf5
# Epoch 165/200
# 25569/25569 [==============================] - 59s 2ms/step - loss: 0.8722 - acc: 0.0753 - f1: 0.1278 - val_loss: 0.8749 - val_acc: 0.0688 - val_f1: 0.1251
#
# Epoch 00165: val_loss did not improve from 0.87493
#
# Epoch 00165: saving model to ../model_wehigts/8_ch.hdf5
# Epoch 166/200
# 25569/25569 [==============================] - 60s 2ms/step - loss: 0.8720 - acc: 0.0752 - f1: 0.1280 - val_loss: 0.8749 - val_acc: 0.0688 - val_f1: 0.1251
#
# Epoch 00166: val_loss did not improve from 0.87493
#
# Epoch 00166: saving model to ../model_wehigts/8_ch.hdf5
# Epoch 167/200
# 25569/25569 [==============================] - 60s 2ms/step - loss: 0.8716 - acc: 0.0754 - f1: 0.1284 - val_loss: 0.8749 - val_acc: 0.0688 - val_f1: 0.1251
#
# Epoch 00167: val_loss did not improve from 0.87493
#
# Epoch 00167: saving model to ../model_wehigts/8_ch.hdf5
# Epoch 168/200
# 25569/25569 [==============================] - 59s 2ms/step - loss: 0.8720 - acc: 0.0747 - f1: 0.1280 - val_loss: 0.8749 - val_acc: 0.0688 - val_f1: 0.1251
#
# Epoch 00168: val_loss did not improve from 0.87493
#
# Epoch 00168: saving model to ../model_wehigts/8_ch.hdf5
# Epoch 169/200
# 25569/25569 [==============================] - 59s 2ms/step - loss: 0.8718 - acc: 0.0752 - f1: 0.1282 - val_loss: 0.8749 - val_acc: 0.0688 - val_f1: 0.1251
#
# Epoch 00169: val_loss did not improve from 0.87493
#
# Epoch 00169: saving model to ../model_wehigts/8_ch.hdf5
# Epoch 170/200
# 25569/25569 [==============================] - 59s 2ms/step - loss: 0.8720 - acc: 0.0750 - f1: 0.1280 - val_loss: 0.8749 - val_acc: 0.0688 - val_f1: 0.1251
#
# Epoch 00170: val_loss did not improve from 0.87493
#
# Epoch 00170: saving model to ../model_wehigts/8_ch.hdf5
# Epoch 171/200
# 25569/25569 [==============================] - 60s 2ms/step - loss: 0.8715 - acc: 0.0750 - f1: 0.1285 - val_loss: 0.8749 - val_acc: 0.0688 - val_f1: 0.1251
#
# Epoch 00171: val_loss did not improve from 0.87493
#
# Epoch 00171: saving model to ../model_wehigts/8_ch.hdf5
# Epoch 172/200
# 25569/25569 [==============================] - 60s 2ms/step - loss: 0.8712 - acc: 0.0747 - f1: 0.1288 - val_loss: 0.8749 - val_acc: 0.0688 - val_f1: 0.1251
#
# Epoch 00172: val_loss did not improve from 0.87493
#
# Epoch 00172: saving model to ../model_wehigts/8_ch.hdf5
# Epoch 173/200
# 25569/25569 [==============================] - 59s 2ms/step - loss: 0.8715 - acc: 0.0749 - f1: 0.1285 - val_loss: 0.8749 - val_acc: 0.0688 - val_f1: 0.1251
#
# Epoch 00173: val_loss did not improve from 0.87493
#
# Epoch 00173: saving model to ../model_wehigts/8_ch.hdf5
# Epoch 174/200
# 25569/25569 [==============================] - 60s 2ms/step - loss: 0.8718 - acc: 0.0740 - f1: 0.1282 - val_loss: 0.8749 - val_acc: 0.0688 - val_f1: 0.1251
#
# Epoch 00174: val_loss did not improve from 0.87493
#
# Epoch 00174: saving model to ../model_wehigts/8_ch.hdf5
# Epoch 175/200
# 25569/25569 [==============================] - 60s 2ms/step - loss: 0.8715 - acc: 0.0752 - f1: 0.1285 - val_loss: 0.8749 - val_acc: 0.0688 - val_f1: 0.1251
#
# Epoch 00175: val_loss did not improve from 0.87493
#
# Epoch 00175: saving model to ../model_wehigts/8_ch.hdf5
# Epoch 176/200
# 25569/25569 [==============================] - 60s 2ms/step - loss: 0.8717 - acc: 0.0752 - f1: 0.1283 - val_loss: 0.8749 - val_acc: 0.0688 - val_f1: 0.1251
#
# Epoch 00176: val_loss did not improve from 0.87493
#
# Epoch 00176: saving model to ../model_wehigts/8_ch.hdf5
# Epoch 177/200
# 25569/25569 [==============================] - 59s 2ms/step - loss: 0.8719 - acc: 0.0752 - f1: 0.1281 - val_loss: 0.8749 - val_acc: 0.0688 - val_f1: 0.1251
#
# Epoch 00177: val_loss did not improve from 0.87493
#
# Epoch 00177: saving model to ../model_wehigts/8_ch.hdf5
# Epoch 178/200
# 25569/25569 [==============================] - 59s 2ms/step - loss: 0.8716 - acc: 0.0751 - f1: 0.1284 - val_loss: 0.8749 - val_acc: 0.0688 - val_f1: 0.1251
#
# Epoch 00178: val_loss did not improve from 0.87493
#
# Epoch 00178: saving model to ../model_wehigts/8_ch.hdf5
# Epoch 179/200
# 25569/25569 [==============================] - 61s 2ms/step - loss: 0.8715 - acc: 0.0756 - f1: 0.1285 - val_loss: 0.8749 - val_acc: 0.0688 - val_f1: 0.1251
#
# Epoch 00179: val_loss did not improve from 0.87493
#
# Epoch 00179: saving model to ../model_wehigts/8_ch.hdf5
# Epoch 180/200
# 25569/25569 [==============================] - 60s 2ms/step - loss: 0.8718 - acc: 0.0752 - f1: 0.1282 - val_loss: 0.8749 - val_acc: 0.0688 - val_f1: 0.1251
#
# Epoch 00180: val_loss did not improve from 0.87493
#
# Epoch 00180: saving model to ../model_wehigts/8_ch.hdf5
# Epoch 181/200
# 25569/25569 [==============================] - 60s 2ms/step - loss: 0.8718 - acc: 0.0745 - f1: 0.1282 - val_loss: 0.8749 - val_acc: 0.0688 - val_f1: 0.1251
#
# Epoch 00181: val_loss did not improve from 0.87493
#
# Epoch 00181: saving model to ../model_wehigts/8_ch.hdf5
# Epoch 182/200
# 25569/25569 [==============================] - 60s 2ms/step - loss: 0.8714 - acc: 0.0767 - f1: 0.1286 - val_loss: 0.8749 - val_acc: 0.0688 - val_f1: 0.1251
#
# Epoch 00182: val_loss did not improve from 0.87493
#
# Epoch 00182: saving model to ../model_wehigts/8_ch.hdf5
# Epoch 183/200
# 25569/25569 [==============================] - 60s 2ms/step - loss: 0.8722 - acc: 0.0754 - f1: 0.1278 - val_loss: 0.8749 - val_acc: 0.0688 - val_f1: 0.1251
#
# Epoch 00183: val_loss did not improve from 0.87493
#
# Epoch 00183: saving model to ../model_wehigts/8_ch.hdf5
# Epoch 184/200
# 25569/25569 [==============================] - 59s 2ms/step - loss: 0.8716 - acc: 0.0754 - f1: 0.1284 - val_loss: 0.8749 - val_acc: 0.0688 - val_f1: 0.1251
#
# Epoch 00184: val_loss did not improve from 0.87493
#
# Epoch 00184: saving model to ../model_wehigts/8_ch.hdf5
# Epoch 185/200
# 25569/25569 [==============================] - 60s 2ms/step - loss: 0.8716 - acc: 0.0742 - f1: 0.1284 - val_loss: 0.8749 - val_acc: 0.0688 - val_f1: 0.1251
#
# Epoch 00185: val_loss did not improve from 0.87493
#
# Epoch 00185: saving model to ../model_wehigts/8_ch.hdf5
# Epoch 186/200
# 25569/25569 [==============================] - 60s 2ms/step - loss: 0.8721 - acc: 0.0747 - f1: 0.1279 - val_loss: 0.8749 - val_acc: 0.0688 - val_f1: 0.1251
#
# Epoch 00186: val_loss did not improve from 0.87493
#
# Epoch 00186: saving model to ../model_wehigts/8_ch.hdf5
# Epoch 187/200
# 25569/25569 [==============================] - 59s 2ms/step - loss: 0.8717 - acc: 0.0741 - f1: 0.1283 - val_loss: 0.8749 - val_acc: 0.0688 - val_f1: 0.1251
#
# Epoch 00187: val_loss did not improve from 0.87493
#
# Epoch 00187: saving model to ../model_wehigts/8_ch.hdf5
# Epoch 188/200
# 25569/25569 [==============================] - 60s 2ms/step - loss: 0.8714 - acc: 0.0750 - f1: 0.1286 - val_loss: 0.8749 - val_acc: 0.0688 - val_f1: 0.1251
#
# Epoch 00188: val_loss did not improve from 0.87493
#
# Epoch 00188: saving model to ../model_wehigts/8_ch.hdf5
# Epoch 189/200
# 25569/25569 [==============================] - 62s 2ms/step - loss: 0.8718 - acc: 0.0753 - f1: 0.1282 - val_loss: 0.8749 - val_acc: 0.0688 - val_f1: 0.1251
#
# Epoch 00189: val_loss did not improve from 0.87493
#
# Epoch 00189: saving model to ../model_wehigts/8_ch.hdf5
# Epoch 190/200
# 25569/25569 [==============================] - 62s 2ms/step - loss: 0.8718 - acc: 0.0749 - f1: 0.1282 - val_loss: 0.8749 - val_acc: 0.0688 - val_f1: 0.1251
#
# Epoch 00190: val_loss did not improve from 0.87493
#
# Epoch 00190: saving model to ../model_wehigts/8_ch.hdf5
# Epoch 191/200
# 25569/25569 [==============================] - 61s 2ms/step - loss: 0.8717 - acc: 0.0747 - f1: 0.1283 - val_loss: 0.8749 - val_acc: 0.0688 - val_f1: 0.1251
#
# Epoch 00191: val_loss did not improve from 0.87493
#
# Epoch 00191: saving model to ../model_wehigts/8_ch.hdf5
# Epoch 192/200
# 25569/25569 [==============================] - 60s 2ms/step - loss: 0.8715 - acc: 0.0749 - f1: 0.1285 - val_loss: 0.8749 - val_acc: 0.0688 - val_f1: 0.1251
#
# Epoch 00192: val_loss did not improve from 0.87493
#
# Epoch 00192: saving model to ../model_wehigts/8_ch.hdf5
# Epoch 193/200
# 25569/25569 [==============================] - 60s 2ms/step - loss: 0.8721 - acc: 0.0742 - f1: 0.1279 - val_loss: 0.8749 - val_acc: 0.0688 - val_f1: 0.1251
#
# Epoch 00193: val_loss did not improve from 0.87493
#
# Epoch 00193: saving model to ../model_wehigts/8_ch.hdf5
# Epoch 194/200
# 25569/25569 [==============================] - 60s 2ms/step - loss: 0.8712 - acc: 0.0741 - f1: 0.1288 - val_loss: 0.8749 - val_acc: 0.0688 - val_f1: 0.1251
#
# Epoch 00194: val_loss did not improve from 0.87493
#
# Epoch 00194: saving model to ../model_wehigts/8_ch.hdf5
# Epoch 195/200
# 25569/25569 [==============================] - 60s 2ms/step - loss: 0.8714 - acc: 0.0742 - f1: 0.1286 - val_loss: 0.8749 - val_acc: 0.0688 - val_f1: 0.1251
#
# Epoch 00195: val_loss did not improve from 0.87493
#
# Epoch 00195: saving model to ../model_wehigts/8_ch.hdf5
# Epoch 196/200
# 25569/25569 [==============================] - 60s 2ms/step - loss: 0.8719 - acc: 0.0737 - f1: 0.1281 - val_loss: 0.8749 - val_acc: 0.0688 - val_f1: 0.1251
#
# Epoch 00196: val_loss did not improve from 0.87493
#
# Epoch 00196: saving model to ../model_wehigts/8_ch.hdf5
# Epoch 197/200
# 25569/25569 [==============================] - 59s 2ms/step - loss: 0.8714 - acc: 0.0748 - f1: 0.1286 - val_loss: 0.8749 - val_acc: 0.0688 - val_f1: 0.1251
#
# Epoch 00197: val_loss did not improve from 0.87493
#
# Epoch 00197: saving model to ../model_wehigts/8_ch.hdf5
# Epoch 198/200
# 25569/25569 [==============================] - 59s 2ms/step - loss: 0.8717 - acc: 0.0744 - f1: 0.1283 - val_loss: 0.8749 - val_acc: 0.0688 - val_f1: 0.1251
#
# Epoch 00198: val_loss did not improve from 0.87493
#
# Epoch 00198: saving model to ../model_wehigts/8_ch.hdf5
# Epoch 199/200
# 25569/25569 [==============================] - 59s 2ms/step - loss: 0.8722 - acc: 0.0747 - f1: 0.1278 - val_loss: 0.8749 - val_acc: 0.0688 - val_f1: 0.1251
#
# Epoch 00199: val_loss did not improve from 0.87493
#
# Epoch 00199: saving model to ../model_wehigts/8_ch.hdf5
# Epoch 200/200
# 25569/25569 [==============================] - 59s 2ms/step - loss: 0.8716 - acc: 0.0758 - f1: 0.1284 - val_loss: 0.8749 - val_acc: 0.0688 - val_f1: 0.1251
#
# Epoch 00200: val_loss did not improve from 0.87493
#
# Epoch 00200: saving model to ../model_wehigts/8_ch.hdf5

# %%
from sklearn.metrics import f1_score

#Load best model
model.load_weights(checkpoint_path)
y_pred = model.predict(x_val, batch_size=1)
y_pred = np.where(y_pred > 0.5, 1, 0)

print("Neural Network f1_sklearn: {}".format(f1_score(y_val, y_pred)))
# Out:
# Neural Network f1_sklearn: 0.12878677008634565
