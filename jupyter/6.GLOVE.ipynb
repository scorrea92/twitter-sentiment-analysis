# %% [markdown]
# # Train Numberbatch or Glove

# %%
import numpy as np
import pandas as pd 
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.layers import (
    Dense,
    Input,
    LSTM,
    Embedding,
    Dropout,
    Activation,
    SpatialDropout1D
)
from tensorflow.keras.models import Model, load_model
from tensorflow.keras.callbacks import ModelCheckpoint
from ast import literal_eval
from sklearn.model_selection import train_test_split
# Out:
# /Users/sebastiancorrea/anaconda3/lib/python3.6/importlib/_bootstrap.py:219: RuntimeWarning: compiletime version 3.5 of module 'tensorflow.python.framework.fast_tensor_util' does not match runtime version 3.6
#   return f(*args, **kwds)

# %%
df = pd.read_csv('../data/pandas_data_frame.csv', index_col=0)
all_data = df.where((pd.notnull(df)), '')
all_data['hashtag'] = all_data['hashtag'].apply(literal_eval)

full_text = all_data['tidy_tweet'][(all_data['label']=='1.0') | (all_data['label']=='0.0')]
y = all_data['label'][(all_data['label']=='1.0') | (all_data['label']=='0.0')]

# %%
tk = Tokenizer(lower=True, filters='')
tk.fit_on_texts(full_text)

train_tokenized = tk.texts_to_sequences(full_text)
max_len = 120
X = pad_sequences(train_tokenized, maxlen=max_len)

x_train, x_val, y_train, y_val = train_test_split(X, y, random_state=1992, test_size=0.2)

print(x_train.shape,y_train.shape)
print(x_val.shape,y_val.shape)
# Out:
# (25569, 120) (25569,)
# (6393, 120) (6393,)

# %%
import pickle

# saving
with open('../model_wehigts/tokenizer.pickle', 'wb') as handle:
    pickle.dump(tk, handle, protocol=pickle.HIGHEST_PROTOCOL)

# # loading
# with open('tokenizer.pickle', 'rb') as handle:
#     tokenizer = pickle.load(handle)

# %%
embedding_path = '../data/vectors/glove.twitter.27B/glove.twitter.27B.200d.txt'
embed_size = 200

max_features = 30000

def get_coefs(word,*arr):
    return word, np.asarray(arr, dtype='float32')

embedding_index = dict(get_coefs(*o.strip().split(" ")) for o in open(embedding_path))

# %%
word_index = tk.word_index
nb_words = min(max_features, len(word_index))
embedding_matrix = np.zeros((nb_words + 1, embed_size))

for word, i in word_index.items():
    if i >= max_features: continue
    embedding_vector = embedding_index.get(word)
    if embedding_vector is not None: embedding_matrix[i] = embedding_vector

# %%
import sys
sys.path.append("../") 
from personal_library.sce_keras.loss_functions import f1_loss
from personal_library.sce_keras.metrics_functions import f1
from personal_library.sce_keras.callbacks import WarmUpCosineDecayScheduler


num_classes = 1
batch_size = 32
epochs = 200
learnRate = 0.001
lstm_out = 200
warmup_epoch = 20

warm_up_lr = WarmUpCosineDecayScheduler(learning_rate_base=learnRate,
                                        warmup_learning_rate=0,
                                        warmup_epoch=warmup_epoch,
                                        hold_base_rate_steps=5,
                                        verbose=0)

checkpoint_path = "../model_wehigts/6_w.hdf5"
checkpoint_path1 = "../model_wehigts/6_ch.hdf5"
checkpointer = ModelCheckpoint(filepath=checkpoint_path,
                               monitor='val_loss', verbose=2,
                               save_best_only=True, mode='min')
checkpointer1 = ModelCheckpoint(filepath=checkpoint_path1,
                               monitor='val_loss', verbose=2,
                               save_best_only=False, mode='min')

inp = Input(shape = (max_len,))
x = Embedding(nb_words+1, embed_size, weights = [embedding_matrix], trainable=False)(inp)
x = SpatialDropout1D(0.3)(x)
x = LSTM(lstm_out, dropout=0.5, recurrent_dropout=0.5)(x)
x = Dense(1, activation = "sigmoid")(x)

model = Model(inputs=inp, outputs=x)
model.summary()

# 'binary_crossentropy'
model.compile(loss=f1_loss, 
              optimizer='adam', 
              metrics=['accuracy', f1]) 

history = model.fit(x_train, y_train, 
                    batch_size=batch_size,
                    epochs=epochs,
                    verbose=1,
                    validation_data=(x_val, y_val),
                    callbacks=[checkpointer, checkpointer1, warm_up_lr])
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, 120)               0
# _________________________________________________________________
# embedding (Embedding)        (None, 120, 200)          3992000
# _________________________________________________________________
# spatial_dropout1d (SpatialDr (None, 120, 200)          0
# _________________________________________________________________
# lstm (LSTM)                  (None, 200)               320800
# _________________________________________________________________
# dense (Dense)                (None, 1)                 201
# =================================================================
# Total params: 4,313,001
# Trainable params: 321,001
# Non-trainable params: 3,992,000
# _________________________________________________________________
# Train on 25569 samples, validate on 6393 samples
# Epoch 1/200
# 25569/25569 [==============================] - 335s 13ms/step - loss: 0.8782 - acc: 0.5022 - f1: 0.1218 - val_loss: 0.8639 - val_acc: 0.2978 - val_f1: 0.1361
#
# Epoch 00001: val_loss improved from inf to 0.86393, saving model to ../model_wehigts/6_w.hdf5
#
# Epoch 00001: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 2/200
# 25569/25569 [==============================] - 336s 13ms/step - loss: 0.8145 - acc: 0.7024 - f1: 0.1855 - val_loss: 0.7156 - val_acc: 0.8807 - val_f1: 0.2844
#
# Epoch 00002: val_loss improved from 0.86393 to 0.71561, saving model to ../model_wehigts/6_w.hdf5
#
# Epoch 00002: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 3/200
# 25569/25569 [==============================] - 341s 13ms/step - loss: 0.7115 - acc: 0.8819 - f1: 0.2885 - val_loss: 0.6633 - val_acc: 0.9069 - val_f1: 0.3367
#
# Epoch 00003: val_loss improved from 0.71561 to 0.66334, saving model to ../model_wehigts/6_w.hdf5
#
# Epoch 00003: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 4/200
# 25569/25569 [==============================] - 372s 15ms/step - loss: 0.6862 - acc: 0.8885 - f1: 0.3138 - val_loss: 0.6368 - val_acc: 0.9033 - val_f1: 0.3632
#
# Epoch 00004: val_loss improved from 0.66334 to 0.63681, saving model to ../model_wehigts/6_w.hdf5
#
# Epoch 00004: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 5/200
# 25569/25569 [==============================] - 490s 19ms/step - loss: 0.6731 - acc: 0.8972 - f1: 0.3269 - val_loss: 0.6211 - val_acc: 0.9038 - val_f1: 0.3789
#
# Epoch 00005: val_loss improved from 0.63681 to 0.62110, saving model to ../model_wehigts/6_w.hdf5
#
# Epoch 00005: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 6/200
# 25569/25569 [==============================] - 501s 20ms/step - loss: 0.6607 - acc: 0.8907 - f1: 0.3393 - val_loss: 0.6330 - val_acc: 0.9241 - val_f1: 0.3670
#
# Epoch 00006: val_loss did not improve from 0.62110
#
# Epoch 00006: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 7/200
# 25569/25569 [==============================] - 410s 16ms/step - loss: 0.6518 - acc: 0.9018 - f1: 0.3482 - val_loss: 0.6142 - val_acc: 0.9209 - val_f1: 0.3858
#
# Epoch 00007: val_loss improved from 0.62110 to 0.61423, saving model to ../model_wehigts/6_w.hdf5
#
# Epoch 00007: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 8/200
# 25569/25569 [==============================] - 350s 14ms/step - loss: 0.6331 - acc: 0.9052 - f1: 0.3669 - val_loss: 0.6060 - val_acc: 0.9221 - val_f1: 0.3940
#
# Epoch 00008: val_loss improved from 0.61423 to 0.60600, saving model to ../model_wehigts/6_w.hdf5
#
# Epoch 00008: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 9/200
# 25569/25569 [==============================] - 307s 12ms/step - loss: 0.6480 - acc: 0.8958 - f1: 0.3520 - val_loss: 0.6164 - val_acc: 0.9133 - val_f1: 0.3836
#
# Epoch 00009: val_loss did not improve from 0.60600
#
# Epoch 00009: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 10/200
# 25569/25569 [==============================] - 290s 11ms/step - loss: 0.6318 - acc: 0.9038 - f1: 0.3682 - val_loss: 0.6003 - val_acc: 0.9146 - val_f1: 0.3997
#
# Epoch 00010: val_loss improved from 0.60600 to 0.60028, saving model to ../model_wehigts/6_w.hdf5
#
# Epoch 00010: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 11/200
# 25569/25569 [==============================] - 289s 11ms/step - loss: 0.6367 - acc: 0.9111 - f1: 0.3633 - val_loss: 0.6457 - val_acc: 0.9338 - val_f1: 0.3543
#
# Epoch 00011: val_loss did not improve from 0.60028
#
# Epoch 00011: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 12/200
# 25569/25569 [==============================] - 290s 11ms/step - loss: 0.6395 - acc: 0.9018 - f1: 0.3605 - val_loss: 0.6225 - val_acc: 0.9187 - val_f1: 0.3775
#
# Epoch 00012: val_loss did not improve from 0.60028
#
# Epoch 00012: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 13/200
# 25569/25569 [==============================] - 287s 11ms/step - loss: 0.6308 - acc: 0.9057 - f1: 0.3692 - val_loss: 0.6152 - val_acc: 0.8825 - val_f1: 0.3848
#
# Epoch 00013: val_loss did not improve from 0.60028
#
# Epoch 00013: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 14/200
# 25569/25569 [==============================] - 285s 11ms/step - loss: 0.6165 - acc: 0.8997 - f1: 0.3835 - val_loss: 0.6026 - val_acc: 0.9082 - val_f1: 0.3974
#
# Epoch 00014: val_loss did not improve from 0.60028
#
# Epoch 00014: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 15/200
# 25569/25569 [==============================] - 286s 11ms/step - loss: 0.6163 - acc: 0.9090 - f1: 0.3837 - val_loss: 0.6160 - val_acc: 0.9215 - val_f1: 0.3840
#
# Epoch 00015: val_loss did not improve from 0.60028
#
# Epoch 00015: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 16/200
# 25569/25569 [==============================] - 285s 11ms/step - loss: 0.6174 - acc: 0.9153 - f1: 0.3826 - val_loss: 0.6022 - val_acc: 0.8986 - val_f1: 0.3978
#
# Epoch 00016: val_loss did not improve from 0.60028
#
# Epoch 00016: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 17/200
# 25569/25569 [==============================] - 285s 11ms/step - loss: 0.6241 - acc: 0.8957 - f1: 0.3759 - val_loss: 0.6053 - val_acc: 0.9148 - val_f1: 0.3947
#
# Epoch 00017: val_loss did not improve from 0.60028
#
# Epoch 00017: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 18/200
# 25569/25569 [==============================] - 333s 13ms/step - loss: 0.6113 - acc: 0.9194 - f1: 0.3887 - val_loss: 0.6040 - val_acc: 0.9171 - val_f1: 0.3960
#
# Epoch 00018: val_loss did not improve from 0.60028
#
# Epoch 00018: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 19/200
# 25569/25569 [==============================] - 331s 13ms/step - loss: 0.5969 - acc: 0.9171 - f1: 0.4031 - val_loss: 0.6007 - val_acc: 0.9060 - val_f1: 0.3993
#
# Epoch 00019: val_loss did not improve from 0.60028
#
# Epoch 00019: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 20/200
# 25569/25569 [==============================] - 317s 12ms/step - loss: 0.6068 - acc: 0.9084 - f1: 0.3932 - val_loss: 0.5922 - val_acc: 0.9190 - val_f1: 0.4078
#
# Epoch 00020: val_loss improved from 0.60028 to 0.59220, saving model to ../model_wehigts/6_w.hdf5
#
# Epoch 00020: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 21/200
# 25569/25569 [==============================] - 315s 12ms/step - loss: 0.6099 - acc: 0.9084 - f1: 0.3901 - val_loss: 0.5910 - val_acc: 0.9133 - val_f1: 0.4090
#
# Epoch 00021: val_loss improved from 0.59220 to 0.59100, saving model to ../model_wehigts/6_w.hdf5
#
# Epoch 00021: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 22/200
# 25569/25569 [==============================] - 312s 12ms/step - loss: 0.5999 - acc: 0.9173 - f1: 0.4001 - val_loss: 0.5911 - val_acc: 0.9207 - val_f1: 0.4089
#
# Epoch 00022: val_loss did not improve from 0.59100
#
# Epoch 00022: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 23/200
# 25569/25569 [==============================] - 314s 12ms/step - loss: 0.5964 - acc: 0.9113 - f1: 0.4036 - val_loss: 0.6084 - val_acc: 0.9296 - val_f1: 0.3916
#
# Epoch 00023: val_loss did not improve from 0.59100
#
# Epoch 00023: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 24/200
# 25569/25569 [==============================] - 318s 12ms/step - loss: 0.5932 - acc: 0.9201 - f1: 0.4068 - val_loss: 0.5889 - val_acc: 0.9137 - val_f1: 0.4111
#
# Epoch 00024: val_loss improved from 0.59100 to 0.58893, saving model to ../model_wehigts/6_w.hdf5
#
# Epoch 00024: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 25/200
# 25569/25569 [==============================] - 316s 12ms/step - loss: 0.5968 - acc: 0.9225 - f1: 0.4032 - val_loss: 0.6085 - val_acc: 0.9213 - val_f1: 0.3915
#
# Epoch 00025: val_loss did not improve from 0.58893
#
# Epoch 00025: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 26/200
# 25569/25569 [==============================] - 322s 13ms/step - loss: 0.5844 - acc: 0.9262 - f1: 0.4156 - val_loss: 0.5968 - val_acc: 0.9196 - val_f1: 0.4032
#
# Epoch 00026: val_loss did not improve from 0.58893
#
# Epoch 00026: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 27/200
# 25569/25569 [==============================] - 313s 12ms/step - loss: 0.5918 - acc: 0.9165 - f1: 0.4082 - val_loss: 0.6094 - val_acc: 0.9359 - val_f1: 0.3906
#
# Epoch 00027: val_loss did not improve from 0.58893
#
# Epoch 00027: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 28/200
# 25569/25569 [==============================] - 331s 13ms/step - loss: 0.5705 - acc: 0.9214 - f1: 0.4295 - val_loss: 0.5964 - val_acc: 0.9112 - val_f1: 0.4036
#
# Epoch 00028: val_loss did not improve from 0.58893
#
# Epoch 00028: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 29/200
# 25569/25569 [==============================] - 341s 13ms/step - loss: 0.5955 - acc: 0.9146 - f1: 0.4045 - val_loss: 0.5805 - val_acc: 0.9015 - val_f1: 0.4195
#
# Epoch 00029: val_loss improved from 0.58893 to 0.58052, saving model to ../model_wehigts/6_w.hdf5
#
# Epoch 00029: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 30/200
# 25569/25569 [==============================] - 322s 13ms/step - loss: 0.5907 - acc: 0.9162 - f1: 0.4093 - val_loss: 0.5871 - val_acc: 0.9052 - val_f1: 0.4129
#
# Epoch 00030: val_loss did not improve from 0.58052
#
# Epoch 00030: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 31/200
# 25569/25569 [==============================] - 321s 13ms/step - loss: 0.5877 - acc: 0.9245 - f1: 0.4123 - val_loss: 0.5898 - val_acc: 0.9188 - val_f1: 0.4102
#
# Epoch 00031: val_loss did not improve from 0.58052
#
# Epoch 00031: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 32/200
# 25569/25569 [==============================] - 352s 14ms/step - loss: 0.5660 - acc: 0.9280 - f1: 0.4340 - val_loss: 0.5898 - val_acc: 0.9277 - val_f1: 0.4102
#
# Epoch 00032: val_loss did not improve from 0.58052
#
# Epoch 00032: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 33/200
# 25569/25569 [==============================] - 330s 13ms/step - loss: 0.5805 - acc: 0.9260 - f1: 0.4195 - val_loss: 0.5962 - val_acc: 0.9263 - val_f1: 0.4038
#
# Epoch 00033: val_loss did not improve from 0.58052
#
# Epoch 00033: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 34/200
# 25569/25569 [==============================] - 333s 13ms/step - loss: 0.5813 - acc: 0.9230 - f1: 0.4187 - val_loss: 0.6086 - val_acc: 0.9340 - val_f1: 0.3914
#
# Epoch 00034: val_loss did not improve from 0.58052
#
# Epoch 00034: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 35/200
# 25569/25569 [==============================] - 319s 12ms/step - loss: 0.5737 - acc: 0.9285 - f1: 0.4263 - val_loss: 0.5892 - val_acc: 0.9227 - val_f1: 0.4108
#
# Epoch 00035: val_loss did not improve from 0.58052
#
# Epoch 00035: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 36/200
# 25569/25569 [==============================] - 319s 12ms/step - loss: 0.5704 - acc: 0.9236 - f1: 0.4296 - val_loss: 0.6079 - val_acc: 0.9215 - val_f1: 0.3921
#
# Epoch 00036: val_loss did not improve from 0.58052
#
# Epoch 00036: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 37/200
# 25569/25569 [==============================] - 376s 15ms/step - loss: 0.5930 - acc: 0.9218 - f1: 0.4070 - val_loss: 0.5902 - val_acc: 0.9266 - val_f1: 0.4098
#
# Epoch 00037: val_loss did not improve from 0.58052
#
# Epoch 00037: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 38/200
# 25569/25569 [==============================] - 293s 11ms/step - loss: 0.5876 - acc: 0.9190 - f1: 0.4124 - val_loss: 0.5880 - val_acc: 0.9338 - val_f1: 0.4120
#
# Epoch 00038: val_loss did not improve from 0.58052
#
# Epoch 00038: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 39/200
# 25569/25569 [==============================] - 292s 11ms/step - loss: 0.5769 - acc: 0.9307 - f1: 0.4231 - val_loss: 0.5974 - val_acc: 0.9284 - val_f1: 0.4026
#
# Epoch 00039: val_loss did not improve from 0.58052
#
# Epoch 00039: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 40/200
# 25569/25569 [==============================] - 303s 12ms/step - loss: 0.5951 - acc: 0.9197 - f1: 0.4049 - val_loss: 0.5912 - val_acc: 0.9296 - val_f1: 0.4088
#
# Epoch 00040: val_loss did not improve from 0.58052
#
# Epoch 00040: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 41/200
# 25569/25569 [==============================] - 332s 13ms/step - loss: 0.5871 - acc: 0.9233 - f1: 0.4129 - val_loss: 0.6037 - val_acc: 0.9318 - val_f1: 0.3963
#
# Epoch 00041: val_loss did not improve from 0.58052
#
# Epoch 00041: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 42/200
# 25569/25569 [==============================] - 293s 11ms/step - loss: 0.5930 - acc: 0.9262 - f1: 0.4070 - val_loss: 0.5928 - val_acc: 0.9365 - val_f1: 0.4072
#
# Epoch 00042: val_loss did not improve from 0.58052
#
# Epoch 00042: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 43/200
# 25569/25569 [==============================] - 292s 11ms/step - loss: 0.5790 - acc: 0.9252 - f1: 0.4210 - val_loss: 0.6048 - val_acc: 0.8963 - val_f1: 0.3952
#
# Epoch 00043: val_loss did not improve from 0.58052
#
# Epoch 00043: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 44/200
# 25569/25569 [==============================] - 292s 11ms/step - loss: 0.5755 - acc: 0.9251 - f1: 0.4245 - val_loss: 0.5857 - val_acc: 0.9176 - val_f1: 0.4143
#
# Epoch 00044: val_loss did not improve from 0.58052
#
# Epoch 00044: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 45/200
# 25569/25569 [==============================] - 289s 11ms/step - loss: 0.5706 - acc: 0.9278 - f1: 0.4294 - val_loss: 0.5836 - val_acc: 0.9257 - val_f1: 0.4164
#
# Epoch 00045: val_loss did not improve from 0.58052
#
# Epoch 00045: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 46/200
# 25569/25569 [==============================] - 286s 11ms/step - loss: 0.6058 - acc: 0.8946 - f1: 0.3942 - val_loss: 0.5792 - val_acc: 0.9331 - val_f1: 0.4208
#
# Epoch 00046: val_loss improved from 0.58052 to 0.57917, saving model to ../model_wehigts/6_w.hdf5
#
# Epoch 00046: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 47/200
# 25569/25569 [==============================] - 285s 11ms/step - loss: 0.5766 - acc: 0.9253 - f1: 0.4234 - val_loss: 0.5815 - val_acc: 0.9248 - val_f1: 0.4185
#
# Epoch 00047: val_loss did not improve from 0.57917
#
# Epoch 00047: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 48/200
# 25569/25569 [==============================] - 285s 11ms/step - loss: 0.5660 - acc: 0.9250 - f1: 0.4340 - val_loss: 0.5791 - val_acc: 0.9290 - val_f1: 0.4209
#
# Epoch 00048: val_loss improved from 0.57917 to 0.57908, saving model to ../model_wehigts/6_w.hdf5
#
# Epoch 00048: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 49/200
# 25569/25569 [==============================] - 285s 11ms/step - loss: 0.5666 - acc: 0.9215 - f1: 0.4334 - val_loss: 0.5725 - val_acc: 0.9273 - val_f1: 0.4275
#
# Epoch 00049: val_loss improved from 0.57908 to 0.57251, saving model to ../model_wehigts/6_w.hdf5
#
# Epoch 00049: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 50/200
# 25569/25569 [==============================] - 285s 11ms/step - loss: 0.5602 - acc: 0.9275 - f1: 0.4398 - val_loss: 0.5823 - val_acc: 0.9229 - val_f1: 0.4177
#
# Epoch 00050: val_loss did not improve from 0.57251
#
# Epoch 00050: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 51/200
# 25569/25569 [==============================] - 286s 11ms/step - loss: 0.5626 - acc: 0.9273 - f1: 0.4374 - val_loss: 0.5868 - val_acc: 0.9124 - val_f1: 0.4132
#
# Epoch 00051: val_loss did not improve from 0.57251
#
# Epoch 00051: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 52/200
# 25569/25569 [==============================] - 285s 11ms/step - loss: 0.5610 - acc: 0.9303 - f1: 0.4390 - val_loss: 0.5904 - val_acc: 0.9173 - val_f1: 0.4096
#
# Epoch 00052: val_loss did not improve from 0.57251
#
# Epoch 00052: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 53/200
# 25569/25569 [==============================] - 285s 11ms/step - loss: 0.5735 - acc: 0.9255 - f1: 0.4265 - val_loss: 0.5811 - val_acc: 0.9152 - val_f1: 0.4189
#
# Epoch 00053: val_loss did not improve from 0.57251
#
# Epoch 00053: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 54/200
# 25569/25569 [==============================] - 285s 11ms/step - loss: 0.5843 - acc: 0.9231 - f1: 0.4157 - val_loss: 0.5939 - val_acc: 0.9179 - val_f1: 0.4061
#
# Epoch 00054: val_loss did not improve from 0.57251
#
# Epoch 00054: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 55/200
# 25569/25569 [==============================] - 286s 11ms/step - loss: 0.5695 - acc: 0.9257 - f1: 0.4305 - val_loss: 0.5900 - val_acc: 0.9271 - val_f1: 0.4100
#
# Epoch 00055: val_loss did not improve from 0.57251
#
# Epoch 00055: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 56/200
# 25569/25569 [==============================] - 285s 11ms/step - loss: 0.5541 - acc: 0.9285 - f1: 0.4459 - val_loss: 0.5810 - val_acc: 0.9331 - val_f1: 0.4190
#
# Epoch 00056: val_loss did not improve from 0.57251
#
# Epoch 00056: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 57/200
# 25569/25569 [==============================] - 285s 11ms/step - loss: 0.5703 - acc: 0.9250 - f1: 0.4297 - val_loss: 0.5814 - val_acc: 0.9235 - val_f1: 0.4186
#
# Epoch 00057: val_loss did not improve from 0.57251
#
# Epoch 00057: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 58/200
# 25569/25569 [==============================] - 285s 11ms/step - loss: 0.5628 - acc: 0.9296 - f1: 0.4372 - val_loss: 0.5816 - val_acc: 0.9282 - val_f1: 0.4184
#
# Epoch 00058: val_loss did not improve from 0.57251
#
# Epoch 00058: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 59/200
# 25569/25569 [==============================] - 285s 11ms/step - loss: 0.5719 - acc: 0.9279 - f1: 0.4281 - val_loss: 0.5755 - val_acc: 0.9282 - val_f1: 0.4245
#
# Epoch 00059: val_loss did not improve from 0.57251
#
# Epoch 00059: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 60/200
# 25569/25569 [==============================] - 285s 11ms/step - loss: 0.5607 - acc: 0.9301 - f1: 0.4393 - val_loss: 0.5751 - val_acc: 0.9243 - val_f1: 0.4249
#
# Epoch 00060: val_loss did not improve from 0.57251
#
# Epoch 00060: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 61/200
# 25569/25569 [==============================] - 285s 11ms/step - loss: 0.5451 - acc: 0.9258 - f1: 0.4549 - val_loss: 0.5755 - val_acc: 0.9152 - val_f1: 0.4245
#
# Epoch 00061: val_loss did not improve from 0.57251
#
# Epoch 00061: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 62/200
# 25569/25569 [==============================] - 285s 11ms/step - loss: 0.5414 - acc: 0.9327 - f1: 0.4586 - val_loss: 0.5715 - val_acc: 0.9276 - val_f1: 0.4285
#
# Epoch 00062: val_loss improved from 0.57251 to 0.57151, saving model to ../model_wehigts/6_w.hdf5
#
# Epoch 00062: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 63/200
# 25569/25569 [==============================] - 285s 11ms/step - loss: 0.5416 - acc: 0.9311 - f1: 0.4584 - val_loss: 0.5889 - val_acc: 0.9096 - val_f1: 0.4111
#
# Epoch 00063: val_loss did not improve from 0.57151
#
# Epoch 00063: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 64/200
# 25569/25569 [==============================] - 286s 11ms/step - loss: 0.5410 - acc: 0.9268 - f1: 0.4590 - val_loss: 0.5816 - val_acc: 0.9177 - val_f1: 0.4184
#
# Epoch 00064: val_loss did not improve from 0.57151
#
# Epoch 00064: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 65/200
# 25569/25569 [==============================] - 286s 11ms/step - loss: 0.5380 - acc: 0.9288 - f1: 0.4620 - val_loss: 0.5836 - val_acc: 0.9141 - val_f1: 0.4164
#
# Epoch 00065: val_loss did not improve from 0.57151
#
# Epoch 00065: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 66/200
# 25569/25569 [==============================] - 286s 11ms/step - loss: 0.5398 - acc: 0.9319 - f1: 0.4602 - val_loss: 0.5756 - val_acc: 0.9309 - val_f1: 0.4244
#
# Epoch 00066: val_loss did not improve from 0.57151
#
# Epoch 00066: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 67/200
# 25569/25569 [==============================] - 286s 11ms/step - loss: 0.5531 - acc: 0.9325 - f1: 0.4469 - val_loss: 0.5625 - val_acc: 0.9254 - val_f1: 0.4375
#
# Epoch 00067: val_loss improved from 0.57151 to 0.56250, saving model to ../model_wehigts/6_w.hdf5
#
# Epoch 00067: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 68/200
# 25569/25569 [==============================] - 286s 11ms/step - loss: 0.5515 - acc: 0.9317 - f1: 0.4485 - val_loss: 0.5742 - val_acc: 0.9215 - val_f1: 0.4258
#
# Epoch 00068: val_loss did not improve from 0.56250
#
# Epoch 00068: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 69/200
# 25569/25569 [==============================] - 286s 11ms/step - loss: 0.5319 - acc: 0.9355 - f1: 0.4681 - val_loss: 0.5783 - val_acc: 0.9229 - val_f1: 0.4217
#
# Epoch 00069: val_loss did not improve from 0.56250
#
# Epoch 00069: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 70/200
# 25569/25569 [==============================] - 285s 11ms/step - loss: 0.5383 - acc: 0.9348 - f1: 0.4617 - val_loss: 0.5733 - val_acc: 0.9216 - val_f1: 0.4267
#
# Epoch 00070: val_loss did not improve from 0.56250
#
# Epoch 00070: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 71/200
# 25569/25569 [==============================] - 285s 11ms/step - loss: 0.5422 - acc: 0.9298 - f1: 0.4578 - val_loss: 0.5706 - val_acc: 0.9227 - val_f1: 0.4294
#
# Epoch 00071: val_loss did not improve from 0.56250
#
# Epoch 00071: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 72/200
# 25569/25569 [==============================] - 286s 11ms/step - loss: 0.5391 - acc: 0.9308 - f1: 0.4609 - val_loss: 0.5720 - val_acc: 0.9207 - val_f1: 0.4280
#
# Epoch 00072: val_loss did not improve from 0.56250
#
# Epoch 00072: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 73/200
# 25569/25569 [==============================] - 285s 11ms/step - loss: 0.5374 - acc: 0.9310 - f1: 0.4626 - val_loss: 0.5679 - val_acc: 0.9194 - val_f1: 0.4321
#
# Epoch 00073: val_loss did not improve from 0.56250
#
# Epoch 00073: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 74/200
# 25569/25569 [==============================] - 285s 11ms/step - loss: 0.5454 - acc: 0.9324 - f1: 0.4546 - val_loss: 0.5758 - val_acc: 0.9235 - val_f1: 0.4242
#
# Epoch 00074: val_loss did not improve from 0.56250
#
# Epoch 00074: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 75/200
# 25569/25569 [==============================] - 285s 11ms/step - loss: 0.5763 - acc: 0.9105 - f1: 0.4237 - val_loss: 0.5843 - val_acc: 0.9155 - val_f1: 0.4157
#
# Epoch 00075: val_loss did not improve from 0.56250
#
# Epoch 00075: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 76/200
# 25569/25569 [==============================] - 286s 11ms/step - loss: 0.7138 - acc: 0.7991 - f1: 0.2862 - val_loss: 0.5864 - val_acc: 0.9354 - val_f1: 0.4136
#
# Epoch 00076: val_loss did not improve from 0.56250
#
# Epoch 00076: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 77/200
# 25569/25569 [==============================] - 287s 11ms/step - loss: 0.7940 - acc: 0.6214 - f1: 0.2060 - val_loss: 0.8729 - val_acc: 0.0862 - val_f1: 0.1271
#
# Epoch 00077: val_loss did not improve from 0.56250
#
# Epoch 00077: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 78/200
# 25569/25569 [==============================] - 285s 11ms/step - loss: 0.8355 - acc: 0.4080 - f1: 0.1645 - val_loss: 0.8531 - val_acc: 0.3571 - val_f1: 0.1469
#
# Epoch 00078: val_loss did not improve from 0.56250
#
# Epoch 00078: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 79/200
# 25569/25569 [==============================] - 287s 11ms/step - loss: 0.8382 - acc: 0.4081 - f1: 0.1618 - val_loss: 0.8176 - val_acc: 0.4721 - val_f1: 0.1824
#
# Epoch 00079: val_loss did not improve from 0.56250
#
# Epoch 00079: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 80/200
# 25569/25569 [==============================] - 286s 11ms/step - loss: 0.8252 - acc: 0.5188 - f1: 0.1748 - val_loss: 0.6695 - val_acc: 0.9032 - val_f1: 0.3305
#
# Epoch 00080: val_loss did not improve from 0.56250
#
# Epoch 00080: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 81/200
# 25569/25569 [==============================] - 286s 11ms/step - loss: 0.7773 - acc: 0.7307 - f1: 0.2227 - val_loss: 0.6156 - val_acc: 0.9140 - val_f1: 0.3844
#
# Epoch 00081: val_loss did not improve from 0.56250
#
# Epoch 00081: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 82/200
# 25569/25569 [==============================] - 286s 11ms/step - loss: 0.7660 - acc: 0.7756 - f1: 0.2340 - val_loss: 0.6431 - val_acc: 0.9215 - val_f1: 0.3569
#
# Epoch 00082: val_loss did not improve from 0.56250
#
# Epoch 00082: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 83/200
# 25569/25569 [==============================] - 286s 11ms/step - loss: 0.7315 - acc: 0.8313 - f1: 0.2685 - val_loss: 0.7775 - val_acc: 0.9324 - val_f1: 0.2225
#
# Epoch 00083: val_loss did not improve from 0.56250
#
# Epoch 00083: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 84/200
# 25569/25569 [==============================] - 286s 11ms/step - loss: 0.7310 - acc: 0.8440 - f1: 0.2690 - val_loss: 0.6432 - val_acc: 0.8838 - val_f1: 0.3568
#
# Epoch 00084: val_loss did not improve from 0.56250
#
# Epoch 00084: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 85/200
# 25569/25569 [==============================] - 286s 11ms/step - loss: 0.7251 - acc: 0.8343 - f1: 0.2749 - val_loss: 0.6958 - val_acc: 0.9199 - val_f1: 0.3042
#
# Epoch 00085: val_loss did not improve from 0.56250
#
# Epoch 00085: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 86/200
# 25569/25569 [==============================] - 286s 11ms/step - loss: 0.7169 - acc: 0.8630 - f1: 0.2831 - val_loss: 0.6512 - val_acc: 0.9237 - val_f1: 0.3488
#
# Epoch 00086: val_loss did not improve from 0.56250
#
# Epoch 00086: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 87/200
# 25569/25569 [==============================] - 286s 11ms/step - loss: 0.6957 - acc: 0.8691 - f1: 0.3043 - val_loss: 0.8421 - val_acc: 0.3177 - val_f1: 0.1579
#
# Epoch 00087: val_loss did not improve from 0.56250
#
# Epoch 00087: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 88/200
# 25569/25569 [==============================] - 287s 11ms/step - loss: 0.6948 - acc: 0.8730 - f1: 0.3052 - val_loss: 0.6509 - val_acc: 0.8589 - val_f1: 0.3491
#
# Epoch 00088: val_loss did not improve from 0.56250
#
# Epoch 00088: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 89/200
# 25569/25569 [==============================] - 286s 11ms/step - loss: 0.6870 - acc: 0.8849 - f1: 0.3130 - val_loss: 0.6763 - val_acc: 0.8431 - val_f1: 0.3237
#
# Epoch 00089: val_loss did not improve from 0.56250
#
# Epoch 00089: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 90/200
# 25569/25569 [==============================] - 288s 11ms/step - loss: 0.6816 - acc: 0.8873 - f1: 0.3184 - val_loss: 0.6348 - val_acc: 0.8713 - val_f1: 0.3652
#
# Epoch 00090: val_loss did not improve from 0.56250
#
# Epoch 00090: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 91/200
# 25569/25569 [==============================] - 286s 11ms/step - loss: 0.6779 - acc: 0.8925 - f1: 0.3221 - val_loss: 0.5954 - val_acc: 0.9099 - val_f1: 0.4046
#
# Epoch 00091: val_loss did not improve from 0.56250
#
# Epoch 00091: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 92/200
# 25569/25569 [==============================] - 287s 11ms/step - loss: 0.6739 - acc: 0.8903 - f1: 0.3261 - val_loss: 0.6532 - val_acc: 0.9291 - val_f1: 0.3468
#
# Epoch 00092: val_loss did not improve from 0.56250
#
# Epoch 00092: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 93/200
# 25569/25569 [==============================] - 286s 11ms/step - loss: 0.6753 - acc: 0.8899 - f1: 0.3247 - val_loss: 0.6172 - val_acc: 0.9061 - val_f1: 0.3828
#
# Epoch 00093: val_loss did not improve from 0.56250
#
# Epoch 00093: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 94/200
# 25569/25569 [==============================] - 287s 11ms/step - loss: 0.6628 - acc: 0.9000 - f1: 0.3372 - val_loss: 0.6143 - val_acc: 0.9119 - val_f1: 0.3857
#
# Epoch 00094: val_loss did not improve from 0.56250
#
# Epoch 00094: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 95/200
# 25569/25569 [==============================] - 286s 11ms/step - loss: 0.6692 - acc: 0.8976 - f1: 0.3308 - val_loss: 0.6062 - val_acc: 0.9116 - val_f1: 0.3938
#
# Epoch 00095: val_loss did not improve from 0.56250
#
# Epoch 00095: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 96/200
# 25569/25569 [==============================] - 287s 11ms/step - loss: 0.6505 - acc: 0.8955 - f1: 0.3495 - val_loss: 0.6282 - val_acc: 0.9223 - val_f1: 0.3718
#
# Epoch 00096: val_loss did not improve from 0.56250
#
# Epoch 00096: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 97/200
# 25569/25569 [==============================] - 286s 11ms/step - loss: 0.6548 - acc: 0.8997 - f1: 0.3452 - val_loss: 0.6173 - val_acc: 0.9246 - val_f1: 0.3827
#
# Epoch 00097: val_loss did not improve from 0.56250
#
# Epoch 00097: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 98/200
# 25569/25569 [==============================] - 286s 11ms/step - loss: 0.6459 - acc: 0.9026 - f1: 0.3541 - val_loss: 0.6172 - val_acc: 0.9238 - val_f1: 0.3828
#
# Epoch 00098: val_loss did not improve from 0.56250
#
# Epoch 00098: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 99/200
# 25569/25569 [==============================] - 285s 11ms/step - loss: 0.6520 - acc: 0.8994 - f1: 0.3480 - val_loss: 0.6177 - val_acc: 0.9066 - val_f1: 0.3823
#
# Epoch 00099: val_loss did not improve from 0.56250
#
# Epoch 00099: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 100/200
# 25569/25569 [==============================] - 287s 11ms/step - loss: 0.6460 - acc: 0.9009 - f1: 0.3540 - val_loss: 0.6319 - val_acc: 0.9152 - val_f1: 0.3681
#
# Epoch 00100: val_loss did not improve from 0.56250
#
# Epoch 00100: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 101/200
# 25569/25569 [==============================] - 287s 11ms/step - loss: 0.6431 - acc: 0.9036 - f1: 0.3569 - val_loss: 0.5967 - val_acc: 0.9188 - val_f1: 0.4033
#
# Epoch 00101: val_loss did not improve from 0.56250
#
# Epoch 00101: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 102/200
# 25569/25569 [==============================] - 286s 11ms/step - loss: 0.6502 - acc: 0.9047 - f1: 0.3498 - val_loss: 0.6150 - val_acc: 0.9232 - val_f1: 0.3850
#
# Epoch 00102: val_loss did not improve from 0.56250
#
# Epoch 00102: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 103/200
# 25569/25569 [==============================] - 286s 11ms/step - loss: 0.6419 - acc: 0.9014 - f1: 0.3581 - val_loss: 0.6348 - val_acc: 0.9204 - val_f1: 0.3652
#
# Epoch 00103: val_loss did not improve from 0.56250
#
# Epoch 00103: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 104/200
# 25569/25569 [==============================] - 287s 11ms/step - loss: 0.6550 - acc: 0.9050 - f1: 0.3450 - val_loss: 0.6349 - val_acc: 0.9223 - val_f1: 0.3651
#
# Epoch 00104: val_loss did not improve from 0.56250
#
# Epoch 00104: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 105/200
# 25569/25569 [==============================] - 287s 11ms/step - loss: 0.6395 - acc: 0.9088 - f1: 0.3605 - val_loss: 0.6500 - val_acc: 0.9309 - val_f1: 0.3500
#
# Epoch 00105: val_loss did not improve from 0.56250
#
# Epoch 00105: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 106/200
# 25569/25569 [==============================] - 287s 11ms/step - loss: 0.6454 - acc: 0.9004 - f1: 0.3546 - val_loss: 0.5892 - val_acc: 0.9154 - val_f1: 0.4108
#
# Epoch 00106: val_loss did not improve from 0.56250
#
# Epoch 00106: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 107/200
# 25569/25569 [==============================] - 287s 11ms/step - loss: 0.6486 - acc: 0.8998 - f1: 0.3514 - val_loss: 0.5975 - val_acc: 0.9074 - val_f1: 0.4025
#
# Epoch 00107: val_loss did not improve from 0.56250
#
# Epoch 00107: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 108/200
# 25569/25569 [==============================] - 286s 11ms/step - loss: 0.6338 - acc: 0.8990 - f1: 0.3662 - val_loss: 0.6175 - val_acc: 0.9155 - val_f1: 0.3825
#
# Epoch 00108: val_loss did not improve from 0.56250
#
# Epoch 00108: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 109/200
# 25569/25569 [==============================] - 287s 11ms/step - loss: 0.6398 - acc: 0.9006 - f1: 0.3602 - val_loss: 0.6383 - val_acc: 0.9251 - val_f1: 0.3617
#
# Epoch 00109: val_loss did not improve from 0.56250
#
# Epoch 00109: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 110/200
# 25569/25569 [==============================] - 286s 11ms/step - loss: 0.6314 - acc: 0.9070 - f1: 0.3686 - val_loss: 0.6256 - val_acc: 0.9202 - val_f1: 0.3744
#
# Epoch 00110: val_loss did not improve from 0.56250
#
# Epoch 00110: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 111/200
# 25569/25569 [==============================] - 288s 11ms/step - loss: 0.6284 - acc: 0.9070 - f1: 0.3716 - val_loss: 0.6303 - val_acc: 0.9212 - val_f1: 0.3697
#
# Epoch 00111: val_loss did not improve from 0.56250
#
# Epoch 00111: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 112/200
# 25569/25569 [==============================] - 286s 11ms/step - loss: 0.6332 - acc: 0.9069 - f1: 0.3668 - val_loss: 0.6260 - val_acc: 0.9201 - val_f1: 0.3740
#
# Epoch 00112: val_loss did not improve from 0.56250
#
# Epoch 00112: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 113/200
# 25569/25569 [==============================] - 287s 11ms/step - loss: 0.6331 - acc: 0.9080 - f1: 0.3669 - val_loss: 0.6197 - val_acc: 0.9226 - val_f1: 0.3803
#
# Epoch 00113: val_loss did not improve from 0.56250
#
# Epoch 00113: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 114/200
# 25569/25569 [==============================] - 286s 11ms/step - loss: 0.6284 - acc: 0.9100 - f1: 0.3716 - val_loss: 0.6401 - val_acc: 0.9238 - val_f1: 0.3599
#
# Epoch 00114: val_loss did not improve from 0.56250
#
# Epoch 00114: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 115/200
# 25569/25569 [==============================] - 287s 11ms/step - loss: 0.6357 - acc: 0.9085 - f1: 0.3643 - val_loss: 0.6410 - val_acc: 0.9248 - val_f1: 0.3590
#
# Epoch 00115: val_loss did not improve from 0.56250
#
# Epoch 00115: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 116/200
# 25569/25569 [==============================] - 287s 11ms/step - loss: 0.6247 - acc: 0.9087 - f1: 0.3753 - val_loss: 0.6391 - val_acc: 0.9252 - val_f1: 0.3609
#
# Epoch 00116: val_loss did not improve from 0.56250
#
# Epoch 00116: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 117/200
# 25569/25569 [==============================] - 287s 11ms/step - loss: 0.6224 - acc: 0.9130 - f1: 0.3776 - val_loss: 0.6259 - val_acc: 0.9274 - val_f1: 0.3741
#
# Epoch 00117: val_loss did not improve from 0.56250
#
# Epoch 00117: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 118/200
# 25569/25569 [==============================] - 287s 11ms/step - loss: 0.6253 - acc: 0.9118 - f1: 0.3747 - val_loss: 0.6236 - val_acc: 0.9232 - val_f1: 0.3764
#
# Epoch 00118: val_loss did not improve from 0.56250
#
# Epoch 00118: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 119/200
# 25569/25569 [==============================] - 287s 11ms/step - loss: 0.6303 - acc: 0.9076 - f1: 0.3697 - val_loss: 0.6121 - val_acc: 0.9213 - val_f1: 0.3879
#
# Epoch 00119: val_loss did not improve from 0.56250
#
# Epoch 00119: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 120/200
# 25569/25569 [==============================] - 287s 11ms/step - loss: 0.6311 - acc: 0.9081 - f1: 0.3689 - val_loss: 0.5956 - val_acc: 0.9166 - val_f1: 0.4044
#
# Epoch 00120: val_loss did not improve from 0.56250
#
# Epoch 00120: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 121/200
# 25569/25569 [==============================] - 287s 11ms/step - loss: 0.6350 - acc: 0.9100 - f1: 0.3650 - val_loss: 0.6254 - val_acc: 0.9227 - val_f1: 0.3746
#
# Epoch 00121: val_loss did not improve from 0.56250
#
# Epoch 00121: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 122/200
# 25569/25569 [==============================] - 287s 11ms/step - loss: 0.6323 - acc: 0.9105 - f1: 0.3677 - val_loss: 0.6182 - val_acc: 0.9209 - val_f1: 0.3818
#
# Epoch 00122: val_loss did not improve from 0.56250
#
# Epoch 00122: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 123/200
# 25569/25569 [==============================] - 287s 11ms/step - loss: 0.6310 - acc: 0.9087 - f1: 0.3690 - val_loss: 0.6209 - val_acc: 0.9232 - val_f1: 0.3791
#
# Epoch 00123: val_loss did not improve from 0.56250
#
# Epoch 00123: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 124/200
# 25569/25569 [==============================] - 287s 11ms/step - loss: 0.6266 - acc: 0.9129 - f1: 0.3734 - val_loss: 0.6125 - val_acc: 0.9240 - val_f1: 0.3875
#
# Epoch 00124: val_loss did not improve from 0.56250
#
# Epoch 00124: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 125/200
# 25569/25569 [==============================] - 287s 11ms/step - loss: 0.6087 - acc: 0.9123 - f1: 0.3913 - val_loss: 0.6046 - val_acc: 0.9162 - val_f1: 0.3954
#
# Epoch 00125: val_loss did not improve from 0.56250
#
# Epoch 00125: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 126/200
# 25569/25569 [==============================] - 287s 11ms/step - loss: 0.6397 - acc: 0.9091 - f1: 0.3603 - val_loss: 0.6029 - val_acc: 0.9158 - val_f1: 0.3971
#
# Epoch 00126: val_loss did not improve from 0.56250
#
# Epoch 00126: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 127/200
# 25569/25569 [==============================] - 288s 11ms/step - loss: 0.6351 - acc: 0.9070 - f1: 0.3649 - val_loss: 0.6197 - val_acc: 0.9202 - val_f1: 0.3803
#
# Epoch 00127: val_loss did not improve from 0.56250
#
# Epoch 00127: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 128/200
# 25569/25569 [==============================] - 287s 11ms/step - loss: 0.6232 - acc: 0.9140 - f1: 0.3768 - val_loss: 0.6016 - val_acc: 0.9207 - val_f1: 0.3984
#
# Epoch 00128: val_loss did not improve from 0.56250
#
# Epoch 00128: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 129/200
# 25569/25569 [==============================] - 287s 11ms/step - loss: 0.6185 - acc: 0.9136 - f1: 0.3815 - val_loss: 0.5961 - val_acc: 0.9083 - val_f1: 0.4039
#
# Epoch 00129: val_loss did not improve from 0.56250
#
# Epoch 00129: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 130/200
# 25569/25569 [==============================] - 287s 11ms/step - loss: 0.6248 - acc: 0.9126 - f1: 0.3752 - val_loss: 0.5965 - val_acc: 0.9218 - val_f1: 0.4035
#
# Epoch 00130: val_loss did not improve from 0.56250
#
# Epoch 00130: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 131/200
# 25569/25569 [==============================] - 288s 11ms/step - loss: 0.6297 - acc: 0.9133 - f1: 0.3703 - val_loss: 0.5986 - val_acc: 0.9154 - val_f1: 0.4014
#
# Epoch 00131: val_loss did not improve from 0.56250
#
# Epoch 00131: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 132/200
# 25569/25569 [==============================] - 288s 11ms/step - loss: 0.6188 - acc: 0.9105 - f1: 0.3812 - val_loss: 0.6088 - val_acc: 0.9185 - val_f1: 0.3912
#
# Epoch 00132: val_loss did not improve from 0.56250
#
# Epoch 00132: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 133/200
# 25569/25569 [==============================] - 286s 11ms/step - loss: 0.6212 - acc: 0.9103 - f1: 0.3788 - val_loss: 0.6203 - val_acc: 0.9293 - val_f1: 0.3797
#
# Epoch 00133: val_loss did not improve from 0.56250
#
# Epoch 00133: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 134/200
# 25569/25569 [==============================] - 288s 11ms/step - loss: 0.6243 - acc: 0.9133 - f1: 0.3757 - val_loss: 0.6165 - val_acc: 0.9277 - val_f1: 0.3835
#
# Epoch 00134: val_loss did not improve from 0.56250
#
# Epoch 00134: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 135/200
# 25569/25569 [==============================] - 287s 11ms/step - loss: 0.6211 - acc: 0.9082 - f1: 0.3789 - val_loss: 0.6125 - val_acc: 0.9227 - val_f1: 0.3875
#
# Epoch 00135: val_loss did not improve from 0.56250
#
# Epoch 00135: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 136/200
# 25569/25569 [==============================] - 288s 11ms/step - loss: 0.6342 - acc: 0.9091 - f1: 0.3658 - val_loss: 0.6047 - val_acc: 0.9207 - val_f1: 0.3953
#
# Epoch 00136: val_loss did not improve from 0.56250
#
# Epoch 00136: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 137/200
# 25569/25569 [==============================] - 287s 11ms/step - loss: 0.6198 - acc: 0.9095 - f1: 0.3802 - val_loss: 0.6152 - val_acc: 0.9257 - val_f1: 0.3848
#
# Epoch 00137: val_loss did not improve from 0.56250
#
# Epoch 00137: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 138/200
# 25569/25569 [==============================] - 288s 11ms/step - loss: 0.6219 - acc: 0.9134 - f1: 0.3781 - val_loss: 0.5919 - val_acc: 0.9199 - val_f1: 0.4081
#
# Epoch 00138: val_loss did not improve from 0.56250
#
# Epoch 00138: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 139/200
# 25569/25569 [==============================] - 287s 11ms/step - loss: 0.6125 - acc: 0.9140 - f1: 0.3875 - val_loss: 0.5922 - val_acc: 0.9061 - val_f1: 0.4078
#
# Epoch 00139: val_loss did not improve from 0.56250
#
# Epoch 00139: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 140/200
# 25569/25569 [==============================] - 287s 11ms/step - loss: 0.6146 - acc: 0.9148 - f1: 0.3854 - val_loss: 0.5900 - val_acc: 0.9143 - val_f1: 0.4100
#
# Epoch 00140: val_loss did not improve from 0.56250
#
# Epoch 00140: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 141/200
# 25569/25569 [==============================] - 287s 11ms/step - loss: 0.6131 - acc: 0.9152 - f1: 0.3869 - val_loss: 0.5890 - val_acc: 0.9130 - val_f1: 0.4110
#
# Epoch 00141: val_loss did not improve from 0.56250
#
# Epoch 00141: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 142/200
# 25569/25569 [==============================] - 287s 11ms/step - loss: 0.6241 - acc: 0.9132 - f1: 0.3759 - val_loss: 0.5908 - val_acc: 0.9115 - val_f1: 0.4092
#
# Epoch 00142: val_loss did not improve from 0.56250
#
# Epoch 00142: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 143/200
# 25569/25569 [==============================] - 287s 11ms/step - loss: 0.6211 - acc: 0.9138 - f1: 0.3789 - val_loss: 0.5924 - val_acc: 0.9166 - val_f1: 0.4076
#
# Epoch 00143: val_loss did not improve from 0.56250
#
# Epoch 00143: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 144/200
# 25569/25569 [==============================] - 287s 11ms/step - loss: 0.6161 - acc: 0.9125 - f1: 0.3839 - val_loss: 0.5871 - val_acc: 0.9127 - val_f1: 0.4129
#
# Epoch 00144: val_loss did not improve from 0.56250
#
# Epoch 00144: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 145/200
# 25569/25569 [==============================] - 287s 11ms/step - loss: 0.6079 - acc: 0.9142 - f1: 0.3921 - val_loss: 0.5927 - val_acc: 0.9041 - val_f1: 0.4073
#
# Epoch 00145: val_loss did not improve from 0.56250
#
# Epoch 00145: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 146/200
# 25569/25569 [==============================] - 287s 11ms/step - loss: 0.6031 - acc: 0.9152 - f1: 0.3969 - val_loss: 0.5940 - val_acc: 0.9074 - val_f1: 0.4060
#
# Epoch 00146: val_loss did not improve from 0.56250
#
# Epoch 00146: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 147/200
# 25569/25569 [==============================] - 287s 11ms/step - loss: 0.6147 - acc: 0.9155 - f1: 0.3853 - val_loss: 0.5904 - val_acc: 0.9119 - val_f1: 0.4096
#
# Epoch 00147: val_loss did not improve from 0.56250
#
# Epoch 00147: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 148/200
# 25569/25569 [==============================] - 287s 11ms/step - loss: 0.6116 - acc: 0.9161 - f1: 0.3884 - val_loss: 0.5945 - val_acc: 0.9113 - val_f1: 0.4055
#
# Epoch 00148: val_loss did not improve from 0.56250
#
# Epoch 00148: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 149/200
# 25569/25569 [==============================] - 287s 11ms/step - loss: 0.6234 - acc: 0.9148 - f1: 0.3766 - val_loss: 0.5916 - val_acc: 0.9237 - val_f1: 0.4084
#
# Epoch 00149: val_loss did not improve from 0.56250
#
# Epoch 00149: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 150/200
# 25569/25569 [==============================] - 288s 11ms/step - loss: 0.6158 - acc: 0.9160 - f1: 0.3842 - val_loss: 0.5909 - val_acc: 0.9243 - val_f1: 0.4091
#
# Epoch 00150: val_loss did not improve from 0.56250
#
# Epoch 00150: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 151/200
# 25569/25569 [==============================] - 287s 11ms/step - loss: 0.6014 - acc: 0.9181 - f1: 0.3986 - val_loss: 0.5877 - val_acc: 0.9207 - val_f1: 0.4123
#
# Epoch 00151: val_loss did not improve from 0.56250
#
# Epoch 00151: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 152/200
# 25569/25569 [==============================] - 287s 11ms/step - loss: 0.6153 - acc: 0.9161 - f1: 0.3847 - val_loss: 0.5950 - val_acc: 0.9135 - val_f1: 0.4050
#
# Epoch 00152: val_loss did not improve from 0.56250
#
# Epoch 00152: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 153/200
# 25569/25569 [==============================] - 288s 11ms/step - loss: 0.6073 - acc: 0.9183 - f1: 0.3927 - val_loss: 0.5953 - val_acc: 0.9124 - val_f1: 0.4047
#
# Epoch 00153: val_loss did not improve from 0.56250
#
# Epoch 00153: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 154/200
# 25569/25569 [==============================] - 287s 11ms/step - loss: 0.6061 - acc: 0.9184 - f1: 0.3939 - val_loss: 0.5946 - val_acc: 0.9107 - val_f1: 0.4054
#
# Epoch 00154: val_loss did not improve from 0.56250
#
# Epoch 00154: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 155/200
# 25569/25569 [==============================] - 287s 11ms/step - loss: 0.6154 - acc: 0.9148 - f1: 0.3846 - val_loss: 0.5916 - val_acc: 0.9132 - val_f1: 0.4084
#
# Epoch 00155: val_loss did not improve from 0.56250
#
# Epoch 00155: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 156/200
# 25569/25569 [==============================] - 287s 11ms/step - loss: 0.6207 - acc: 0.9157 - f1: 0.3793 - val_loss: 0.5989 - val_acc: 0.9051 - val_f1: 0.4011
#
# Epoch 00156: val_loss did not improve from 0.56250
#
# Epoch 00156: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 157/200
# 25569/25569 [==============================] - 287s 11ms/step - loss: 0.5990 - acc: 0.9168 - f1: 0.4010 - val_loss: 0.5987 - val_acc: 0.9071 - val_f1: 0.4013
#
# Epoch 00157: val_loss did not improve from 0.56250
#
# Epoch 00157: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 158/200
# 25569/25569 [==============================] - 287s 11ms/step - loss: 0.6012 - acc: 0.9168 - f1: 0.3988 - val_loss: 0.5961 - val_acc: 0.9076 - val_f1: 0.4039
#
# Epoch 00158: val_loss did not improve from 0.56250
#
# Epoch 00158: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 159/200
# 25569/25569 [==============================] - 287s 11ms/step - loss: 0.6220 - acc: 0.9160 - f1: 0.3780 - val_loss: 0.5963 - val_acc: 0.9151 - val_f1: 0.4037
#
# Epoch 00159: val_loss did not improve from 0.56250
#
# Epoch 00159: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 160/200
# 25569/25569 [==============================] - 288s 11ms/step - loss: 0.6148 - acc: 0.9152 - f1: 0.3852 - val_loss: 0.5986 - val_acc: 0.9168 - val_f1: 0.4014
#
# Epoch 00160: val_loss did not improve from 0.56250
#
# Epoch 00160: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 161/200
# 25569/25569 [==============================] - 288s 11ms/step - loss: 0.6116 - acc: 0.9160 - f1: 0.3884 - val_loss: 0.5923 - val_acc: 0.9157 - val_f1: 0.4077
#
# Epoch 00161: val_loss did not improve from 0.56250
#
# Epoch 00161: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 162/200
# 25569/25569 [==============================] - 287s 11ms/step - loss: 0.6200 - acc: 0.9175 - f1: 0.3800 - val_loss: 0.5906 - val_acc: 0.9126 - val_f1: 0.4094
#
# Epoch 00162: val_loss did not improve from 0.56250
#
# Epoch 00162: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 163/200
# 25569/25569 [==============================] - 288s 11ms/step - loss: 0.5885 - acc: 0.9199 - f1: 0.4115 - val_loss: 0.5926 - val_acc: 0.9213 - val_f1: 0.4074
#
# Epoch 00163: val_loss did not improve from 0.56250
#
# Epoch 00163: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 164/200
# 25569/25569 [==============================] - 287s 11ms/step - loss: 0.6084 - acc: 0.9197 - f1: 0.3916 - val_loss: 0.5950 - val_acc: 0.9244 - val_f1: 0.4050
#
# Epoch 00164: val_loss did not improve from 0.56250
#
# Epoch 00164: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 165/200
# 25569/25569 [==============================] - 287s 11ms/step - loss: 0.6049 - acc: 0.9184 - f1: 0.3951 - val_loss: 0.5899 - val_acc: 0.9173 - val_f1: 0.4101
#
# Epoch 00165: val_loss did not improve from 0.56250
#
# Epoch 00165: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 166/200
# 25569/25569 [==============================] - 296s 12ms/step - loss: 0.6106 - acc: 0.9175 - f1: 0.3894 - val_loss: 0.5868 - val_acc: 0.9171 - val_f1: 0.4132
#
# Epoch 00166: val_loss did not improve from 0.56250
#
# Epoch 00166: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 167/200
# 25569/25569 [==============================] - 2598s 102ms/step - loss: 0.6132 - acc: 0.9178 - f1: 0.3868 - val_loss: 0.6001 - val_acc: 0.9274 - val_f1: 0.3999
#
# Epoch 00167: val_loss did not improve from 0.56250
#
# Epoch 00167: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 168/200
# 25569/25569 [==============================] - 321s 13ms/step - loss: 0.6094 - acc: 0.9157 - f1: 0.3906 - val_loss: 0.5903 - val_acc: 0.9210 - val_f1: 0.4097
#
# Epoch 00168: val_loss did not improve from 0.56250
#
# Epoch 00168: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 169/200
# 25569/25569 [==============================] - 321s 13ms/step - loss: 0.6117 - acc: 0.9179 - f1: 0.3883 - val_loss: 0.5994 - val_acc: 0.9265 - val_f1: 0.4006
#
# Epoch 00169: val_loss did not improve from 0.56250
#
# Epoch 00169: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 170/200
# 25569/25569 [==============================] - 344s 13ms/step - loss: 0.6182 - acc: 0.9174 - f1: 0.3818 - val_loss: 0.5909 - val_acc: 0.9238 - val_f1: 0.4091
#
# Epoch 00170: val_loss did not improve from 0.56250
#
# Epoch 00170: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 171/200
# 25569/25569 [==============================] - 330s 13ms/step - loss: 0.6073 - acc: 0.9161 - f1: 0.3927 - val_loss: 0.5898 - val_acc: 0.9237 - val_f1: 0.4102
#
# Epoch 00171: val_loss did not improve from 0.56250
#
# Epoch 00171: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 172/200
# 25569/25569 [==============================] - 360s 14ms/step - loss: 0.6146 - acc: 0.9141 - f1: 0.3854 - val_loss: 0.5893 - val_acc: 0.9235 - val_f1: 0.4107
#
# Epoch 00172: val_loss did not improve from 0.56250
#
# Epoch 00172: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 173/200
# 25569/25569 [==============================] - 316s 12ms/step - loss: 0.6097 - acc: 0.9170 - f1: 0.3903 - val_loss: 0.5875 - val_acc: 0.9183 - val_f1: 0.4125
#
# Epoch 00173: val_loss did not improve from 0.56250
#
# Epoch 00173: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 174/200
# 25569/25569 [==============================] - 1212s 47ms/step - loss: 0.6007 - acc: 0.9165 - f1: 0.3993 - val_loss: 0.5872 - val_acc: 0.9180 - val_f1: 0.4128
#
# Epoch 00174: val_loss did not improve from 0.56250
#
# Epoch 00174: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 175/200
# 25569/25569 [==============================] - 30295s 1s/step - loss: 0.6093 - acc: 0.9147 - f1: 0.3907 - val_loss: 0.5905 - val_acc: 0.9243 - val_f1: 0.4095
#
# Epoch 00175: val_loss did not improve from 0.56250
#
# Epoch 00175: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 176/200
# 25569/25569 [==============================] - 352s 14ms/step - loss: 0.6076 - acc: 0.9152 - f1: 0.3924 - val_loss: 0.5905 - val_acc: 0.9248 - val_f1: 0.4095
#
# Epoch 00176: val_loss did not improve from 0.56250
#
# Epoch 00176: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 177/200
# 25569/25569 [==============================] - 353s 14ms/step - loss: 0.5983 - acc: 0.9181 - f1: 0.4017 - val_loss: 0.5871 - val_acc: 0.9163 - val_f1: 0.4129
#
# Epoch 00177: val_loss did not improve from 0.56250
#
# Epoch 00177: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 178/200
# 25569/25569 [==============================] - 329s 13ms/step - loss: 0.6001 - acc: 0.9165 - f1: 0.3999 - val_loss: 0.5853 - val_acc: 0.9174 - val_f1: 0.4147
#
# Epoch 00178: val_loss did not improve from 0.56250
#
# Epoch 00178: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 179/200
# 25569/25569 [==============================] - 330s 13ms/step - loss: 0.6143 - acc: 0.9151 - f1: 0.3857 - val_loss: 0.5865 - val_acc: 0.9180 - val_f1: 0.4135
#
# Epoch 00179: val_loss did not improve from 0.56250
#
# Epoch 00179: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 180/200
# 25569/25569 [==============================] - 298s 12ms/step - loss: 0.6085 - acc: 0.9151 - f1: 0.3915 - val_loss: 0.5867 - val_acc: 0.9173 - val_f1: 0.4133
#
# Epoch 00180: val_loss did not improve from 0.56250
#
# Epoch 00180: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 181/200
# 25569/25569 [==============================] - 321s 13ms/step - loss: 0.5961 - acc: 0.9167 - f1: 0.4039 - val_loss: 0.5865 - val_acc: 0.9152 - val_f1: 0.4135
#
# Epoch 00181: val_loss did not improve from 0.56250
#
# Epoch 00181: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 182/200
# 25569/25569 [==============================] - 306s 12ms/step - loss: 0.6095 - acc: 0.9161 - f1: 0.3905 - val_loss: 0.5866 - val_acc: 0.9162 - val_f1: 0.4134
#
# Epoch 00182: val_loss did not improve from 0.56250
#
# Epoch 00182: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 183/200
# 25569/25569 [==============================] - 303s 12ms/step - loss: 0.6247 - acc: 0.9164 - f1: 0.3753 - val_loss: 0.5868 - val_acc: 0.9152 - val_f1: 0.4132
#
# Epoch 00183: val_loss did not improve from 0.56250
#
# Epoch 00183: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 184/200
# 25569/25569 [==============================] - 303s 12ms/step - loss: 0.6039 - acc: 0.9161 - f1: 0.3961 - val_loss: 0.5867 - val_acc: 0.9151 - val_f1: 0.4133
#
# Epoch 00184: val_loss did not improve from 0.56250
#
# Epoch 00184: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 185/200
# 25569/25569 [==============================] - 303s 12ms/step - loss: 0.6080 - acc: 0.9160 - f1: 0.3920 - val_loss: 0.5866 - val_acc: 0.9155 - val_f1: 0.4134
#
# Epoch 00185: val_loss did not improve from 0.56250
#
# Epoch 00185: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 186/200
# 25569/25569 [==============================] - 287s 11ms/step - loss: 0.5979 - acc: 0.9175 - f1: 0.4021 - val_loss: 0.5868 - val_acc: 0.9151 - val_f1: 0.4132
#
# Epoch 00186: val_loss did not improve from 0.56250
#
# Epoch 00186: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 187/200
# 25569/25569 [==============================] - 285s 11ms/step - loss: 0.6075 - acc: 0.9178 - f1: 0.3925 - val_loss: 0.5868 - val_acc: 0.9151 - val_f1: 0.4132
#
# Epoch 00187: val_loss did not improve from 0.56250
#
# Epoch 00187: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 188/200
# 25569/25569 [==============================] - 285s 11ms/step - loss: 0.6123 - acc: 0.9182 - f1: 0.3877 - val_loss: 0.5868 - val_acc: 0.9151 - val_f1: 0.4132
#
# Epoch 00188: val_loss did not improve from 0.56250
#
# Epoch 00188: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 189/200
# 25569/25569 [==============================] - 285s 11ms/step - loss: 0.6047 - acc: 0.9169 - f1: 0.3953 - val_loss: 0.5868 - val_acc: 0.9149 - val_f1: 0.4132
#
# Epoch 00189: val_loss did not improve from 0.56250
#
# Epoch 00189: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 190/200
# 25569/25569 [==============================] - 287s 11ms/step - loss: 0.6155 - acc: 0.9178 - f1: 0.3845 - val_loss: 0.5866 - val_acc: 0.9149 - val_f1: 0.4134
#
# Epoch 00190: val_loss did not improve from 0.56250
#
# Epoch 00190: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 191/200
# 25569/25569 [==============================] - 285s 11ms/step - loss: 0.6137 - acc: 0.9151 - f1: 0.3863 - val_loss: 0.5865 - val_acc: 0.9149 - val_f1: 0.4135
#
# Epoch 00191: val_loss did not improve from 0.56250
#
# Epoch 00191: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 192/200
# 25569/25569 [==============================] - 285s 11ms/step - loss: 0.5923 - acc: 0.9170 - f1: 0.4077 - val_loss: 0.5864 - val_acc: 0.9149 - val_f1: 0.4136
#
# Epoch 00192: val_loss did not improve from 0.56250
#
# Epoch 00192: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 193/200
# 25569/25569 [==============================] - 285s 11ms/step - loss: 0.6012 - acc: 0.9178 - f1: 0.3988 - val_loss: 0.5864 - val_acc: 0.9149 - val_f1: 0.4136
#
# Epoch 00193: val_loss did not improve from 0.56250
#
# Epoch 00193: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 194/200
# 25569/25569 [==============================] - 285s 11ms/step - loss: 0.6074 - acc: 0.9172 - f1: 0.3926 - val_loss: 0.5864 - val_acc: 0.9149 - val_f1: 0.4136
#
# Epoch 00194: val_loss did not improve from 0.56250
#
# Epoch 00194: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 195/200
# 25569/25569 [==============================] - 285s 11ms/step - loss: 0.6161 - acc: 0.9164 - f1: 0.3839 - val_loss: 0.5864 - val_acc: 0.9149 - val_f1: 0.4136
#
# Epoch 00195: val_loss did not improve from 0.56250
#
# Epoch 00195: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 196/200
# 25569/25569 [==============================] - 285s 11ms/step - loss: 0.5922 - acc: 0.9193 - f1: 0.4078 - val_loss: 0.5864 - val_acc: 0.9149 - val_f1: 0.4136
#
# Epoch 00196: val_loss did not improve from 0.56250
#
# Epoch 00196: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 197/200
# 25569/25569 [==============================] - 286s 11ms/step - loss: 0.6071 - acc: 0.9169 - f1: 0.3929 - val_loss: 0.5864 - val_acc: 0.9148 - val_f1: 0.4136
#
# Epoch 00197: val_loss did not improve from 0.56250
#
# Epoch 00197: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 198/200
# 25569/25569 [==============================] - 285s 11ms/step - loss: 0.6154 - acc: 0.9158 - f1: 0.3846 - val_loss: 0.5864 - val_acc: 0.9148 - val_f1: 0.4136
#
# Epoch 00198: val_loss did not improve from 0.56250
#
# Epoch 00198: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 199/200
# 25569/25569 [==============================] - 285s 11ms/step - loss: 0.6038 - acc: 0.9178 - f1: 0.3962 - val_loss: 0.5864 - val_acc: 0.9148 - val_f1: 0.4136
#
# Epoch 00199: val_loss did not improve from 0.56250
#
# Epoch 00199: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 200/200
# 25569/25569 [==============================] - 286s 11ms/step - loss: 0.6024 - acc: 0.9170 - f1: 0.3976 - val_loss: 0.5864 - val_acc: 0.9148 - val_f1: 0.4136
#
# Epoch 00200: val_loss did not improve from 0.56250
#
# Epoch 00200: saving model to ../model_wehigts/6_ch.hdf5

# %%
from sklearn.metrics import f1_score, accuracy_score

#Load best model
model.load_weights(checkpoint_path)
y_pred = model.predict(x_val, batch_size=1)
y_pred = np.where(y_pred > 0.5, 1, 0)

print("GLOVE emmbeding f1_sklearn: {}".format(f1_score(y_val.astype(float), y_pred)))
print("GLOVE emmbeding accuracy: {}".format(accuracy_score(y_val.astype(float), y_pred)))
# Out:
# GLOVE emmbeding f1_sklearn: 0.5244267198404787
# GLOVE emmbeding accuracy: 0.9253871421867668
