# %% [markdown]
# # Train Numberbatch or Glove

# %%
import numpy as np
import pandas as pd 
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.layers import (
    Dense,
    Input,
    LSTM,
    Embedding,
    Dropout,
    Activation,
    SpatialDropout1D
)
from tensorflow.keras.models import Model, load_model
from tensorflow.keras.callbacks import ModelCheckpoint
from ast import literal_eval
from sklearn.model_selection import train_test_split
# Out:
# /Users/sebastiancorrea/anaconda3/lib/python3.6/importlib/_bootstrap.py:219: RuntimeWarning: compiletime version 3.5 of module 'tensorflow.python.framework.fast_tensor_util' does not match runtime version 3.6
#   return f(*args, **kwds)

# %%
df = pd.read_csv('../data/pandas_data_frame.csv', index_col=0)
all_data = df.where((pd.notnull(df)), '')
all_data['hashtag'] = all_data['hashtag'].apply(literal_eval)

full_text = all_data['tidy_tweet'][(all_data['label']==1.0) | (all_data['label']==0.0)]
y = all_data['label'][(all_data['label']==1.0) | (all_data['label']==0.0)]

# %%
tk = Tokenizer(lower=True, filters='')
tk.fit_on_texts(full_text)

train_tokenized = tk.texts_to_sequences(full_text)
max_len = 19
X = pad_sequences(train_tokenized, maxlen=max_len)

x_train, x_val, y_train, y_val = train_test_split(X, y, random_state=1992, test_size=0.2)

print(x_train.shape,y_train.shape)
print(x_val.shape,y_val.shape)
# Out:
# (25569, 19) (25569,)
# (6393, 19) (6393,)

# %%
import pickle

# saving
with open('../model_wehigts/tokenizer.pickle', 'wb') as handle:
    pickle.dump(tk, handle, protocol=pickle.HIGHEST_PROTOCOL)

# # loading
# with open('tokenizer.pickle', 'rb') as handle:
#     tokenizer = pickle.load(handle)

# %%
embedding_path = '../data/vectors/glove.twitter.27B/glove.twitter.27B.200d.txt'
# embedding_path = '../data/vectors/numberbatch-17.06.txt'
embed_size = 200

max_features = 30000

def get_coefs(word,*arr):
    return word, np.asarray(arr, dtype='float32')

embedding_index = dict(get_coefs(*o.strip().split(" ")) for o in open(embedding_path))

# %%
word_index = tk.word_index
nb_words = min(max_features, len(word_index))
embedding_matrix = np.zeros((nb_words + 1, embed_size))

for word, i in word_index.items():
    if i >= max_features: continue
    embedding_vector = embedding_index.get(word)
    if embedding_vector is not None: embedding_matrix[i] = embedding_vector

# %%
import sys
sys.path.append("../") 
from personal_library.sce_keras.loss_functions import f1_loss
from personal_library.sce_keras.metrics_functions import f1
from personal_library.sce_keras.callbacks import (
    LearningRateDecay,
    WarmUpCosineDecayScheduler
)


num_classes = 1
batch_size = 32
epochs = 200
learnRate = 0.001
lstm_out = 200
warmup_epoch = 20

lrate_decay = LearningRateDecay(epochs, learnRate).step_decay
warm_up_lr = WarmUpCosineDecayScheduler(learning_rate_base=learnRate,
                                        warmup_learning_rate=0,
                                        warmup_epoch=warmup_epoch,
                                        hold_base_rate_steps=5,
                                        verbose=0)

checkpoint_path = "../model_wehigts/6_w.hdf5"
checkpoint_path1 = "../model_wehigts/6_ch.hdf5"
checkpointer = ModelCheckpoint(filepath=checkpoint_path,
                               monitor='val_loss', verbose=2,
                               save_best_only=True, mode='min')
checkpointer1 = ModelCheckpoint(filepath=checkpoint_path1,
                               monitor='val_loss', verbose=2,
                               save_best_only=False, mode='min')

inp = Input(shape = (max_len,))
x = Embedding(nb_words+1, embed_size, weights = [embedding_matrix], trainable=False)(inp)
x = SpatialDropout1D(0.3)(x)
x = LSTM(lstm_out, dropout=0.5, recurrent_dropout=0.5)(x)
x = Dense(1, activation = "sigmoid")(x)

model = Model(inputs=inp, outputs=x)
model.summary()

# 'binary_crossentropy'
model.compile(loss=f1_loss, 
              optimizer='adam', 
              metrics=['accuracy', f1]) 

history = model.fit(x_train, y_train, 
                    batch_size=batch_size,
                    epochs=epochs,
                    verbose=1,
                    validation_data=(x_val, y_val),
                    callbacks=[checkpointer, checkpointer1, lrate_decay])
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, 19)                0
# _________________________________________________________________
# embedding (Embedding)        (None, 19, 200)           3033400
# _________________________________________________________________
# spatial_dropout1d (SpatialDr (None, 19, 200)           0
# _________________________________________________________________
# lstm (LSTM)                  (None, 200)               320800
# _________________________________________________________________
# dense (Dense)                (None, 1)                 201
# =================================================================
# Total params: 3,354,401
# Trainable params: 321,001
# Non-trainable params: 3,033,400
# _________________________________________________________________
# Train on 25569 samples, validate on 6393 samples
# Epoch 1/200
# 25569/25569 [==============================] - 51s 2ms/step - loss: 0.7492 - acc: 0.8173 - f1: 0.2508 - val_loss: 0.6548 - val_acc: 0.8878 - val_f1: 0.3452
#
# Epoch 00001: val_loss improved from inf to 0.65481, saving model to ../model_wehigts/6_w.hdf5
#
# Epoch 00001: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 2/200
# 25569/25569 [==============================] - 50s 2ms/step - loss: 0.6775 - acc: 0.9005 - f1: 0.3225 - val_loss: 0.6983 - val_acc: 0.9284 - val_f1: 0.3017
#
# Epoch 00002: val_loss did not improve from 0.65481
#
# Epoch 00002: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 3/200
# 25569/25569 [==============================] - 51s 2ms/step - loss: 0.6728 - acc: 0.8917 - f1: 0.3272 - val_loss: 0.6426 - val_acc: 0.9072 - val_f1: 0.3574
#
# Epoch 00003: val_loss improved from 0.65481 to 0.64260, saving model to ../model_wehigts/6_w.hdf5
#
# Epoch 00003: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 4/200
# 25569/25569 [==============================] - 51s 2ms/step - loss: 0.6593 - acc: 0.8957 - f1: 0.3407 - val_loss: 0.6461 - val_acc: 0.9215 - val_f1: 0.3539
#
# Epoch 00004: val_loss did not improve from 0.64260
#
# Epoch 00004: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 5/200
# 25569/25569 [==============================] - 51s 2ms/step - loss: 0.6493 - acc: 0.9094 - f1: 0.3507 - val_loss: 0.6861 - val_acc: 0.9370 - val_f1: 0.3139
#
# Epoch 00005: val_loss did not improve from 0.64260
#
# Epoch 00005: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 6/200
# 25569/25569 [==============================] - 52s 2ms/step - loss: 0.6400 - acc: 0.9012 - f1: 0.3600 - val_loss: 0.6490 - val_acc: 0.9227 - val_f1: 0.3510
#
# Epoch 00006: val_loss did not improve from 0.64260
#
# Epoch 00006: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 7/200
# 25569/25569 [==============================] - 51s 2ms/step - loss: 0.6296 - acc: 0.9192 - f1: 0.3704 - val_loss: 0.6672 - val_acc: 0.9379 - val_f1: 0.3328
#
# Epoch 00007: val_loss did not improve from 0.64260
#
# Epoch 00007: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 8/200
# 25569/25569 [==============================] - 51s 2ms/step - loss: 0.6322 - acc: 0.9117 - f1: 0.3678 - val_loss: 0.6297 - val_acc: 0.9121 - val_f1: 0.3703
#
# Epoch 00008: val_loss improved from 0.64260 to 0.62970, saving model to ../model_wehigts/6_w.hdf5
#
# Epoch 00008: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 9/200
# 25569/25569 [==============================] - 52s 2ms/step - loss: 0.6367 - acc: 0.9047 - f1: 0.3633 - val_loss: 0.6183 - val_acc: 0.9263 - val_f1: 0.3817
#
# Epoch 00009: val_loss improved from 0.62970 to 0.61827, saving model to ../model_wehigts/6_w.hdf5
#
# Epoch 00009: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 10/200
# 25569/25569 [==============================] - 52s 2ms/step - loss: 0.6354 - acc: 0.9132 - f1: 0.3646 - val_loss: 0.6277 - val_acc: 0.9263 - val_f1: 0.3723
#
# Epoch 00010: val_loss did not improve from 0.61827
#
# Epoch 00010: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 11/200
# 25569/25569 [==============================] - 52s 2ms/step - loss: 0.6316 - acc: 0.9162 - f1: 0.3684 - val_loss: 0.6300 - val_acc: 0.9082 - val_f1: 0.3700
#
# Epoch 00011: val_loss did not improve from 0.61827
#
# Epoch 00011: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 12/200
# 25569/25569 [==============================] - 52s 2ms/step - loss: 0.6239 - acc: 0.9246 - f1: 0.3761 - val_loss: 0.6221 - val_acc: 0.9173 - val_f1: 0.3779
#
# Epoch 00012: val_loss did not improve from 0.61827
#
# Epoch 00012: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 13/200
# 25569/25569 [==============================] - 52s 2ms/step - loss: 0.6187 - acc: 0.9138 - f1: 0.3813 - val_loss: 0.6219 - val_acc: 0.9207 - val_f1: 0.3781
#
# Epoch 00013: val_loss did not improve from 0.61827
#
# Epoch 00013: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 14/200
# 25569/25569 [==============================] - 52s 2ms/step - loss: 0.6078 - acc: 0.9164 - f1: 0.3922 - val_loss: 0.6127 - val_acc: 0.9246 - val_f1: 0.3873
#
# Epoch 00014: val_loss improved from 0.61827 to 0.61273, saving model to ../model_wehigts/6_w.hdf5
#
# Epoch 00014: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 15/200
# 25569/25569 [==============================] - 54s 2ms/step - loss: 0.6180 - acc: 0.9185 - f1: 0.3820 - val_loss: 0.6121 - val_acc: 0.9137 - val_f1: 0.3879
#
# Epoch 00015: val_loss improved from 0.61273 to 0.61213, saving model to ../model_wehigts/6_w.hdf5
#
# Epoch 00015: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 16/200
# 25569/25569 [==============================] - 54s 2ms/step - loss: 0.6078 - acc: 0.9231 - f1: 0.3922 - val_loss: 0.6152 - val_acc: 0.9051 - val_f1: 0.3848
#
# Epoch 00016: val_loss did not improve from 0.61213
#
# Epoch 00016: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 17/200
# 25569/25569 [==============================] - 54s 2ms/step - loss: 0.6147 - acc: 0.9246 - f1: 0.3853 - val_loss: 0.6100 - val_acc: 0.9148 - val_f1: 0.3900
#
# Epoch 00017: val_loss improved from 0.61213 to 0.61004, saving model to ../model_wehigts/6_w.hdf5
#
# Epoch 00017: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 18/200
# 25569/25569 [==============================] - 54s 2ms/step - loss: 0.6018 - acc: 0.9243 - f1: 0.3982 - val_loss: 0.6171 - val_acc: 0.9240 - val_f1: 0.3829
#
# Epoch 00018: val_loss did not improve from 0.61004
#
# Epoch 00018: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 19/200
# 25569/25569 [==============================] - 53s 2ms/step - loss: 0.5997 - acc: 0.9212 - f1: 0.4003 - val_loss: 0.6187 - val_acc: 0.9302 - val_f1: 0.3813
#
# Epoch 00019: val_loss did not improve from 0.61004
#
# Epoch 00019: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 20/200
# 25569/25569 [==============================] - 53s 2ms/step - loss: 0.6037 - acc: 0.9162 - f1: 0.3963 - val_loss: 0.6063 - val_acc: 0.9140 - val_f1: 0.3937
#
# Epoch 00020: val_loss improved from 0.61004 to 0.60630, saving model to ../model_wehigts/6_w.hdf5
#
# Epoch 00020: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 21/200
# 25569/25569 [==============================] - 53s 2ms/step - loss: 0.5987 - acc: 0.9175 - f1: 0.4013 - val_loss: 0.5963 - val_acc: 0.9080 - val_f1: 0.4037
#
# Epoch 00021: val_loss improved from 0.60630 to 0.59629, saving model to ../model_wehigts/6_w.hdf5
#
# Epoch 00021: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 22/200
# 25569/25569 [==============================] - 53s 2ms/step - loss: 0.5923 - acc: 0.9195 - f1: 0.4077 - val_loss: 0.6080 - val_acc: 0.9163 - val_f1: 0.3920
#
# Epoch 00022: val_loss did not improve from 0.59629
#
# Epoch 00022: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 23/200
# 25569/25569 [==============================] - 49s 2ms/step - loss: 0.5822 - acc: 0.9270 - f1: 0.4178 - val_loss: 0.6090 - val_acc: 0.9204 - val_f1: 0.3910
#
# Epoch 00023: val_loss did not improve from 0.59629
#
# Epoch 00023: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 24/200
# 25569/25569 [==============================] - 47s 2ms/step - loss: 0.5899 - acc: 0.9218 - f1: 0.4101 - val_loss: 0.6042 - val_acc: 0.9148 - val_f1: 0.3958
#
# Epoch 00024: val_loss did not improve from 0.59629
#
# Epoch 00024: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 25/200
# 25569/25569 [==============================] - 47s 2ms/step - loss: 0.5789 - acc: 0.9234 - f1: 0.4211 - val_loss: 0.6019 - val_acc: 0.9182 - val_f1: 0.3981
#
# Epoch 00025: val_loss did not improve from 0.59629
#
# Epoch 00025: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 26/200
# 25569/25569 [==============================] - 47s 2ms/step - loss: 0.5992 - acc: 0.9285 - f1: 0.4008 - val_loss: 0.5981 - val_acc: 0.9218 - val_f1: 0.4019
#
# Epoch 00026: val_loss did not improve from 0.59629
#
# Epoch 00026: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 27/200
# 25569/25569 [==============================] - 47s 2ms/step - loss: 0.5894 - acc: 0.9292 - f1: 0.4106 - val_loss: 0.6166 - val_acc: 0.9285 - val_f1: 0.3834
#
# Epoch 00027: val_loss did not improve from 0.59629
#
# Epoch 00027: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 28/200
# 25569/25569 [==============================] - 47s 2ms/step - loss: 0.5877 - acc: 0.9238 - f1: 0.4123 - val_loss: 0.6011 - val_acc: 0.9207 - val_f1: 0.3989
#
# Epoch 00028: val_loss did not improve from 0.59629
#
# Epoch 00028: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 29/200
# 25569/25569 [==============================] - 47s 2ms/step - loss: 0.5772 - acc: 0.9258 - f1: 0.4228 - val_loss: 0.5968 - val_acc: 0.9118 - val_f1: 0.4032
#
# Epoch 00029: val_loss did not improve from 0.59629
#
# Epoch 00029: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 30/200
# 25569/25569 [==============================] - 47s 2ms/step - loss: 0.6035 - acc: 0.9173 - f1: 0.3965 - val_loss: 0.6043 - val_acc: 0.9223 - val_f1: 0.3957
#
# Epoch 00030: val_loss did not improve from 0.59629
#
# Epoch 00030: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 31/200
# 25569/25569 [==============================] - 48s 2ms/step - loss: 0.5761 - acc: 0.9283 - f1: 0.4239 - val_loss: 0.6029 - val_acc: 0.9166 - val_f1: 0.3971
#
# Epoch 00031: val_loss did not improve from 0.59629
#
# Epoch 00031: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 32/200
# 25569/25569 [==============================] - 47s 2ms/step - loss: 0.5789 - acc: 0.9246 - f1: 0.4211 - val_loss: 0.6005 - val_acc: 0.9116 - val_f1: 0.3995
#
# Epoch 00032: val_loss did not improve from 0.59629
#
# Epoch 00032: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 33/200
# 25569/25569 [==============================] - 48s 2ms/step - loss: 0.5690 - acc: 0.9289 - f1: 0.4310 - val_loss: 0.5986 - val_acc: 0.9058 - val_f1: 0.4014
#
# Epoch 00033: val_loss did not improve from 0.59629
#
# Epoch 00033: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 34/200
# 25569/25569 [==============================] - 47s 2ms/step - loss: 0.5730 - acc: 0.9258 - f1: 0.4270 - val_loss: 0.5984 - val_acc: 0.9209 - val_f1: 0.4016
#
# Epoch 00034: val_loss did not improve from 0.59629
#
# Epoch 00034: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 35/200
# 25569/25569 [==============================] - 47s 2ms/step - loss: 0.5626 - acc: 0.9298 - f1: 0.4374 - val_loss: 0.5881 - val_acc: 0.9227 - val_f1: 0.4119
#
# Epoch 00035: val_loss improved from 0.59629 to 0.58814, saving model to ../model_wehigts/6_w.hdf5
#
# Epoch 00035: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 36/200
# 25569/25569 [==============================] - 47s 2ms/step - loss: 0.5715 - acc: 0.9243 - f1: 0.4285 - val_loss: 0.5914 - val_acc: 0.9183 - val_f1: 0.4086
#
# Epoch 00036: val_loss did not improve from 0.58814
#
# Epoch 00036: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 37/200
# 25569/25569 [==============================] - 47s 2ms/step - loss: 0.5665 - acc: 0.9274 - f1: 0.4335 - val_loss: 0.6064 - val_acc: 0.9284 - val_f1: 0.3936
#
# Epoch 00037: val_loss did not improve from 0.58814
#
# Epoch 00037: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 38/200
# 25569/25569 [==============================] - 48s 2ms/step - loss: 0.5753 - acc: 0.9283 - f1: 0.4247 - val_loss: 0.5911 - val_acc: 0.9029 - val_f1: 0.4089
#
# Epoch 00038: val_loss did not improve from 0.58814
#
# Epoch 00038: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 39/200
# 25569/25569 [==============================] - 47s 2ms/step - loss: 0.5661 - acc: 0.9274 - f1: 0.4339 - val_loss: 0.5888 - val_acc: 0.9135 - val_f1: 0.4112
#
# Epoch 00039: val_loss did not improve from 0.58814
#
# Epoch 00039: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 40/200
# 25569/25569 [==============================] - 47s 2ms/step - loss: 0.5680 - acc: 0.9263 - f1: 0.4320 - val_loss: 0.5917 - val_acc: 0.9163 - val_f1: 0.4083
#
# Epoch 00040: val_loss did not improve from 0.58814
#
# Epoch 00040: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 41/200
# 25569/25569 [==============================] - 48s 2ms/step - loss: 0.5600 - acc: 0.9303 - f1: 0.4400 - val_loss: 0.5820 - val_acc: 0.9244 - val_f1: 0.4180
#
# Epoch 00041: val_loss improved from 0.58814 to 0.58199, saving model to ../model_wehigts/6_w.hdf5
#
# Epoch 00041: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 42/200
# 25569/25569 [==============================] - 48s 2ms/step - loss: 0.5547 - acc: 0.9321 - f1: 0.4453 - val_loss: 0.5836 - val_acc: 0.9262 - val_f1: 0.4164
#
# Epoch 00042: val_loss did not improve from 0.58199
#
# Epoch 00042: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 43/200
# 25569/25569 [==============================] - 48s 2ms/step - loss: 0.5541 - acc: 0.9359 - f1: 0.4459 - val_loss: 0.5868 - val_acc: 0.9312 - val_f1: 0.4132
#
# Epoch 00043: val_loss did not improve from 0.58199
#
# Epoch 00043: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 44/200
# 25569/25569 [==============================] - 47s 2ms/step - loss: 0.5569 - acc: 0.9316 - f1: 0.4431 - val_loss: 0.5802 - val_acc: 0.9271 - val_f1: 0.4198
#
# Epoch 00044: val_loss improved from 0.58199 to 0.58017, saving model to ../model_wehigts/6_w.hdf5
#
# Epoch 00044: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 45/200
# 25569/25569 [==============================] - 47s 2ms/step - loss: 0.5512 - acc: 0.9342 - f1: 0.4488 - val_loss: 0.5833 - val_acc: 0.9276 - val_f1: 0.4167
#
# Epoch 00045: val_loss did not improve from 0.58017
#
# Epoch 00045: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 46/200
# 25569/25569 [==============================] - 47s 2ms/step - loss: 0.5419 - acc: 0.9348 - f1: 0.4581 - val_loss: 0.5864 - val_acc: 0.9223 - val_f1: 0.4136
#
# Epoch 00046: val_loss did not improve from 0.58017
#
# Epoch 00046: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 47/200
# 25569/25569 [==============================] - 47s 2ms/step - loss: 0.5557 - acc: 0.9359 - f1: 0.4443 - val_loss: 0.5751 - val_acc: 0.9155 - val_f1: 0.4249
#
# Epoch 00047: val_loss improved from 0.58017 to 0.57509, saving model to ../model_wehigts/6_w.hdf5
#
# Epoch 00047: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 48/200
# 25569/25569 [==============================] - 47s 2ms/step - loss: 0.5489 - acc: 0.9320 - f1: 0.4511 - val_loss: 0.5836 - val_acc: 0.9210 - val_f1: 0.4164
#
# Epoch 00048: val_loss did not improve from 0.57509
#
# Epoch 00048: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 49/200
# 25569/25569 [==============================] - 47s 2ms/step - loss: 0.5518 - acc: 0.9324 - f1: 0.4482 - val_loss: 0.5809 - val_acc: 0.9133 - val_f1: 0.4191
#
# Epoch 00049: val_loss did not improve from 0.57509
#
# Epoch 00049: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 50/200
# 25569/25569 [==============================] - 47s 2ms/step - loss: 0.5461 - acc: 0.9304 - f1: 0.4539 - val_loss: 0.5760 - val_acc: 0.9202 - val_f1: 0.4240
#
# Epoch 00050: val_loss did not improve from 0.57509
#
# Epoch 00050: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 51/200
# 25569/25569 [==============================] - 47s 2ms/step - loss: 0.5531 - acc: 0.9339 - f1: 0.4469 - val_loss: 0.5790 - val_acc: 0.9254 - val_f1: 0.4210
#
# Epoch 00051: val_loss did not improve from 0.57509
#
# Epoch 00051: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 52/200
# 25569/25569 [==============================] - 48s 2ms/step - loss: 0.5539 - acc: 0.9354 - f1: 0.4461 - val_loss: 0.5789 - val_acc: 0.9230 - val_f1: 0.4211
#
# Epoch 00052: val_loss did not improve from 0.57509
#
# Epoch 00052: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 53/200
# 25569/25569 [==============================] - 47s 2ms/step - loss: 0.5496 - acc: 0.9333 - f1: 0.4504 - val_loss: 0.5795 - val_acc: 0.9224 - val_f1: 0.4205
#
# Epoch 00053: val_loss did not improve from 0.57509
#
# Epoch 00053: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 54/200
# 25569/25569 [==============================] - 47s 2ms/step - loss: 0.5270 - acc: 0.9327 - f1: 0.4730 - val_loss: 0.5825 - val_acc: 0.9207 - val_f1: 0.4175
#
# Epoch 00054: val_loss did not improve from 0.57509
#
# Epoch 00054: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 55/200
# 25569/25569 [==============================] - 48s 2ms/step - loss: 0.5416 - acc: 0.9338 - f1: 0.4584 - val_loss: 0.5807 - val_acc: 0.9252 - val_f1: 0.4193
#
# Epoch 00055: val_loss did not improve from 0.57509
#
# Epoch 00055: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 56/200
# 25569/25569 [==============================] - 48s 2ms/step - loss: 0.5362 - acc: 0.9349 - f1: 0.4638 - val_loss: 0.5763 - val_acc: 0.9218 - val_f1: 0.4237
#
# Epoch 00056: val_loss did not improve from 0.57509
#
# Epoch 00056: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 57/200
# 25569/25569 [==============================] - 47s 2ms/step - loss: 0.5300 - acc: 0.9343 - f1: 0.4700 - val_loss: 0.5767 - val_acc: 0.9190 - val_f1: 0.4233
#
# Epoch 00057: val_loss did not improve from 0.57509
#
# Epoch 00057: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 58/200
# 25569/25569 [==============================] - 48s 2ms/step - loss: 0.5283 - acc: 0.9382 - f1: 0.4717 - val_loss: 0.5756 - val_acc: 0.9259 - val_f1: 0.4244
#
# Epoch 00058: val_loss did not improve from 0.57509
#
# Epoch 00058: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 59/200
# 25569/25569 [==============================] - 47s 2ms/step - loss: 0.5230 - acc: 0.9368 - f1: 0.4770 - val_loss: 0.5797 - val_acc: 0.9234 - val_f1: 0.4203
#
# Epoch 00059: val_loss did not improve from 0.57509
#
# Epoch 00059: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 60/200
# 25569/25569 [==============================] - 47s 2ms/step - loss: 0.5365 - acc: 0.9378 - f1: 0.4635 - val_loss: 0.5789 - val_acc: 0.9238 - val_f1: 0.4211
#
# Epoch 00060: val_loss did not improve from 0.57509
#
# Epoch 00060: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 61/200
# 25569/25569 [==============================] - 47s 2ms/step - loss: 0.5162 - acc: 0.9378 - f1: 0.4838 - val_loss: 0.5842 - val_acc: 0.9218 - val_f1: 0.4158
#
# Epoch 00061: val_loss did not improve from 0.57509
#
# Epoch 00061: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 62/200
# 25569/25569 [==============================] - 47s 2ms/step - loss: 0.5188 - acc: 0.9378 - f1: 0.4812 - val_loss: 0.5828 - val_acc: 0.9224 - val_f1: 0.4172
#
# Epoch 00062: val_loss did not improve from 0.57509
#
# Epoch 00062: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 63/200
# 25569/25569 [==============================] - 47s 2ms/step - loss: 0.5324 - acc: 0.9398 - f1: 0.4676 - val_loss: 0.5820 - val_acc: 0.9202 - val_f1: 0.4180
#
# Epoch 00063: val_loss did not improve from 0.57509
#
# Epoch 00063: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 64/200
# 25569/25569 [==============================] - 47s 2ms/step - loss: 0.5256 - acc: 0.9397 - f1: 0.4744 - val_loss: 0.5754 - val_acc: 0.9260 - val_f1: 0.4246
#
# Epoch 00064: val_loss did not improve from 0.57509
#
# Epoch 00064: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 65/200
# 25569/25569 [==============================] - 48s 2ms/step - loss: 0.5278 - acc: 0.9397 - f1: 0.4722 - val_loss: 0.5752 - val_acc: 0.9215 - val_f1: 0.4248
#
# Epoch 00065: val_loss did not improve from 0.57509
#
# Epoch 00065: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 66/200
# 25569/25569 [==============================] - 48s 2ms/step - loss: 0.5232 - acc: 0.9392 - f1: 0.4768 - val_loss: 0.5764 - val_acc: 0.9221 - val_f1: 0.4236
#
# Epoch 00066: val_loss did not improve from 0.57509
#
# Epoch 00066: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 67/200
# 25569/25569 [==============================] - 48s 2ms/step - loss: 0.5106 - acc: 0.9360 - f1: 0.4894 - val_loss: 0.5781 - val_acc: 0.9207 - val_f1: 0.4219
#
# Epoch 00067: val_loss did not improve from 0.57509
#
# Epoch 00067: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 68/200
# 25569/25569 [==============================] - 48s 2ms/step - loss: 0.5185 - acc: 0.9389 - f1: 0.4815 - val_loss: 0.5808 - val_acc: 0.9199 - val_f1: 0.4192
#
# Epoch 00068: val_loss did not improve from 0.57509
#
# Epoch 00068: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 69/200
# 25569/25569 [==============================] - 47s 2ms/step - loss: 0.5091 - acc: 0.9415 - f1: 0.4909 - val_loss: 0.5815 - val_acc: 0.9276 - val_f1: 0.4185
#
# Epoch 00069: val_loss did not improve from 0.57509
#
# Epoch 00069: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 70/200
# 25569/25569 [==============================] - 48s 2ms/step - loss: 0.5206 - acc: 0.9420 - f1: 0.4794 - val_loss: 0.5782 - val_acc: 0.9213 - val_f1: 0.4218
#
# Epoch 00070: val_loss did not improve from 0.57509
#
# Epoch 00070: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 71/200
# 25569/25569 [==============================] - 48s 2ms/step - loss: 0.5130 - acc: 0.9396 - f1: 0.4870 - val_loss: 0.5695 - val_acc: 0.9166 - val_f1: 0.4305
#
# Epoch 00071: val_loss improved from 0.57509 to 0.56951, saving model to ../model_wehigts/6_w.hdf5
#
# Epoch 00071: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 72/200
# 25569/25569 [==============================] - 47s 2ms/step - loss: 0.5296 - acc: 0.9386 - f1: 0.4704 - val_loss: 0.5811 - val_acc: 0.9260 - val_f1: 0.4189
#
# Epoch 00072: val_loss did not improve from 0.56951
#
# Epoch 00072: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 73/200
# 25569/25569 [==============================] - 47s 2ms/step - loss: 0.5127 - acc: 0.9384 - f1: 0.4873 - val_loss: 0.5818 - val_acc: 0.9199 - val_f1: 0.4182
#
# Epoch 00073: val_loss did not improve from 0.56951
#
# Epoch 00073: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 74/200
# 25569/25569 [==============================] - 48s 2ms/step - loss: 0.5139 - acc: 0.9432 - f1: 0.4861 - val_loss: 0.5788 - val_acc: 0.9171 - val_f1: 0.4212
#
# Epoch 00074: val_loss did not improve from 0.56951
#
# Epoch 00074: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 75/200
# 25569/25569 [==============================] - 47s 2ms/step - loss: 0.5140 - acc: 0.9398 - f1: 0.4860 - val_loss: 0.5756 - val_acc: 0.9198 - val_f1: 0.4244
#
# Epoch 00075: val_loss did not improve from 0.56951
#
# Epoch 00075: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 76/200
# 25569/25569 [==============================] - 47s 2ms/step - loss: 0.5132 - acc: 0.9402 - f1: 0.4868 - val_loss: 0.5744 - val_acc: 0.9190 - val_f1: 0.4256
#
# Epoch 00076: val_loss did not improve from 0.56951
#
# Epoch 00076: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 77/200
# 25569/25569 [==============================] - 48s 2ms/step - loss: 0.5222 - acc: 0.9404 - f1: 0.4778 - val_loss: 0.5745 - val_acc: 0.9144 - val_f1: 0.4255
#
# Epoch 00077: val_loss did not improve from 0.56951
#
# Epoch 00077: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 78/200
# 25569/25569 [==============================] - 48s 2ms/step - loss: 0.5183 - acc: 0.9388 - f1: 0.4817 - val_loss: 0.5810 - val_acc: 0.9244 - val_f1: 0.4190
#
# Epoch 00078: val_loss did not improve from 0.56951
#
# Epoch 00078: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 79/200
# 25569/25569 [==============================] - 47s 2ms/step - loss: 0.5065 - acc: 0.9441 - f1: 0.4935 - val_loss: 0.5770 - val_acc: 0.9262 - val_f1: 0.4230
#
# Epoch 00079: val_loss did not improve from 0.56951
#
# Epoch 00079: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 80/200
# 25569/25569 [==============================] - 48s 2ms/step - loss: 0.5063 - acc: 0.9403 - f1: 0.4937 - val_loss: 0.5742 - val_acc: 0.9196 - val_f1: 0.4258
#
# Epoch 00080: val_loss did not improve from 0.56951
#
# Epoch 00080: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 81/200
# 25569/25569 [==============================] - 48s 2ms/step - loss: 0.4952 - acc: 0.9435 - f1: 0.5048 - val_loss: 0.5814 - val_acc: 0.9270 - val_f1: 0.4186
#
# Epoch 00081: val_loss did not improve from 0.56951
#
# Epoch 00081: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 82/200
# 25569/25569 [==============================] - 47s 2ms/step - loss: 0.5207 - acc: 0.9419 - f1: 0.4793 - val_loss: 0.5761 - val_acc: 0.9243 - val_f1: 0.4239
#
# Epoch 00082: val_loss did not improve from 0.56951
#
# Epoch 00082: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 83/200
# 25569/25569 [==============================] - 47s 2ms/step - loss: 0.5155 - acc: 0.9437 - f1: 0.4845 - val_loss: 0.5784 - val_acc: 0.9234 - val_f1: 0.4216
#
# Epoch 00083: val_loss did not improve from 0.56951
#
# Epoch 00083: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 84/200
# 25569/25569 [==============================] - 48s 2ms/step - loss: 0.5142 - acc: 0.9416 - f1: 0.4858 - val_loss: 0.5802 - val_acc: 0.9252 - val_f1: 0.4198
#
# Epoch 00084: val_loss did not improve from 0.56951
#
# Epoch 00084: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 85/200
# 25569/25569 [==============================] - 47s 2ms/step - loss: 0.5020 - acc: 0.9440 - f1: 0.4980 - val_loss: 0.5784 - val_acc: 0.9285 - val_f1: 0.4216
#
# Epoch 00085: val_loss did not improve from 0.56951
#
# Epoch 00085: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 86/200
# 25569/25569 [==============================] - 47s 2ms/step - loss: 0.4987 - acc: 0.9444 - f1: 0.5013 - val_loss: 0.5751 - val_acc: 0.9240 - val_f1: 0.4249
#
# Epoch 00086: val_loss did not improve from 0.56951
#
# Epoch 00086: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 87/200
# 25569/25569 [==============================] - 47s 2ms/step - loss: 0.5152 - acc: 0.9424 - f1: 0.4848 - val_loss: 0.5754 - val_acc: 0.9238 - val_f1: 0.4246
#
# Epoch 00087: val_loss did not improve from 0.56951
#
# Epoch 00087: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 88/200
# 25569/25569 [==============================] - 48s 2ms/step - loss: 0.5048 - acc: 0.9423 - f1: 0.4952 - val_loss: 0.5752 - val_acc: 0.9246 - val_f1: 0.4248
#
# Epoch 00088: val_loss did not improve from 0.56951
#
# Epoch 00088: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 89/200
# 25569/25569 [==============================] - 48s 2ms/step - loss: 0.5114 - acc: 0.9436 - f1: 0.4886 - val_loss: 0.5781 - val_acc: 0.9279 - val_f1: 0.4219
#
# Epoch 00089: val_loss did not improve from 0.56951
#
# Epoch 00089: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 90/200
# 25569/25569 [==============================] - 48s 2ms/step - loss: 0.5063 - acc: 0.9445 - f1: 0.4937 - val_loss: 0.5683 - val_acc: 0.9252 - val_f1: 0.4317
#
# Epoch 00090: val_loss improved from 0.56951 to 0.56830, saving model to ../model_wehigts/6_w.hdf5
#
# Epoch 00090: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 91/200
# 25569/25569 [==============================] - 47s 2ms/step - loss: 0.5015 - acc: 0.9424 - f1: 0.4985 - val_loss: 0.5750 - val_acc: 0.9279 - val_f1: 0.4250
#
# Epoch 00091: val_loss did not improve from 0.56830
#
# Epoch 00091: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 92/200
# 25569/25569 [==============================] - 48s 2ms/step - loss: 0.4967 - acc: 0.9446 - f1: 0.5033 - val_loss: 0.5730 - val_acc: 0.9259 - val_f1: 0.4270
#
# Epoch 00092: val_loss did not improve from 0.56830
#
# Epoch 00092: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 93/200
# 25569/25569 [==============================] - 48s 2ms/step - loss: 0.5109 - acc: 0.9432 - f1: 0.4891 - val_loss: 0.5699 - val_acc: 0.9288 - val_f1: 0.4301
#
# Epoch 00093: val_loss did not improve from 0.56830
#
# Epoch 00093: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 94/200
# 25569/25569 [==============================] - 47s 2ms/step - loss: 0.5081 - acc: 0.9447 - f1: 0.4919 - val_loss: 0.5697 - val_acc: 0.9248 - val_f1: 0.4303
#
# Epoch 00094: val_loss did not improve from 0.56830
#
# Epoch 00094: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 95/200
# 25569/25569 [==============================] - 48s 2ms/step - loss: 0.5061 - acc: 0.9416 - f1: 0.4939 - val_loss: 0.5679 - val_acc: 0.9295 - val_f1: 0.4321
#
# Epoch 00095: val_loss improved from 0.56830 to 0.56794, saving model to ../model_wehigts/6_w.hdf5
#
# Epoch 00095: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 96/200
# 25569/25569 [==============================] - 48s 2ms/step - loss: 0.4980 - acc: 0.9432 - f1: 0.5020 - val_loss: 0.5696 - val_acc: 0.9274 - val_f1: 0.4304
#
# Epoch 00096: val_loss did not improve from 0.56794
#
# Epoch 00096: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 97/200
# 25569/25569 [==============================] - 48s 2ms/step - loss: 0.5133 - acc: 0.9412 - f1: 0.4867 - val_loss: 0.5727 - val_acc: 0.9243 - val_f1: 0.4273
#
# Epoch 00097: val_loss did not improve from 0.56794
#
# Epoch 00097: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 98/200
# 25569/25569 [==============================] - 48s 2ms/step - loss: 0.5041 - acc: 0.9433 - f1: 0.4959 - val_loss: 0.5737 - val_acc: 0.9274 - val_f1: 0.4263
#
# Epoch 00098: val_loss did not improve from 0.56794
#
# Epoch 00098: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 99/200
# 25569/25569 [==============================] - 48s 2ms/step - loss: 0.5103 - acc: 0.9429 - f1: 0.4897 - val_loss: 0.5769 - val_acc: 0.9263 - val_f1: 0.4231
#
# Epoch 00099: val_loss did not improve from 0.56794
#
# Epoch 00099: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 100/200
# 25569/25569 [==============================] - 47s 2ms/step - loss: 0.5070 - acc: 0.9463 - f1: 0.4930 - val_loss: 0.5786 - val_acc: 0.9290 - val_f1: 0.4214
#
# Epoch 00100: val_loss did not improve from 0.56794
#
# Epoch 00100: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 101/200
# 25569/25569 [==============================] - 48s 2ms/step - loss: 0.4950 - acc: 0.9458 - f1: 0.5050 - val_loss: 0.5750 - val_acc: 0.9291 - val_f1: 0.4250
#
# Epoch 00101: val_loss did not improve from 0.56794
#
# Epoch 00101: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 102/200
# 25569/25569 [==============================] - 47s 2ms/step - loss: 0.5001 - acc: 0.9462 - f1: 0.4999 - val_loss: 0.5739 - val_acc: 0.9291 - val_f1: 0.4261
#
# Epoch 00102: val_loss did not improve from 0.56794
#
# Epoch 00102: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 103/200
# 25569/25569 [==============================] - 48s 2ms/step - loss: 0.5038 - acc: 0.9461 - f1: 0.4962 - val_loss: 0.5731 - val_acc: 0.9302 - val_f1: 0.4269
#
# Epoch 00103: val_loss did not improve from 0.56794
#
# Epoch 00103: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 104/200
# 25569/25569 [==============================] - 48s 2ms/step - loss: 0.4814 - acc: 0.9461 - f1: 0.5186 - val_loss: 0.5752 - val_acc: 0.9290 - val_f1: 0.4248
#
# Epoch 00104: val_loss did not improve from 0.56794
#
# Epoch 00104: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 105/200
# 25569/25569 [==============================] - 47s 2ms/step - loss: 0.4966 - acc: 0.9459 - f1: 0.5034 - val_loss: 0.5747 - val_acc: 0.9284 - val_f1: 0.4253
#
# Epoch 00105: val_loss did not improve from 0.56794
#
# Epoch 00105: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 106/200
# 25569/25569 [==============================] - 48s 2ms/step - loss: 0.4973 - acc: 0.9447 - f1: 0.5027 - val_loss: 0.5750 - val_acc: 0.9276 - val_f1: 0.4250
#
# Epoch 00106: val_loss did not improve from 0.56794
#
# Epoch 00106: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 107/200
# 25569/25569 [==============================] - 48s 2ms/step - loss: 0.4990 - acc: 0.9449 - f1: 0.5010 - val_loss: 0.5732 - val_acc: 0.9277 - val_f1: 0.4268
#
# Epoch 00107: val_loss did not improve from 0.56794
#
# Epoch 00107: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 108/200
# 25569/25569 [==============================] - 47s 2ms/step - loss: 0.4912 - acc: 0.9445 - f1: 0.5088 - val_loss: 0.5718 - val_acc: 0.9277 - val_f1: 0.4282
#
# Epoch 00108: val_loss did not improve from 0.56794
#
# Epoch 00108: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 109/200
# 25569/25569 [==============================] - 48s 2ms/step - loss: 0.4906 - acc: 0.9435 - f1: 0.5094 - val_loss: 0.5716 - val_acc: 0.9257 - val_f1: 0.4284
#
# Epoch 00109: val_loss did not improve from 0.56794
#
# Epoch 00109: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 110/200
# 25569/25569 [==============================] - 48s 2ms/step - loss: 0.5066 - acc: 0.9433 - f1: 0.4934 - val_loss: 0.5729 - val_acc: 0.9277 - val_f1: 0.4271
#
# Epoch 00110: val_loss did not improve from 0.56794
#
# Epoch 00110: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 111/200
# 25569/25569 [==============================] - 48s 2ms/step - loss: 0.4729 - acc: 0.9461 - f1: 0.5271 - val_loss: 0.5743 - val_acc: 0.9295 - val_f1: 0.4257
#
# Epoch 00111: val_loss did not improve from 0.56794
#
# Epoch 00111: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 112/200
# 25569/25569 [==============================] - 48s 2ms/step - loss: 0.4830 - acc: 0.9463 - f1: 0.5170 - val_loss: 0.5725 - val_acc: 0.9285 - val_f1: 0.4275
#
# Epoch 00112: val_loss did not improve from 0.56794
#
# Epoch 00112: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 113/200
# 25569/25569 [==============================] - 48s 2ms/step - loss: 0.4821 - acc: 0.9472 - f1: 0.5179 - val_loss: 0.5729 - val_acc: 0.9288 - val_f1: 0.4271
#
# Epoch 00113: val_loss did not improve from 0.56794
#
# Epoch 00113: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 114/200
# 25569/25569 [==============================] - 48s 2ms/step - loss: 0.4846 - acc: 0.9468 - f1: 0.5154 - val_loss: 0.5731 - val_acc: 0.9288 - val_f1: 0.4269
#
# Epoch 00114: val_loss did not improve from 0.56794
#
# Epoch 00114: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 115/200
# 25569/25569 [==============================] - 48s 2ms/step - loss: 0.4938 - acc: 0.9460 - f1: 0.5062 - val_loss: 0.5728 - val_acc: 0.9290 - val_f1: 0.4272
#
# Epoch 00115: val_loss did not improve from 0.56794
#
# Epoch 00115: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 116/200
# 25569/25569 [==============================] - 47s 2ms/step - loss: 0.4860 - acc: 0.9474 - f1: 0.5140 - val_loss: 0.5692 - val_acc: 0.9295 - val_f1: 0.4308
#
# Epoch 00116: val_loss did not improve from 0.56794
#
# Epoch 00116: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 117/200
# 25569/25569 [==============================] - 48s 2ms/step - loss: 0.4839 - acc: 0.9465 - f1: 0.5161 - val_loss: 0.5681 - val_acc: 0.9291 - val_f1: 0.4319
#
# Epoch 00117: val_loss did not improve from 0.56794
#
# Epoch 00117: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 118/200
# 25569/25569 [==============================] - 48s 2ms/step - loss: 0.4778 - acc: 0.9457 - f1: 0.5222 - val_loss: 0.5677 - val_acc: 0.9284 - val_f1: 0.4323
#
# Epoch 00118: val_loss improved from 0.56794 to 0.56769, saving model to ../model_wehigts/6_w.hdf5
#
# Epoch 00118: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 119/200
# 25569/25569 [==============================] - 48s 2ms/step - loss: 0.4839 - acc: 0.9461 - f1: 0.5161 - val_loss: 0.5693 - val_acc: 0.9287 - val_f1: 0.4307
#
# Epoch 00119: val_loss did not improve from 0.56769
#
# Epoch 00119: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 120/200
# 25569/25569 [==============================] - 47s 2ms/step - loss: 0.4902 - acc: 0.9457 - f1: 0.5098 - val_loss: 0.5709 - val_acc: 0.9284 - val_f1: 0.4291
#
# Epoch 00120: val_loss did not improve from 0.56769
#
# Epoch 00120: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 121/200
# 25569/25569 [==============================] - 48s 2ms/step - loss: 0.5011 - acc: 0.9435 - f1: 0.4989 - val_loss: 0.5710 - val_acc: 0.9280 - val_f1: 0.4290
#
# Epoch 00121: val_loss did not improve from 0.56769
#
# Epoch 00121: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 122/200
# 25569/25569 [==============================] - 48s 2ms/step - loss: 0.4716 - acc: 0.9460 - f1: 0.5284 - val_loss: 0.5711 - val_acc: 0.9290 - val_f1: 0.4289
#
# Epoch 00122: val_loss did not improve from 0.56769
#
# Epoch 00122: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 123/200
# 25569/25569 [==============================] - 48s 2ms/step - loss: 0.4791 - acc: 0.9479 - f1: 0.5209 - val_loss: 0.5706 - val_acc: 0.9288 - val_f1: 0.4294
#
# Epoch 00123: val_loss did not improve from 0.56769
#
# Epoch 00123: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 124/200
# 25569/25569 [==============================] - 48s 2ms/step - loss: 0.4929 - acc: 0.9475 - f1: 0.5071 - val_loss: 0.5699 - val_acc: 0.9285 - val_f1: 0.4301
#
# Epoch 00124: val_loss did not improve from 0.56769
#
# Epoch 00124: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 125/200
# 25569/25569 [==============================] - 48s 2ms/step - loss: 0.4887 - acc: 0.9467 - f1: 0.5113 - val_loss: 0.5679 - val_acc: 0.9291 - val_f1: 0.4321
#
# Epoch 00125: val_loss did not improve from 0.56769
#
# Epoch 00125: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 126/200
# 25569/25569 [==============================] - 48s 2ms/step - loss: 0.4693 - acc: 0.9473 - f1: 0.5307 - val_loss: 0.5669 - val_acc: 0.9288 - val_f1: 0.4331
#
# Epoch 00126: val_loss improved from 0.56769 to 0.56689, saving model to ../model_wehigts/6_w.hdf5
#
# Epoch 00126: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 127/200
# 25569/25569 [==============================] - 48s 2ms/step - loss: 0.4795 - acc: 0.9460 - f1: 0.5205 - val_loss: 0.5651 - val_acc: 0.9277 - val_f1: 0.4349
#
# Epoch 00127: val_loss improved from 0.56689 to 0.56507, saving model to ../model_wehigts/6_w.hdf5
#
# Epoch 00127: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 128/200
# 25569/25569 [==============================] - 49s 2ms/step - loss: 0.4856 - acc: 0.9460 - f1: 0.5144 - val_loss: 0.5650 - val_acc: 0.9285 - val_f1: 0.4350
#
# Epoch 00128: val_loss improved from 0.56507 to 0.56497, saving model to ../model_wehigts/6_w.hdf5
#
# Epoch 00128: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 129/200
# 25569/25569 [==============================] - 48s 2ms/step - loss: 0.4809 - acc: 0.9454 - f1: 0.5191 - val_loss: 0.5643 - val_acc: 0.9270 - val_f1: 0.4357
#
# Epoch 00129: val_loss improved from 0.56497 to 0.56428, saving model to ../model_wehigts/6_w.hdf5
#
# Epoch 00129: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 130/200
# 25569/25569 [==============================] - 48s 2ms/step - loss: 0.4932 - acc: 0.9460 - f1: 0.5068 - val_loss: 0.5657 - val_acc: 0.9277 - val_f1: 0.4343
#
# Epoch 00130: val_loss did not improve from 0.56428
#
# Epoch 00130: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 131/200
# 25569/25569 [==============================] - 48s 2ms/step - loss: 0.4820 - acc: 0.9468 - f1: 0.5180 - val_loss: 0.5651 - val_acc: 0.9285 - val_f1: 0.4349
#
# Epoch 00131: val_loss did not improve from 0.56428
#
# Epoch 00131: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 132/200
# 25569/25569 [==============================] - 48s 2ms/step - loss: 0.4789 - acc: 0.9456 - f1: 0.5211 - val_loss: 0.5676 - val_acc: 0.9287 - val_f1: 0.4324
#
# Epoch 00132: val_loss did not improve from 0.56428
#
# Epoch 00132: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 133/200
# 25569/25569 [==============================] - 48s 2ms/step - loss: 0.4928 - acc: 0.9466 - f1: 0.5072 - val_loss: 0.5680 - val_acc: 0.9288 - val_f1: 0.4320
#
# Epoch 00133: val_loss did not improve from 0.56428
#
# Epoch 00133: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 134/200
# 25569/25569 [==============================] - 48s 2ms/step - loss: 0.4827 - acc: 0.9475 - f1: 0.5173 - val_loss: 0.5691 - val_acc: 0.9295 - val_f1: 0.4309
#
# Epoch 00134: val_loss did not improve from 0.56428
#
# Epoch 00134: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 135/200
# 25569/25569 [==============================] - 48s 2ms/step - loss: 0.4797 - acc: 0.9466 - f1: 0.5203 - val_loss: 0.5669 - val_acc: 0.9284 - val_f1: 0.4331
#
# Epoch 00135: val_loss did not improve from 0.56428
#
# Epoch 00135: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 136/200
# 25569/25569 [==============================] - 48s 2ms/step - loss: 0.4833 - acc: 0.9483 - f1: 0.5167 - val_loss: 0.5680 - val_acc: 0.9288 - val_f1: 0.4320
#
# Epoch 00136: val_loss did not improve from 0.56428
#
# Epoch 00136: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 137/200
# 25569/25569 [==============================] - 48s 2ms/step - loss: 0.4798 - acc: 0.9487 - f1: 0.5202 - val_loss: 0.5674 - val_acc: 0.9295 - val_f1: 0.4326
#
# Epoch 00137: val_loss did not improve from 0.56428
#
# Epoch 00137: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 138/200
# 25569/25569 [==============================] - 48s 2ms/step - loss: 0.4815 - acc: 0.9503 - f1: 0.5185 - val_loss: 0.5670 - val_acc: 0.9301 - val_f1: 0.4330
#
# Epoch 00138: val_loss did not improve from 0.56428
#
# Epoch 00138: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 139/200
# 25569/25569 [==============================] - 48s 2ms/step - loss: 0.4789 - acc: 0.9478 - f1: 0.5211 - val_loss: 0.5634 - val_acc: 0.9290 - val_f1: 0.4366
#
# Epoch 00139: val_loss improved from 0.56428 to 0.56340, saving model to ../model_wehigts/6_w.hdf5
#
# Epoch 00139: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 140/200
# 25569/25569 [==============================] - 48s 2ms/step - loss: 0.4771 - acc: 0.9477 - f1: 0.5229 - val_loss: 0.5645 - val_acc: 0.9302 - val_f1: 0.4355
#
# Epoch 00140: val_loss did not improve from 0.56340
#
# Epoch 00140: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 141/200
# 25569/25569 [==============================] - 48s 2ms/step - loss: 0.4894 - acc: 0.9476 - f1: 0.5106 - val_loss: 0.5651 - val_acc: 0.9296 - val_f1: 0.4349
#
# Epoch 00141: val_loss did not improve from 0.56340
#
# Epoch 00141: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 142/200
# 25569/25569 [==============================] - 48s 2ms/step - loss: 0.4842 - acc: 0.9486 - f1: 0.5158 - val_loss: 0.5679 - val_acc: 0.9296 - val_f1: 0.4321
#
# Epoch 00142: val_loss did not improve from 0.56340
#
# Epoch 00142: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 143/200
# 25569/25569 [==============================] - 48s 2ms/step - loss: 0.4732 - acc: 0.9494 - f1: 0.5268 - val_loss: 0.5673 - val_acc: 0.9298 - val_f1: 0.4327
#
# Epoch 00143: val_loss did not improve from 0.56340
#
# Epoch 00143: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 144/200
# 25569/25569 [==============================] - 48s 2ms/step - loss: 0.4854 - acc: 0.9486 - f1: 0.5146 - val_loss: 0.5674 - val_acc: 0.9304 - val_f1: 0.4326
#
# Epoch 00144: val_loss did not improve from 0.56340
#
# Epoch 00144: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 145/200
# 25569/25569 [==============================] - 48s 2ms/step - loss: 0.4839 - acc: 0.9495 - f1: 0.5161 - val_loss: 0.5675 - val_acc: 0.9307 - val_f1: 0.4325
#
# Epoch 00145: val_loss did not improve from 0.56340
#
# Epoch 00145: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 146/200
# 25569/25569 [==============================] - 48s 2ms/step - loss: 0.4891 - acc: 0.9470 - f1: 0.5109 - val_loss: 0.5662 - val_acc: 0.9276 - val_f1: 0.4338
#
# Epoch 00146: val_loss did not improve from 0.56340
#
# Epoch 00146: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 147/200
# 25569/25569 [==============================] - 48s 2ms/step - loss: 0.4917 - acc: 0.9453 - f1: 0.5083 - val_loss: 0.5661 - val_acc: 0.9279 - val_f1: 0.4339
#
# Epoch 00147: val_loss did not improve from 0.56340
#
# Epoch 00147: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 148/200
# 25569/25569 [==============================] - 49s 2ms/step - loss: 0.4654 - acc: 0.9482 - f1: 0.5346 - val_loss: 0.5672 - val_acc: 0.9291 - val_f1: 0.4328
#
# Epoch 00148: val_loss did not improve from 0.56340
#
# Epoch 00148: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 149/200
# 25569/25569 [==============================] - 48s 2ms/step - loss: 0.4804 - acc: 0.9469 - f1: 0.5196 - val_loss: 0.5622 - val_acc: 0.9284 - val_f1: 0.4378
#
# Epoch 00149: val_loss improved from 0.56340 to 0.56218, saving model to ../model_wehigts/6_w.hdf5
#
# Epoch 00149: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 150/200
# 25569/25569 [==============================] - 47s 2ms/step - loss: 0.4693 - acc: 0.9471 - f1: 0.5307 - val_loss: 0.5621 - val_acc: 0.9284 - val_f1: 0.4379
#
# Epoch 00150: val_loss improved from 0.56218 to 0.56213, saving model to ../model_wehigts/6_w.hdf5
#
# Epoch 00150: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 151/200
# 25569/25569 [==============================] - 47s 2ms/step - loss: 0.4789 - acc: 0.9463 - f1: 0.5211 - val_loss: 0.5647 - val_acc: 0.9285 - val_f1: 0.4353
#
# Epoch 00151: val_loss did not improve from 0.56213
#
# Epoch 00151: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 152/200
# 25569/25569 [==============================] - 48s 2ms/step - loss: 0.4895 - acc: 0.9464 - f1: 0.5105 - val_loss: 0.5653 - val_acc: 0.9287 - val_f1: 0.4347
#
# Epoch 00152: val_loss did not improve from 0.56213
#
# Epoch 00152: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 153/200
# 25569/25569 [==============================] - 48s 2ms/step - loss: 0.4816 - acc: 0.9467 - f1: 0.5184 - val_loss: 0.5652 - val_acc: 0.9285 - val_f1: 0.4348
#
# Epoch 00153: val_loss did not improve from 0.56213
#
# Epoch 00153: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 154/200
# 25569/25569 [==============================] - 48s 2ms/step - loss: 0.4844 - acc: 0.9474 - f1: 0.5156 - val_loss: 0.5646 - val_acc: 0.9285 - val_f1: 0.4354
#
# Epoch 00154: val_loss did not improve from 0.56213
#
# Epoch 00154: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 155/200
# 25569/25569 [==============================] - 48s 2ms/step - loss: 0.4871 - acc: 0.9472 - f1: 0.5129 - val_loss: 0.5645 - val_acc: 0.9285 - val_f1: 0.4355
#
# Epoch 00155: val_loss did not improve from 0.56213
#
# Epoch 00155: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 156/200
# 25569/25569 [==============================] - 48s 2ms/step - loss: 0.4962 - acc: 0.9466 - f1: 0.5038 - val_loss: 0.5644 - val_acc: 0.9287 - val_f1: 0.4356
#
# Epoch 00156: val_loss did not improve from 0.56213
#
# Epoch 00156: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 157/200
# 25569/25569 [==============================] - 48s 2ms/step - loss: 0.4788 - acc: 0.9479 - f1: 0.5212 - val_loss: 0.5641 - val_acc: 0.9285 - val_f1: 0.4359
#
# Epoch 00157: val_loss did not improve from 0.56213
#
# Epoch 00157: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 158/200
# 25569/25569 [==============================] - 48s 2ms/step - loss: 0.4870 - acc: 0.9468 - f1: 0.5130 - val_loss: 0.5638 - val_acc: 0.9285 - val_f1: 0.4362
#
# Epoch 00158: val_loss did not improve from 0.56213
#
# Epoch 00158: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 159/200
# 25569/25569 [==============================] - 48s 2ms/step - loss: 0.4822 - acc: 0.9473 - f1: 0.5178 - val_loss: 0.5634 - val_acc: 0.9285 - val_f1: 0.4366
#
# Epoch 00159: val_loss did not improve from 0.56213
#
# Epoch 00159: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 160/200
# 25569/25569 [==============================] - 48s 2ms/step - loss: 0.4594 - acc: 0.9504 - f1: 0.5406 - val_loss: 0.5637 - val_acc: 0.9287 - val_f1: 0.4363
#
# Epoch 00160: val_loss did not improve from 0.56213
#
# Epoch 00160: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 161/200
# 25569/25569 [==============================] - 48s 2ms/step - loss: 0.4681 - acc: 0.9484 - f1: 0.5319 - val_loss: 0.5643 - val_acc: 0.9288 - val_f1: 0.4357
#
# Epoch 00161: val_loss did not improve from 0.56213
#
# Epoch 00161: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 162/200
# 25569/25569 [==============================] - 48s 2ms/step - loss: 0.4706 - acc: 0.9490 - f1: 0.5294 - val_loss: 0.5639 - val_acc: 0.9287 - val_f1: 0.4361
#
# Epoch 00162: val_loss did not improve from 0.56213
#
# Epoch 00162: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 163/200
# 25569/25569 [==============================] - 48s 2ms/step - loss: 0.4983 - acc: 0.9465 - f1: 0.5017 - val_loss: 0.5638 - val_acc: 0.9285 - val_f1: 0.4362
#
# Epoch 00163: val_loss did not improve from 0.56213
#
# Epoch 00163: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 164/200
# 25569/25569 [==============================] - 48s 2ms/step - loss: 0.4793 - acc: 0.9473 - f1: 0.5207 - val_loss: 0.5637 - val_acc: 0.9285 - val_f1: 0.4363
#
# Epoch 00164: val_loss did not improve from 0.56213
#
# Epoch 00164: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 165/200
# 25569/25569 [==============================] - 48s 2ms/step - loss: 0.4853 - acc: 0.9475 - f1: 0.5147 - val_loss: 0.5634 - val_acc: 0.9288 - val_f1: 0.4366
#
# Epoch 00165: val_loss did not improve from 0.56213
#
# Epoch 00165: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 166/200
# 25569/25569 [==============================] - 48s 2ms/step - loss: 0.4729 - acc: 0.9473 - f1: 0.5271 - val_loss: 0.5636 - val_acc: 0.9287 - val_f1: 0.4364
#
# Epoch 00166: val_loss did not improve from 0.56213
#
# Epoch 00166: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 167/200
# 25569/25569 [==============================] - 48s 2ms/step - loss: 0.4733 - acc: 0.9495 - f1: 0.5267 - val_loss: 0.5640 - val_acc: 0.9288 - val_f1: 0.4360
#
# Epoch 00167: val_loss did not improve from 0.56213
#
# Epoch 00167: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 168/200
# 25569/25569 [==============================] - 48s 2ms/step - loss: 0.4654 - acc: 0.9475 - f1: 0.5346 - val_loss: 0.5634 - val_acc: 0.9287 - val_f1: 0.4366
#
# Epoch 00168: val_loss did not improve from 0.56213
#
# Epoch 00168: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 169/200
# 25569/25569 [==============================] - 48s 2ms/step - loss: 0.4733 - acc: 0.9472 - f1: 0.5267 - val_loss: 0.5637 - val_acc: 0.9287 - val_f1: 0.4363
#
# Epoch 00169: val_loss did not improve from 0.56213
#
# Epoch 00169: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 170/200
# 25569/25569 [==============================] - 48s 2ms/step - loss: 0.4843 - acc: 0.9478 - f1: 0.5157 - val_loss: 0.5639 - val_acc: 0.9288 - val_f1: 0.4361
#
# Epoch 00170: val_loss did not improve from 0.56213
#
# Epoch 00170: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 171/200
# 25569/25569 [==============================] - 48s 2ms/step - loss: 0.4852 - acc: 0.9495 - f1: 0.5148 - val_loss: 0.5641 - val_acc: 0.9287 - val_f1: 0.4359
#
# Epoch 00171: val_loss did not improve from 0.56213
#
# Epoch 00171: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 172/200
# 25569/25569 [==============================] - 48s 2ms/step - loss: 0.4846 - acc: 0.9468 - f1: 0.5154 - val_loss: 0.5643 - val_acc: 0.9290 - val_f1: 0.4357
#
# Epoch 00172: val_loss did not improve from 0.56213
#
# Epoch 00172: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 173/200
# 25569/25569 [==============================] - 48s 2ms/step - loss: 0.4576 - acc: 0.9488 - f1: 0.5424 - val_loss: 0.5643 - val_acc: 0.9291 - val_f1: 0.4357
#
# Epoch 00173: val_loss did not improve from 0.56213
#
# Epoch 00173: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 174/200
# 25569/25569 [==============================] - 48s 2ms/step - loss: 0.4720 - acc: 0.9485 - f1: 0.5280 - val_loss: 0.5645 - val_acc: 0.9288 - val_f1: 0.4355
#
# Epoch 00174: val_loss did not improve from 0.56213
#
# Epoch 00174: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 175/200
# 25569/25569 [==============================] - 48s 2ms/step - loss: 0.4877 - acc: 0.9479 - f1: 0.5123 - val_loss: 0.5643 - val_acc: 0.9290 - val_f1: 0.4357
#
# Epoch 00175: val_loss did not improve from 0.56213
#
# Epoch 00175: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 176/200
# 25569/25569 [==============================] - 47s 2ms/step - loss: 0.4756 - acc: 0.9493 - f1: 0.5244 - val_loss: 0.5642 - val_acc: 0.9290 - val_f1: 0.4358
#
# Epoch 00176: val_loss did not improve from 0.56213
#
# Epoch 00176: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 177/200
# 25569/25569 [==============================] - 48s 2ms/step - loss: 0.4759 - acc: 0.9482 - f1: 0.5241 - val_loss: 0.5642 - val_acc: 0.9288 - val_f1: 0.4358
#
# Epoch 00177: val_loss did not improve from 0.56213
#
# Epoch 00177: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 178/200
# 25569/25569 [==============================] - 48s 2ms/step - loss: 0.4812 - acc: 0.9470 - f1: 0.5188 - val_loss: 0.5642 - val_acc: 0.9288 - val_f1: 0.4358
#
# Epoch 00178: val_loss did not improve from 0.56213
#
# Epoch 00178: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 179/200
# 25569/25569 [==============================] - 48s 2ms/step - loss: 0.4733 - acc: 0.9472 - f1: 0.5267 - val_loss: 0.5643 - val_acc: 0.9288 - val_f1: 0.4357
#
# Epoch 00179: val_loss did not improve from 0.56213
#
# Epoch 00179: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 180/200
# 25569/25569 [==============================] - 48s 2ms/step - loss: 0.4785 - acc: 0.9483 - f1: 0.5215 - val_loss: 0.5642 - val_acc: 0.9288 - val_f1: 0.4358
#
# Epoch 00180: val_loss did not improve from 0.56213
#
# Epoch 00180: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 181/200
# 25569/25569 [==============================] - 48s 2ms/step - loss: 0.4804 - acc: 0.9471 - f1: 0.5196 - val_loss: 0.5640 - val_acc: 0.9288 - val_f1: 0.4360
#
# Epoch 00181: val_loss did not improve from 0.56213
#
# Epoch 00181: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 182/200
# 25569/25569 [==============================] - 48s 2ms/step - loss: 0.4902 - acc: 0.9471 - f1: 0.5098 - val_loss: 0.5636 - val_acc: 0.9290 - val_f1: 0.4364
#
# Epoch 00182: val_loss did not improve from 0.56213
#
# Epoch 00182: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 183/200
# 25569/25569 [==============================] - 48s 2ms/step - loss: 0.4699 - acc: 0.9488 - f1: 0.5301 - val_loss: 0.5639 - val_acc: 0.9288 - val_f1: 0.4361
#
# Epoch 00183: val_loss did not improve from 0.56213
#
# Epoch 00183: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 184/200
# 25569/25569 [==============================] - 48s 2ms/step - loss: 0.4689 - acc: 0.9489 - f1: 0.5311 - val_loss: 0.5637 - val_acc: 0.9288 - val_f1: 0.4363
#
# Epoch 00184: val_loss did not improve from 0.56213
#
# Epoch 00184: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 185/200
# 25569/25569 [==============================] - 48s 2ms/step - loss: 0.4747 - acc: 0.9493 - f1: 0.5253 - val_loss: 0.5633 - val_acc: 0.9290 - val_f1: 0.4367
#
# Epoch 00185: val_loss did not improve from 0.56213
#
# Epoch 00185: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 186/200
# 25569/25569 [==============================] - 48s 2ms/step - loss: 0.4756 - acc: 0.9492 - f1: 0.5244 - val_loss: 0.5638 - val_acc: 0.9288 - val_f1: 0.4362
#
# Epoch 00186: val_loss did not improve from 0.56213
#
# Epoch 00186: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 187/200
# 25569/25569 [==============================] - 48s 2ms/step - loss: 0.4830 - acc: 0.9463 - f1: 0.5170 - val_loss: 0.5639 - val_acc: 0.9288 - val_f1: 0.4361
#
# Epoch 00187: val_loss did not improve from 0.56213
#
# Epoch 00187: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 188/200
# 25569/25569 [==============================] - 48s 2ms/step - loss: 0.4793 - acc: 0.9480 - f1: 0.5207 - val_loss: 0.5641 - val_acc: 0.9290 - val_f1: 0.4359
#
# Epoch 00188: val_loss did not improve from 0.56213
#
# Epoch 00188: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 189/200
# 25569/25569 [==============================] - 48s 2ms/step - loss: 0.4640 - acc: 0.9482 - f1: 0.5360 - val_loss: 0.5639 - val_acc: 0.9287 - val_f1: 0.4361
#
# Epoch 00189: val_loss did not improve from 0.56213
#
# Epoch 00189: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 190/200
# 25569/25569 [==============================] - 48s 2ms/step - loss: 0.4744 - acc: 0.9479 - f1: 0.5256 - val_loss: 0.5640 - val_acc: 0.9287 - val_f1: 0.4360
#
# Epoch 00190: val_loss did not improve from 0.56213
#
# Epoch 00190: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 191/200
# 25569/25569 [==============================] - 48s 2ms/step - loss: 0.4750 - acc: 0.9470 - f1: 0.5250 - val_loss: 0.5642 - val_acc: 0.9288 - val_f1: 0.4358
#
# Epoch 00191: val_loss did not improve from 0.56213
#
# Epoch 00191: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 192/200
# 25569/25569 [==============================] - 48s 2ms/step - loss: 0.4841 - acc: 0.9470 - f1: 0.5159 - val_loss: 0.5642 - val_acc: 0.9285 - val_f1: 0.4358
#
# Epoch 00192: val_loss did not improve from 0.56213
#
# Epoch 00192: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 193/200
# 25569/25569 [==============================] - 48s 2ms/step - loss: 0.4915 - acc: 0.9475 - f1: 0.5085 - val_loss: 0.5639 - val_acc: 0.9285 - val_f1: 0.4361
#
# Epoch 00193: val_loss did not improve from 0.56213
#
# Epoch 00193: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 194/200
# 25569/25569 [==============================] - 48s 2ms/step - loss: 0.4779 - acc: 0.9467 - f1: 0.5221 - val_loss: 0.5638 - val_acc: 0.9287 - val_f1: 0.4362
#
# Epoch 00194: val_loss did not improve from 0.56213
#
# Epoch 00194: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 195/200
# 25569/25569 [==============================] - 48s 2ms/step - loss: 0.4817 - acc: 0.9468 - f1: 0.5183 - val_loss: 0.5641 - val_acc: 0.9287 - val_f1: 0.4359
#
# Epoch 00195: val_loss did not improve from 0.56213
#
# Epoch 00195: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 196/200
# 25569/25569 [==============================] - 48s 2ms/step - loss: 0.4923 - acc: 0.9471 - f1: 0.5077 - val_loss: 0.5645 - val_acc: 0.9290 - val_f1: 0.4355
#
# Epoch 00196: val_loss did not improve from 0.56213
#
# Epoch 00196: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 197/200
# 25569/25569 [==============================] - 48s 2ms/step - loss: 0.4817 - acc: 0.9483 - f1: 0.5183 - val_loss: 0.5645 - val_acc: 0.9290 - val_f1: 0.4355
#
# Epoch 00197: val_loss did not improve from 0.56213
#
# Epoch 00197: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 198/200
# 25569/25569 [==============================] - 48s 2ms/step - loss: 0.4706 - acc: 0.9483 - f1: 0.5294 - val_loss: 0.5649 - val_acc: 0.9290 - val_f1: 0.4351
#
# Epoch 00198: val_loss did not improve from 0.56213
#
# Epoch 00198: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 199/200
# 25569/25569 [==============================] - 48s 2ms/step - loss: 0.4781 - acc: 0.9472 - f1: 0.5219 - val_loss: 0.5649 - val_acc: 0.9290 - val_f1: 0.4351
#
# Epoch 00199: val_loss did not improve from 0.56213
#
# Epoch 00199: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 200/200
# 25569/25569 [==============================] - 48s 2ms/step - loss: 0.4724 - acc: 0.9484 - f1: 0.5276 - val_loss: 0.5650 - val_acc: 0.9290 - val_f1: 0.4350
#
# Epoch 00200: val_loss did not improve from 0.56213
#
# Epoch 00200: saving model to ../model_wehigts/6_ch.hdf5

# %%
from sklearn.metrics import f1_score

#Load best model
model.load_weights(checkpoint_path)
y_pred = model.predict(x_val, batch_size=1)
y_pred = np.where(y_pred > 0.5, 1, 0)

print("Neural Network f1_sklearn: {}".format(f1_score(y_val, y_pred)))
# Out:
# Neural Network f1_sklearn: 0.5178947368421052
