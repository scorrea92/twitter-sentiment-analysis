# %% [markdown]
# # Train Numberbatch or Glove

# %%
import numpy as np
import pandas as pd 
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.layers import (
    Dense,
    Input,
    LSTM,
    Embedding,
    Dropout,
    Activation,
    SpatialDropout1D
)
from tensorflow.keras.models import Model, load_model
from tensorflow.keras.callbacks import ModelCheckpoint
from ast import literal_eval
from sklearn.model_selection import train_test_split
# Out:
# /Users/sebastiancorrea/anaconda3/lib/python3.6/importlib/_bootstrap.py:219: RuntimeWarning: compiletime version 3.5 of module 'tensorflow.python.framework.fast_tensor_util' does not match runtime version 3.6
#   return f(*args, **kwds)

# %%
df = pd.read_csv('../data/pandas_data_frame.csv', index_col=0)
all_data = df.where((pd.notnull(df)), '')
all_data['hashtag'] = all_data['hashtag'].apply(literal_eval)

full_text = all_data['tidy_tweet'][(all_data['label']==1.0) | (all_data['label']==0.0)]
y = all_data['label'][(all_data['label']==1.0) | (all_data['label']==0.0)]

# %%
tk = Tokenizer(lower=True, filters='')
tk.fit_on_texts(full_text)

train_tokenized = tk.texts_to_sequences(full_text)
max_len = 19
X = pad_sequences(train_tokenized, maxlen=max_len)

x_train, x_val, y_train, y_val = train_test_split(X, y, random_state=1992, test_size=0.2)

print(x_train.shape,y_train.shape)
print(x_val.shape,y_val.shape)
# Out:
# (25569, 19) (25569,)
# (6393, 19) (6393,)

# %%
import pickle

# saving
with open('../model_wehigts/tokenizer.pickle', 'wb') as handle:
    pickle.dump(tk, handle, protocol=pickle.HIGHEST_PROTOCOL)

# # loading
# with open('tokenizer.pickle', 'rb') as handle:
#     tokenizer = pickle.load(handle)

# %%
embedding_path = '../data/vectors/glove.twitter.27B/glove.twitter.27B.100d.txt'
# embedding_path = '../data/vectors/numberbatch-17.06.txt'
embed_size = 100

max_features = 30000

def get_coefs(word,*arr):
    return word, np.asarray(arr, dtype='float32')

embedding_index = dict(get_coefs(*o.strip().split(" ")) for o in open(embedding_path))

# %%
word_index = tk.word_index
nb_words = min(max_features, len(word_index))
embedding_matrix = np.zeros((nb_words + 1, embed_size))

for word, i in word_index.items():
    if i >= max_features: continue
    embedding_vector = embedding_index.get(word)
    if embedding_vector is not None: embedding_matrix[i] = embedding_vector

# %%
import sys
sys.path.append("../") 
from personal_library.sce_keras.loss_functions import f1_loss
from personal_library.sce_keras.metrics_functions import f1
from personal_library.sce_keras.callbacks import (
    LearningRateDecay,
    WarmUpCosineDecayScheduler
)


num_classes = 1
batch_size = 32
epochs = 200
learnRate = 0.001
lstm_out = 200
warmup_epoch = 20

lrate_decay = LearningRateDecay(epochs, learnRate).step_decay
warm_up_lr = WarmUpCosineDecayScheduler(learning_rate_base=learnRate,
                                        warmup_learning_rate=0,
                                        warmup_epoch=warmup_epoch,
                                        hold_base_rate_steps=5,
                                        verbose=0)

checkpoint_path = "../model_wehigts/6_w.hdf5"
checkpoint_path1 = "../model_wehigts/6_ch.hdf5"
checkpointer = ModelCheckpoint(filepath=checkpoint_path,
                               monitor='val_loss', verbose=2,
                               save_best_only=True, mode='min')
checkpointer1 = ModelCheckpoint(filepath=checkpoint_path1,
                               monitor='val_loss', verbose=2,
                               save_best_only=False, mode='min')

inp = Input(shape = (max_len,))
x = Embedding(nb_words+1, embed_size, weights = [embedding_matrix], trainable=False)(inp)
x = SpatialDropout1D(0.3)(x)
x = LSTM(lstm_out, dropout=0.5, recurrent_dropout=0.5)(x)
x = Dense(1, activation = "sigmoid")(x)

model = Model(inputs=inp, outputs=x)
model.summary()

# 'binary_crossentropy'
model.compile(loss=f1_loss, 
              optimizer='adam', 
              metrics=['accuracy', f1]) 

history = model.fit(x_train, y_train, 
                    batch_size=batch_size,
                    epochs=epochs,
                    verbose=1,
                    validation_data=(x_val, y_val),
                    callbacks=[checkpointer, checkpointer1, lrate_decay])
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, 19)                0
# _________________________________________________________________
# embedding (Embedding)        (None, 19, 100)           1516700
# _________________________________________________________________
# spatial_dropout1d (SpatialDr (None, 19, 100)           0
# _________________________________________________________________
# lstm (LSTM)                  (None, 200)               240800
# _________________________________________________________________
# dense (Dense)                (None, 1)                 201
# =================================================================
# Total params: 1,757,701
# Trainable params: 241,001
# Non-trainable params: 1,516,700
# _________________________________________________________________
# Train on 25569 samples, validate on 6393 samples
# Epoch 1/200
# 25569/25569 [==============================] - 42s 2ms/step - loss: 0.7582 - acc: 0.8201 - f1: 0.2418 - val_loss: 0.6976 - val_acc: 0.9076 - val_f1: 0.3024
#
# Epoch 00001: val_loss improved from inf to 0.69763, saving model to ../model_wehigts/6_w.hdf5
#
# Epoch 00001: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 2/200
# 25569/25569 [==============================] - 40s 2ms/step - loss: 0.7169 - acc: 0.8664 - f1: 0.2831 - val_loss: 0.6699 - val_acc: 0.9129 - val_f1: 0.3301
#
# Epoch 00002: val_loss improved from 0.69763 to 0.66988, saving model to ../model_wehigts/6_w.hdf5
#
# Epoch 00002: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 3/200
# 25569/25569 [==============================] - 39s 2ms/step - loss: 0.6907 - acc: 0.8908 - f1: 0.3093 - val_loss: 0.6912 - val_acc: 0.9273 - val_f1: 0.3088
#
# Epoch 00003: val_loss did not improve from 0.66988
#
# Epoch 00003: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 4/200
# 25569/25569 [==============================] - 40s 2ms/step - loss: 0.6734 - acc: 0.8987 - f1: 0.3266 - val_loss: 0.6459 - val_acc: 0.9071 - val_f1: 0.3541
#
# Epoch 00004: val_loss improved from 0.66988 to 0.64588, saving model to ../model_wehigts/6_w.hdf5
#
# Epoch 00004: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 5/200
# 25569/25569 [==============================] - 42s 2ms/step - loss: 0.6682 - acc: 0.9032 - f1: 0.3318 - val_loss: 0.6534 - val_acc: 0.9243 - val_f1: 0.3466
#
# Epoch 00005: val_loss did not improve from 0.64588
#
# Epoch 00005: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 6/200
# 25569/25569 [==============================] - 43s 2ms/step - loss: 0.6770 - acc: 0.9057 - f1: 0.3230 - val_loss: 0.6325 - val_acc: 0.9158 - val_f1: 0.3675
#
# Epoch 00006: val_loss improved from 0.64588 to 0.63251, saving model to ../model_wehigts/6_w.hdf5
#
# Epoch 00006: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 7/200
# 25569/25569 [==============================] - 44s 2ms/step - loss: 0.6617 - acc: 0.9050 - f1: 0.3383 - val_loss: 0.6699 - val_acc: 0.9345 - val_f1: 0.3301
#
# Epoch 00007: val_loss did not improve from 0.63251
#
# Epoch 00007: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 8/200
# 25569/25569 [==============================] - 46s 2ms/step - loss: 0.6560 - acc: 0.9128 - f1: 0.3440 - val_loss: 0.6361 - val_acc: 0.9165 - val_f1: 0.3639
#
# Epoch 00008: val_loss did not improve from 0.63251
#
# Epoch 00008: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 9/200
# 25569/25569 [==============================] - 40s 2ms/step - loss: 0.6657 - acc: 0.9048 - f1: 0.3343 - val_loss: 0.6495 - val_acc: 0.9238 - val_f1: 0.3505
#
# Epoch 00009: val_loss did not improve from 0.63251
#
# Epoch 00009: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 10/200
# 25569/25569 [==============================] - 36s 1ms/step - loss: 0.6611 - acc: 0.9095 - f1: 0.3389 - val_loss: 0.6407 - val_acc: 0.9199 - val_f1: 0.3593
#
# Epoch 00010: val_loss did not improve from 0.63251
#
# Epoch 00010: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 11/200
# 25569/25569 [==============================] - 36s 1ms/step - loss: 0.6491 - acc: 0.9031 - f1: 0.3509 - val_loss: 0.6256 - val_acc: 0.9107 - val_f1: 0.3744
#
# Epoch 00011: val_loss improved from 0.63251 to 0.62558, saving model to ../model_wehigts/6_w.hdf5
#
# Epoch 00011: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 12/200
# 25569/25569 [==============================] - 42s 2ms/step - loss: 0.6453 - acc: 0.8976 - f1: 0.3547 - val_loss: 0.6432 - val_acc: 0.9219 - val_f1: 0.3568
#
# Epoch 00012: val_loss did not improve from 0.62558
#
# Epoch 00012: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 13/200
# 25569/25569 [==============================] - 36s 1ms/step - loss: 0.6286 - acc: 0.9161 - f1: 0.3714 - val_loss: 0.6345 - val_acc: 0.9262 - val_f1: 0.3655
#
# Epoch 00013: val_loss did not improve from 0.62558
#
# Epoch 00013: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 14/200
# 25569/25569 [==============================] - 38s 1ms/step - loss: 0.6482 - acc: 0.9046 - f1: 0.3518 - val_loss: 0.6378 - val_acc: 0.9277 - val_f1: 0.3622
#
# Epoch 00014: val_loss did not improve from 0.62558
#
# Epoch 00014: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 15/200
# 25569/25569 [==============================] - 37s 1ms/step - loss: 0.6279 - acc: 0.9090 - f1: 0.3721 - val_loss: 0.6260 - val_acc: 0.9205 - val_f1: 0.3740
#
# Epoch 00015: val_loss did not improve from 0.62558
#
# Epoch 00015: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 16/200
# 25569/25569 [==============================] - 41s 2ms/step - loss: 0.6449 - acc: 0.9088 - f1: 0.3551 - val_loss: 0.6190 - val_acc: 0.9185 - val_f1: 0.3810
#
# Epoch 00016: val_loss improved from 0.62558 to 0.61896, saving model to ../model_wehigts/6_w.hdf5
#
# Epoch 00016: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 17/200
# 25569/25569 [==============================] - 45s 2ms/step - loss: 0.6249 - acc: 0.9094 - f1: 0.3751 - val_loss: 0.6287 - val_acc: 0.9162 - val_f1: 0.3713
#
# Epoch 00017: val_loss did not improve from 0.61896
#
# Epoch 00017: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 18/200
# 25569/25569 [==============================] - 43s 2ms/step - loss: 0.6227 - acc: 0.9102 - f1: 0.3773 - val_loss: 0.6109 - val_acc: 0.9058 - val_f1: 0.3891
#
# Epoch 00018: val_loss improved from 0.61896 to 0.61094, saving model to ../model_wehigts/6_w.hdf5
#
# Epoch 00018: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 19/200
# 25569/25569 [==============================] - 40s 2ms/step - loss: 0.6150 - acc: 0.9181 - f1: 0.3850 - val_loss: 0.6128 - val_acc: 0.9144 - val_f1: 0.3872
#
# Epoch 00019: val_loss did not improve from 0.61094
#
# Epoch 00019: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 20/200
# 25569/25569 [==============================] - 46s 2ms/step - loss: 0.6394 - acc: 0.9122 - f1: 0.3606 - val_loss: 0.6200 - val_acc: 0.9209 - val_f1: 0.3800
#
# Epoch 00020: val_loss did not improve from 0.61094
#
# Epoch 00020: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 21/200
# 25569/25569 [==============================] - 42s 2ms/step - loss: 0.6213 - acc: 0.9160 - f1: 0.3787 - val_loss: 0.6077 - val_acc: 0.9213 - val_f1: 0.3923
#
# Epoch 00021: val_loss improved from 0.61094 to 0.60770, saving model to ../model_wehigts/6_w.hdf5
#
# Epoch 00021: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 22/200
# 25569/25569 [==============================] - 43s 2ms/step - loss: 0.6162 - acc: 0.9206 - f1: 0.3838 - val_loss: 0.6042 - val_acc: 0.9182 - val_f1: 0.3958
#
# Epoch 00022: val_loss improved from 0.60770 to 0.60421, saving model to ../model_wehigts/6_w.hdf5
#
# Epoch 00022: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 23/200
# 25569/25569 [==============================] - 43s 2ms/step - loss: 0.6221 - acc: 0.9171 - f1: 0.3779 - val_loss: 0.6057 - val_acc: 0.9199 - val_f1: 0.3943
#
# Epoch 00023: val_loss did not improve from 0.60421
#
# Epoch 00023: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 24/200
# 25569/25569 [==============================] - 42s 2ms/step - loss: 0.6077 - acc: 0.9213 - f1: 0.3923 - val_loss: 0.6105 - val_acc: 0.9204 - val_f1: 0.3895
#
# Epoch 00024: val_loss did not improve from 0.60421
#
# Epoch 00024: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 25/200
# 25569/25569 [==============================] - 40s 2ms/step - loss: 0.6165 - acc: 0.9170 - f1: 0.3835 - val_loss: 0.6096 - val_acc: 0.9216 - val_f1: 0.3904
#
# Epoch 00025: val_loss did not improve from 0.60421
#
# Epoch 00025: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 26/200
# 25569/25569 [==============================] - 42s 2ms/step - loss: 0.6035 - acc: 0.9179 - f1: 0.3965 - val_loss: 0.6111 - val_acc: 0.9180 - val_f1: 0.3889
#
# Epoch 00026: val_loss did not improve from 0.60421
#
# Epoch 00026: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 27/200
# 25569/25569 [==============================] - 40s 2ms/step - loss: 0.6134 - acc: 0.9187 - f1: 0.3866 - val_loss: 0.6092 - val_acc: 0.9152 - val_f1: 0.3908
#
# Epoch 00027: val_loss did not improve from 0.60421
#
# Epoch 00027: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 28/200
# 25569/25569 [==============================] - 39s 2ms/step - loss: 0.6120 - acc: 0.9199 - f1: 0.3880 - val_loss: 0.6074 - val_acc: 0.9183 - val_f1: 0.3926
#
# Epoch 00028: val_loss did not improve from 0.60421
#
# Epoch 00028: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 29/200
# 25569/25569 [==============================] - 38s 1ms/step - loss: 0.6123 - acc: 0.9112 - f1: 0.3877 - val_loss: 0.6058 - val_acc: 0.9207 - val_f1: 0.3942
#
# Epoch 00029: val_loss did not improve from 0.60421
#
# Epoch 00029: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 30/200
# 25569/25569 [==============================] - 36s 1ms/step - loss: 0.6070 - acc: 0.9224 - f1: 0.3930 - val_loss: 0.6045 - val_acc: 0.9218 - val_f1: 0.3955
#
# Epoch 00030: val_loss did not improve from 0.60421
#
# Epoch 00030: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 31/200
# 25569/25569 [==============================] - 40s 2ms/step - loss: 0.6082 - acc: 0.9155 - f1: 0.3918 - val_loss: 0.6194 - val_acc: 0.9284 - val_f1: 0.3806
#
# Epoch 00031: val_loss did not improve from 0.60421
#
# Epoch 00031: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 32/200
# 25569/25569 [==============================] - 37s 1ms/step - loss: 0.6089 - acc: 0.9222 - f1: 0.3911 - val_loss: 0.6031 - val_acc: 0.9146 - val_f1: 0.3969
#
# Epoch 00032: val_loss improved from 0.60421 to 0.60312, saving model to ../model_wehigts/6_w.hdf5
#
# Epoch 00032: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 33/200
# 25569/25569 [==============================] - 37s 1ms/step - loss: 0.6096 - acc: 0.9200 - f1: 0.3904 - val_loss: 0.6041 - val_acc: 0.9133 - val_f1: 0.3959
#
# Epoch 00033: val_loss did not improve from 0.60312
#
# Epoch 00033: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 34/200
# 25569/25569 [==============================] - 37s 1ms/step - loss: 0.6090 - acc: 0.9247 - f1: 0.3910 - val_loss: 0.6046 - val_acc: 0.9199 - val_f1: 0.3954
#
# Epoch 00034: val_loss did not improve from 0.60312
#
# Epoch 00034: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 35/200
# 25569/25569 [==============================] - 36s 1ms/step - loss: 0.5942 - acc: 0.9206 - f1: 0.4058 - val_loss: 0.6099 - val_acc: 0.9163 - val_f1: 0.3901
#
# Epoch 00035: val_loss did not improve from 0.60312
#
# Epoch 00035: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 36/200
# 25569/25569 [==============================] - 37s 1ms/step - loss: 0.6039 - acc: 0.9201 - f1: 0.3961 - val_loss: 0.5956 - val_acc: 0.9171 - val_f1: 0.4044
#
# Epoch 00036: val_loss improved from 0.60312 to 0.59564, saving model to ../model_wehigts/6_w.hdf5
#
# Epoch 00036: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 37/200
# 25569/25569 [==============================] - 37s 1ms/step - loss: 0.6173 - acc: 0.9253 - f1: 0.3827 - val_loss: 0.5976 - val_acc: 0.9185 - val_f1: 0.4024
#
# Epoch 00037: val_loss did not improve from 0.59564
#
# Epoch 00037: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 38/200
# 25569/25569 [==============================] - 37s 1ms/step - loss: 0.5991 - acc: 0.9223 - f1: 0.4009 - val_loss: 0.5901 - val_acc: 0.9141 - val_f1: 0.4099
#
# Epoch 00038: val_loss improved from 0.59564 to 0.59014, saving model to ../model_wehigts/6_w.hdf5
#
# Epoch 00038: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 39/200
# 25569/25569 [==============================] - 37s 1ms/step - loss: 0.6179 - acc: 0.9210 - f1: 0.3821 - val_loss: 0.5947 - val_acc: 0.9190 - val_f1: 0.4053
#
# Epoch 00039: val_loss did not improve from 0.59014
#
# Epoch 00039: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 40/200
# 25569/25569 [==============================] - 42s 2ms/step - loss: 0.5997 - acc: 0.9256 - f1: 0.4003 - val_loss: 0.5940 - val_acc: 0.9276 - val_f1: 0.4060
#
# Epoch 00040: val_loss did not improve from 0.59014
#
# Epoch 00040: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 41/200
# 25569/25569 [==============================] - 47s 2ms/step - loss: 0.5957 - acc: 0.9251 - f1: 0.4043 - val_loss: 0.5957 - val_acc: 0.9140 - val_f1: 0.4043
#
# Epoch 00041: val_loss did not improve from 0.59014
#
# Epoch 00041: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 42/200
# 25569/25569 [==============================] - 47s 2ms/step - loss: 0.5901 - acc: 0.9269 - f1: 0.4099 - val_loss: 0.5909 - val_acc: 0.9185 - val_f1: 0.4091
#
# Epoch 00042: val_loss did not improve from 0.59014
#
# Epoch 00042: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 43/200
# 25569/25569 [==============================] - 48s 2ms/step - loss: 0.5979 - acc: 0.9274 - f1: 0.4021 - val_loss: 0.6008 - val_acc: 0.9176 - val_f1: 0.3992
#
# Epoch 00043: val_loss did not improve from 0.59014
#
# Epoch 00043: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 44/200
# 25569/25569 [==============================] - 47s 2ms/step - loss: 0.5996 - acc: 0.9267 - f1: 0.4004 - val_loss: 0.6022 - val_acc: 0.9218 - val_f1: 0.3978
#
# Epoch 00044: val_loss did not improve from 0.59014
#
# Epoch 00044: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 45/200
# 25569/25569 [==============================] - 47s 2ms/step - loss: 0.5881 - acc: 0.9219 - f1: 0.4119 - val_loss: 0.5951 - val_acc: 0.9154 - val_f1: 0.4049
#
# Epoch 00045: val_loss did not improve from 0.59014
#
# Epoch 00045: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 46/200
# 25569/25569 [==============================] - 48s 2ms/step - loss: 0.5872 - acc: 0.9276 - f1: 0.4128 - val_loss: 0.6000 - val_acc: 0.9160 - val_f1: 0.4000
#
# Epoch 00046: val_loss did not improve from 0.59014
#
# Epoch 00046: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 47/200
# 25569/25569 [==============================] - 48s 2ms/step - loss: 0.5836 - acc: 0.9272 - f1: 0.4164 - val_loss: 0.5949 - val_acc: 0.9248 - val_f1: 0.4051
#
# Epoch 00047: val_loss did not improve from 0.59014
#
# Epoch 00047: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 48/200
# 25569/25569 [==============================] - 48s 2ms/step - loss: 0.6031 - acc: 0.9299 - f1: 0.3969 - val_loss: 0.6042 - val_acc: 0.9265 - val_f1: 0.3958
#
# Epoch 00048: val_loss did not improve from 0.59014
#
# Epoch 00048: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 49/200
# 25569/25569 [==============================] - 49s 2ms/step - loss: 0.5952 - acc: 0.9265 - f1: 0.4048 - val_loss: 0.6020 - val_acc: 0.9337 - val_f1: 0.3980
#
# Epoch 00049: val_loss did not improve from 0.59014
#
# Epoch 00049: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 50/200
# 25569/25569 [==============================] - 49s 2ms/step - loss: 0.5814 - acc: 0.9310 - f1: 0.4186 - val_loss: 0.5906 - val_acc: 0.9099 - val_f1: 0.4094
#
# Epoch 00050: val_loss did not improve from 0.59014
#
# Epoch 00050: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 51/200
# 25569/25569 [==============================] - 42s 2ms/step - loss: 0.5831 - acc: 0.9244 - f1: 0.4169 - val_loss: 0.5960 - val_acc: 0.9174 - val_f1: 0.4040
#
# Epoch 00051: val_loss did not improve from 0.59014
#
# Epoch 00051: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 52/200
# 25569/25569 [==============================] - 43s 2ms/step - loss: 0.5709 - acc: 0.9270 - f1: 0.4291 - val_loss: 0.5869 - val_acc: 0.9168 - val_f1: 0.4131
#
# Epoch 00052: val_loss improved from 0.59014 to 0.58687, saving model to ../model_wehigts/6_w.hdf5
#
# Epoch 00052: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 53/200
# 25569/25569 [==============================] - 41s 2ms/step - loss: 0.5722 - acc: 0.9271 - f1: 0.4278 - val_loss: 0.5908 - val_acc: 0.9157 - val_f1: 0.4092
#
# Epoch 00053: val_loss did not improve from 0.58687
#
# Epoch 00053: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 54/200
# 25569/25569 [==============================] - 43s 2ms/step - loss: 0.5777 - acc: 0.9291 - f1: 0.4223 - val_loss: 0.5868 - val_acc: 0.9143 - val_f1: 0.4132
#
# Epoch 00054: val_loss improved from 0.58687 to 0.58682, saving model to ../model_wehigts/6_w.hdf5
#
# Epoch 00054: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 55/200
# 25569/25569 [==============================] - 43s 2ms/step - loss: 0.5814 - acc: 0.9242 - f1: 0.4186 - val_loss: 0.5889 - val_acc: 0.9162 - val_f1: 0.4111
#
# Epoch 00055: val_loss did not improve from 0.58682
#
# Epoch 00055: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 56/200
# 25569/25569 [==============================] - 53s 2ms/step - loss: 0.5806 - acc: 0.9296 - f1: 0.4194 - val_loss: 0.5919 - val_acc: 0.9193 - val_f1: 0.4081
#
# Epoch 00056: val_loss did not improve from 0.58682
#
# Epoch 00056: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 57/200
# 25569/25569 [==============================] - 45s 2ms/step - loss: 0.5787 - acc: 0.9302 - f1: 0.4213 - val_loss: 0.5951 - val_acc: 0.9148 - val_f1: 0.4049
#
# Epoch 00057: val_loss did not improve from 0.58682
#
# Epoch 00057: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 58/200
# 25569/25569 [==============================] - 39s 2ms/step - loss: 0.5833 - acc: 0.9296 - f1: 0.4167 - val_loss: 0.5909 - val_acc: 0.9223 - val_f1: 0.4091
#
# Epoch 00058: val_loss did not improve from 0.58682
#
# Epoch 00058: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 59/200
# 25569/25569 [==============================] - 41s 2ms/step - loss: 0.5663 - acc: 0.9301 - f1: 0.4337 - val_loss: 0.5802 - val_acc: 0.9165 - val_f1: 0.4198
#
# Epoch 00059: val_loss improved from 0.58682 to 0.58018, saving model to ../model_wehigts/6_w.hdf5
#
# Epoch 00059: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 60/200
# 25569/25569 [==============================] - 46s 2ms/step - loss: 0.5664 - acc: 0.9313 - f1: 0.4336 - val_loss: 0.5887 - val_acc: 0.9234 - val_f1: 0.4113
#
# Epoch 00060: val_loss did not improve from 0.58018
#
# Epoch 00060: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 61/200
# 25569/25569 [==============================] - 42s 2ms/step - loss: 0.5680 - acc: 0.9301 - f1: 0.4320 - val_loss: 0.5817 - val_acc: 0.9177 - val_f1: 0.4183
#
# Epoch 00061: val_loss did not improve from 0.58018
#
# Epoch 00061: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 62/200
# 25569/25569 [==============================] - 41s 2ms/step - loss: 0.5737 - acc: 0.9280 - f1: 0.4263 - val_loss: 0.5894 - val_acc: 0.9232 - val_f1: 0.4106
#
# Epoch 00062: val_loss did not improve from 0.58018
#
# Epoch 00062: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 63/200
# 25569/25569 [==============================] - 43s 2ms/step - loss: 0.5766 - acc: 0.9280 - f1: 0.4234 - val_loss: 0.5803 - val_acc: 0.9219 - val_f1: 0.4197
#
# Epoch 00063: val_loss did not improve from 0.58018
#
# Epoch 00063: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 64/200
# 25569/25569 [==============================] - 44s 2ms/step - loss: 0.5787 - acc: 0.9326 - f1: 0.4213 - val_loss: 0.5842 - val_acc: 0.9210 - val_f1: 0.4158
#
# Epoch 00064: val_loss did not improve from 0.58018
#
# Epoch 00064: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 65/200
# 25569/25569 [==============================] - 46s 2ms/step - loss: 0.5826 - acc: 0.9298 - f1: 0.4174 - val_loss: 0.5880 - val_acc: 0.9213 - val_f1: 0.4120
#
# Epoch 00065: val_loss did not improve from 0.58018
#
# Epoch 00065: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 66/200
# 25569/25569 [==============================] - 45s 2ms/step - loss: 0.5736 - acc: 0.9307 - f1: 0.4264 - val_loss: 0.5791 - val_acc: 0.9177 - val_f1: 0.4209
#
# Epoch 00066: val_loss improved from 0.58018 to 0.57914, saving model to ../model_wehigts/6_w.hdf5
#
# Epoch 00066: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 67/200
# 25569/25569 [==============================] - 40s 2ms/step - loss: 0.5767 - acc: 0.9318 - f1: 0.4233 - val_loss: 0.5829 - val_acc: 0.9224 - val_f1: 0.4171
#
# Epoch 00067: val_loss did not improve from 0.57914
#
# Epoch 00067: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 68/200
# 25569/25569 [==============================] - 43s 2ms/step - loss: 0.5854 - acc: 0.9288 - f1: 0.4146 - val_loss: 0.5796 - val_acc: 0.9162 - val_f1: 0.4204
#
# Epoch 00068: val_loss did not improve from 0.57914
#
# Epoch 00068: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 69/200
# 25569/25569 [==============================] - 41s 2ms/step - loss: 0.5735 - acc: 0.9318 - f1: 0.4265 - val_loss: 0.5828 - val_acc: 0.9194 - val_f1: 0.4172
#
# Epoch 00069: val_loss did not improve from 0.57914
#
# Epoch 00069: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 70/200
# 25569/25569 [==============================] - 45s 2ms/step - loss: 0.5451 - acc: 0.9326 - f1: 0.4549 - val_loss: 0.5818 - val_acc: 0.9226 - val_f1: 0.4182
#
# Epoch 00070: val_loss did not improve from 0.57914
#
# Epoch 00070: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 71/200
# 25569/25569 [==============================] - 49s 2ms/step - loss: 0.5808 - acc: 0.9332 - f1: 0.4192 - val_loss: 0.5857 - val_acc: 0.9226 - val_f1: 0.4143
#
# Epoch 00071: val_loss did not improve from 0.57914
#
# Epoch 00071: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 72/200
# 25569/25569 [==============================] - 48s 2ms/step - loss: 0.5644 - acc: 0.9322 - f1: 0.4356 - val_loss: 0.5786 - val_acc: 0.9187 - val_f1: 0.4214
#
# Epoch 00072: val_loss improved from 0.57914 to 0.57862, saving model to ../model_wehigts/6_w.hdf5
#
# Epoch 00072: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 73/200
# 25569/25569 [==============================] - 44s 2ms/step - loss: 0.5563 - acc: 0.9322 - f1: 0.4437 - val_loss: 0.5796 - val_acc: 0.9185 - val_f1: 0.4204
#
# Epoch 00073: val_loss did not improve from 0.57862
#
# Epoch 00073: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 74/200
# 25569/25569 [==============================] - 40s 2ms/step - loss: 0.5609 - acc: 0.9335 - f1: 0.4391 - val_loss: 0.5814 - val_acc: 0.9165 - val_f1: 0.4186
#
# Epoch 00074: val_loss did not improve from 0.57862
#
# Epoch 00074: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 75/200
# 25569/25569 [==============================] - 48s 2ms/step - loss: 0.5619 - acc: 0.9280 - f1: 0.4381 - val_loss: 0.5819 - val_acc: 0.9162 - val_f1: 0.4181
#
# Epoch 00075: val_loss did not improve from 0.57862
#
# Epoch 00075: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 76/200
# 25569/25569 [==============================] - 46s 2ms/step - loss: 0.5648 - acc: 0.9270 - f1: 0.4352 - val_loss: 0.5836 - val_acc: 0.9190 - val_f1: 0.4164
#
# Epoch 00076: val_loss did not improve from 0.57862
#
# Epoch 00076: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 77/200
# 25569/25569 [==============================] - 43s 2ms/step - loss: 0.5626 - acc: 0.9321 - f1: 0.4374 - val_loss: 0.5826 - val_acc: 0.9132 - val_f1: 0.4174
#
# Epoch 00077: val_loss did not improve from 0.57862
#
# Epoch 00077: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 78/200
# 25569/25569 [==============================] - 40s 2ms/step - loss: 0.5586 - acc: 0.9316 - f1: 0.4414 - val_loss: 0.5801 - val_acc: 0.9210 - val_f1: 0.4199
#
# Epoch 00078: val_loss did not improve from 0.57862
#
# Epoch 00078: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 79/200
# 25569/25569 [==============================] - 45s 2ms/step - loss: 0.5752 - acc: 0.9342 - f1: 0.4248 - val_loss: 0.5759 - val_acc: 0.9216 - val_f1: 0.4241
#
# Epoch 00079: val_loss improved from 0.57862 to 0.57587, saving model to ../model_wehigts/6_w.hdf5
#
# Epoch 00079: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 80/200
# 25569/25569 [==============================] - 50s 2ms/step - loss: 0.5710 - acc: 0.9323 - f1: 0.4290 - val_loss: 0.5737 - val_acc: 0.9188 - val_f1: 0.4263
#
# Epoch 00080: val_loss improved from 0.57587 to 0.57371, saving model to ../model_wehigts/6_w.hdf5
#
# Epoch 00080: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 81/200
# 25569/25569 [==============================] - 50s 2ms/step - loss: 0.5620 - acc: 0.9321 - f1: 0.4380 - val_loss: 0.5799 - val_acc: 0.9216 - val_f1: 0.4201
#
# Epoch 00081: val_loss did not improve from 0.57371
#
# Epoch 00081: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 82/200
# 25569/25569 [==============================] - 48s 2ms/step - loss: 0.5551 - acc: 0.9330 - f1: 0.4449 - val_loss: 0.5794 - val_acc: 0.9157 - val_f1: 0.4206
#
# Epoch 00082: val_loss did not improve from 0.57371
#
# Epoch 00082: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 83/200
# 25569/25569 [==============================] - 43s 2ms/step - loss: 0.5650 - acc: 0.9291 - f1: 0.4350 - val_loss: 0.5782 - val_acc: 0.9088 - val_f1: 0.4218
#
# Epoch 00083: val_loss did not improve from 0.57371
#
# Epoch 00083: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 84/200
# 25569/25569 [==============================] - 44s 2ms/step - loss: 0.5504 - acc: 0.9310 - f1: 0.4496 - val_loss: 0.5826 - val_acc: 0.9230 - val_f1: 0.4174
#
# Epoch 00084: val_loss did not improve from 0.57371
#
# Epoch 00084: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 85/200
# 25569/25569 [==============================] - 43s 2ms/step - loss: 0.5695 - acc: 0.9302 - f1: 0.4305 - val_loss: 0.5892 - val_acc: 0.9243 - val_f1: 0.4108
#
# Epoch 00085: val_loss did not improve from 0.57371
#
# Epoch 00085: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 86/200
# 25569/25569 [==============================] - 46s 2ms/step - loss: 0.5597 - acc: 0.9339 - f1: 0.4403 - val_loss: 0.5846 - val_acc: 0.9202 - val_f1: 0.4154
#
# Epoch 00086: val_loss did not improve from 0.57371
#
# Epoch 00086: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 87/200
# 25569/25569 [==============================] - 44s 2ms/step - loss: 0.5514 - acc: 0.9356 - f1: 0.4486 - val_loss: 0.5798 - val_acc: 0.9198 - val_f1: 0.4202
#
# Epoch 00087: val_loss did not improve from 0.57371
#
# Epoch 00087: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 88/200
# 25569/25569 [==============================] - 44s 2ms/step - loss: 0.5684 - acc: 0.9342 - f1: 0.4316 - val_loss: 0.5852 - val_acc: 0.9226 - val_f1: 0.4148
#
# Epoch 00088: val_loss did not improve from 0.57371
#
# Epoch 00088: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 89/200
# 25569/25569 [==============================] - 44s 2ms/step - loss: 0.5548 - acc: 0.9351 - f1: 0.4452 - val_loss: 0.5781 - val_acc: 0.9215 - val_f1: 0.4219
#
# Epoch 00089: val_loss did not improve from 0.57371
#
# Epoch 00089: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 90/200
# 25569/25569 [==============================] - 39s 2ms/step - loss: 0.5561 - acc: 0.9342 - f1: 0.4439 - val_loss: 0.5781 - val_acc: 0.9226 - val_f1: 0.4219
#
# Epoch 00090: val_loss did not improve from 0.57371
#
# Epoch 00090: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 91/200
# 25569/25569 [==============================] - 43s 2ms/step - loss: 0.5523 - acc: 0.9366 - f1: 0.4477 - val_loss: 0.5768 - val_acc: 0.9190 - val_f1: 0.4232
#
# Epoch 00091: val_loss did not improve from 0.57371
#
# Epoch 00091: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 92/200
# 25569/25569 [==============================] - 46s 2ms/step - loss: 0.5497 - acc: 0.9330 - f1: 0.4503 - val_loss: 0.5705 - val_acc: 0.9135 - val_f1: 0.4295
#
# Epoch 00092: val_loss improved from 0.57371 to 0.57053, saving model to ../model_wehigts/6_w.hdf5
#
# Epoch 00092: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 93/200
# 25569/25569 [==============================] - 42s 2ms/step - loss: 0.5331 - acc: 0.9345 - f1: 0.4669 - val_loss: 0.5801 - val_acc: 0.9224 - val_f1: 0.4199
#
# Epoch 00093: val_loss did not improve from 0.57053
#
# Epoch 00093: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 94/200
# 25569/25569 [==============================] - 51s 2ms/step - loss: 0.5601 - acc: 0.9348 - f1: 0.4399 - val_loss: 0.5750 - val_acc: 0.9169 - val_f1: 0.4250
#
# Epoch 00094: val_loss did not improve from 0.57053
#
# Epoch 00094: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 95/200
# 25569/25569 [==============================] - 57s 2ms/step - loss: 0.5444 - acc: 0.9310 - f1: 0.4556 - val_loss: 0.5800 - val_acc: 0.9174 - val_f1: 0.4200
#
# Epoch 00095: val_loss did not improve from 0.57053
#
# Epoch 00095: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 96/200
# 25569/25569 [==============================] - 48s 2ms/step - loss: 0.5593 - acc: 0.9320 - f1: 0.4407 - val_loss: 0.5796 - val_acc: 0.9230 - val_f1: 0.4204
#
# Epoch 00096: val_loss did not improve from 0.57053
#
# Epoch 00096: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 97/200
# 25569/25569 [==============================] - 60s 2ms/step - loss: 0.5432 - acc: 0.9350 - f1: 0.4568 - val_loss: 0.5815 - val_acc: 0.9165 - val_f1: 0.4185
#
# Epoch 00097: val_loss did not improve from 0.57053
#
# Epoch 00097: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 98/200
# 25569/25569 [==============================] - 70s 3ms/step - loss: 0.5469 - acc: 0.9343 - f1: 0.4531 - val_loss: 0.5787 - val_acc: 0.9193 - val_f1: 0.4213
#
# Epoch 00098: val_loss did not improve from 0.57053
#
# Epoch 00098: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 99/200
# 25569/25569 [==============================] - 46s 2ms/step - loss: 0.5586 - acc: 0.9343 - f1: 0.4414 - val_loss: 0.5835 - val_acc: 0.9221 - val_f1: 0.4165
#
# Epoch 00099: val_loss did not improve from 0.57053
#
# Epoch 00099: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 100/200
# 25569/25569 [==============================] - 43s 2ms/step - loss: 0.5443 - acc: 0.9355 - f1: 0.4557 - val_loss: 0.5842 - val_acc: 0.9209 - val_f1: 0.4158
#
# Epoch 00100: val_loss did not improve from 0.57053
#
# Epoch 00100: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 101/200
# 25569/25569 [==============================] - 41s 2ms/step - loss: 0.5368 - acc: 0.9409 - f1: 0.4632 - val_loss: 0.5836 - val_acc: 0.9252 - val_f1: 0.4164
#
# Epoch 00101: val_loss did not improve from 0.57053
#
# Epoch 00101: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 102/200
# 25569/25569 [==============================] - 44s 2ms/step - loss: 0.5481 - acc: 0.9385 - f1: 0.4519 - val_loss: 0.5826 - val_acc: 0.9237 - val_f1: 0.4174
#
# Epoch 00102: val_loss did not improve from 0.57053
#
# Epoch 00102: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 103/200
# 25569/25569 [==============================] - 43s 2ms/step - loss: 0.5585 - acc: 0.9348 - f1: 0.4415 - val_loss: 0.5831 - val_acc: 0.9198 - val_f1: 0.4169
#
# Epoch 00103: val_loss did not improve from 0.57053
#
# Epoch 00103: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 104/200
# 25569/25569 [==============================] - 47s 2ms/step - loss: 0.5488 - acc: 0.9351 - f1: 0.4512 - val_loss: 0.5836 - val_acc: 0.9196 - val_f1: 0.4164
#
# Epoch 00104: val_loss did not improve from 0.57053
#
# Epoch 00104: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 105/200
# 25569/25569 [==============================] - 49s 2ms/step - loss: 0.5513 - acc: 0.9350 - f1: 0.4487 - val_loss: 0.5835 - val_acc: 0.9182 - val_f1: 0.4165
#
# Epoch 00105: val_loss did not improve from 0.57053
#
# Epoch 00105: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 106/200
# 25569/25569 [==============================] - 43s 2ms/step - loss: 0.5573 - acc: 0.9339 - f1: 0.4427 - val_loss: 0.5820 - val_acc: 0.9171 - val_f1: 0.4180
#
# Epoch 00106: val_loss did not improve from 0.57053
#
# Epoch 00106: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 107/200
# 25569/25569 [==============================] - 37s 1ms/step - loss: 0.5446 - acc: 0.9349 - f1: 0.4554 - val_loss: 0.5817 - val_acc: 0.9191 - val_f1: 0.4183
#
# Epoch 00107: val_loss did not improve from 0.57053
#
# Epoch 00107: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 108/200
# 25569/25569 [==============================] - 37s 1ms/step - loss: 0.5476 - acc: 0.9355 - f1: 0.4524 - val_loss: 0.5831 - val_acc: 0.9190 - val_f1: 0.4169
#
# Epoch 00108: val_loss did not improve from 0.57053
#
# Epoch 00108: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 109/200
# 25569/25569 [==============================] - 37s 1ms/step - loss: 0.5464 - acc: 0.9359 - f1: 0.4536 - val_loss: 0.5828 - val_acc: 0.9180 - val_f1: 0.4172
#
# Epoch 00109: val_loss did not improve from 0.57053
#
# Epoch 00109: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 110/200
# 25569/25569 [==============================] - 37s 1ms/step - loss: 0.5432 - acc: 0.9348 - f1: 0.4568 - val_loss: 0.5831 - val_acc: 0.9194 - val_f1: 0.4169
#
# Epoch 00110: val_loss did not improve from 0.57053
#
# Epoch 00110: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 111/200
# 25569/25569 [==============================] - 37s 1ms/step - loss: 0.5486 - acc: 0.9359 - f1: 0.4514 - val_loss: 0.5832 - val_acc: 0.9188 - val_f1: 0.4168
#
# Epoch 00111: val_loss did not improve from 0.57053
#
# Epoch 00111: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 112/200
# 25569/25569 [==============================] - 37s 1ms/step - loss: 0.5353 - acc: 0.9358 - f1: 0.4647 - val_loss: 0.5826 - val_acc: 0.9180 - val_f1: 0.4174
#
# Epoch 00112: val_loss did not improve from 0.57053
#
# Epoch 00112: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 113/200
# 25569/25569 [==============================] - 40s 2ms/step - loss: 0.5392 - acc: 0.9358 - f1: 0.4608 - val_loss: 0.5823 - val_acc: 0.9193 - val_f1: 0.4177
#
# Epoch 00113: val_loss did not improve from 0.57053
#
# Epoch 00113: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 114/200
# 25569/25569 [==============================] - 41s 2ms/step - loss: 0.5462 - acc: 0.9360 - f1: 0.4538 - val_loss: 0.5843 - val_acc: 0.9194 - val_f1: 0.4157
#
# Epoch 00114: val_loss did not improve from 0.57053
#
# Epoch 00114: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 115/200
# 25569/25569 [==============================] - 50s 2ms/step - loss: 0.5327 - acc: 0.9365 - f1: 0.4673 - val_loss: 0.5849 - val_acc: 0.9199 - val_f1: 0.4151
#
# Epoch 00115: val_loss did not improve from 0.57053
#
# Epoch 00115: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 116/200
# 25569/25569 [==============================] - 44s 2ms/step - loss: 0.5578 - acc: 0.9353 - f1: 0.4422 - val_loss: 0.5828 - val_acc: 0.9193 - val_f1: 0.4172
#
# Epoch 00116: val_loss did not improve from 0.57053
#
# Epoch 00116: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 117/200
# 25569/25569 [==============================] - 48s 2ms/step - loss: 0.5431 - acc: 0.9361 - f1: 0.4569 - val_loss: 0.5833 - val_acc: 0.9183 - val_f1: 0.4167
#
# Epoch 00117: val_loss did not improve from 0.57053
#
# Epoch 00117: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 118/200
# 25569/25569 [==============================] - 41s 2ms/step - loss: 0.5500 - acc: 0.9353 - f1: 0.4500 - val_loss: 0.5835 - val_acc: 0.9187 - val_f1: 0.4165
#
# Epoch 00118: val_loss did not improve from 0.57053
#
# Epoch 00118: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 119/200
# 25569/25569 [==============================] - 47s 2ms/step - loss: 0.5290 - acc: 0.9372 - f1: 0.4710 - val_loss: 0.5816 - val_acc: 0.9179 - val_f1: 0.4184
#
# Epoch 00119: val_loss did not improve from 0.57053
#
# Epoch 00119: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 120/200
# 25569/25569 [==============================] - 41s 2ms/step - loss: 0.5409 - acc: 0.9375 - f1: 0.4591 - val_loss: 0.5793 - val_acc: 0.9182 - val_f1: 0.4207
#
# Epoch 00120: val_loss did not improve from 0.57053
#
# Epoch 00120: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 121/200
# 25569/25569 [==============================] - 45s 2ms/step - loss: 0.5380 - acc: 0.9371 - f1: 0.4620 - val_loss: 0.5825 - val_acc: 0.9188 - val_f1: 0.4175
#
# Epoch 00121: val_loss did not improve from 0.57053
#
# Epoch 00121: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 122/200
# 25569/25569 [==============================] - 50s 2ms/step - loss: 0.5414 - acc: 0.9337 - f1: 0.4586 - val_loss: 0.5797 - val_acc: 0.9183 - val_f1: 0.4203
#
# Epoch 00122: val_loss did not improve from 0.57053
#
# Epoch 00122: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 123/200
# 25569/25569 [==============================] - 41s 2ms/step - loss: 0.5322 - acc: 0.9358 - f1: 0.4678 - val_loss: 0.5817 - val_acc: 0.9190 - val_f1: 0.4183
#
# Epoch 00123: val_loss did not improve from 0.57053
#
# Epoch 00123: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 124/200
# 25569/25569 [==============================] - 45s 2ms/step - loss: 0.5347 - acc: 0.9376 - f1: 0.4653 - val_loss: 0.5812 - val_acc: 0.9190 - val_f1: 0.4188
#
# Epoch 00124: val_loss did not improve from 0.57053
#
# Epoch 00124: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 125/200
# 25569/25569 [==============================] - 45s 2ms/step - loss: 0.5406 - acc: 0.9366 - f1: 0.4594 - val_loss: 0.5791 - val_acc: 0.9173 - val_f1: 0.4209
#
# Epoch 00125: val_loss did not improve from 0.57053
#
# Epoch 00125: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 126/200
# 25569/25569 [==============================] - 42s 2ms/step - loss: 0.5315 - acc: 0.9362 - f1: 0.4685 - val_loss: 0.5800 - val_acc: 0.9179 - val_f1: 0.4200
#
# Epoch 00126: val_loss did not improve from 0.57053
#
# Epoch 00126: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 127/200
# 25569/25569 [==============================] - 48s 2ms/step - loss: 0.5485 - acc: 0.9364 - f1: 0.4515 - val_loss: 0.5806 - val_acc: 0.9187 - val_f1: 0.4194
#
# Epoch 00127: val_loss did not improve from 0.57053
#
# Epoch 00127: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 128/200
# 25569/25569 [==============================] - 40s 2ms/step - loss: 0.5421 - acc: 0.9372 - f1: 0.4579 - val_loss: 0.5806 - val_acc: 0.9191 - val_f1: 0.4194
#
# Epoch 00128: val_loss did not improve from 0.57053
#
# Epoch 00128: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 129/200
# 25569/25569 [==============================] - 42s 2ms/step - loss: 0.5444 - acc: 0.9371 - f1: 0.4556 - val_loss: 0.5792 - val_acc: 0.9179 - val_f1: 0.4208
#
# Epoch 00129: val_loss did not improve from 0.57053
#
# Epoch 00129: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 130/200
# 25569/25569 [==============================] - 45s 2ms/step - loss: 0.5365 - acc: 0.9366 - f1: 0.4635 - val_loss: 0.5803 - val_acc: 0.9177 - val_f1: 0.4197
#
# Epoch 00130: val_loss did not improve from 0.57053
#
# Epoch 00130: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 131/200
# 25569/25569 [==============================] - 44s 2ms/step - loss: 0.5382 - acc: 0.9371 - f1: 0.4618 - val_loss: 0.5812 - val_acc: 0.9191 - val_f1: 0.4188
#
# Epoch 00131: val_loss did not improve from 0.57053
#
# Epoch 00131: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 132/200
# 25569/25569 [==============================] - 46s 2ms/step - loss: 0.5408 - acc: 0.9382 - f1: 0.4592 - val_loss: 0.5802 - val_acc: 0.9207 - val_f1: 0.4198
#
# Epoch 00132: val_loss did not improve from 0.57053
#
# Epoch 00132: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 133/200
# 25569/25569 [==============================] - 43s 2ms/step - loss: 0.5318 - acc: 0.9384 - f1: 0.4682 - val_loss: 0.5797 - val_acc: 0.9212 - val_f1: 0.4203
#
# Epoch 00133: val_loss did not improve from 0.57053
#
# Epoch 00133: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 134/200
# 25569/25569 [==============================] - 41s 2ms/step - loss: 0.5363 - acc: 0.9375 - f1: 0.4637 - val_loss: 0.5818 - val_acc: 0.9193 - val_f1: 0.4182
#
# Epoch 00134: val_loss did not improve from 0.57053
#
# Epoch 00134: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 135/200
# 25569/25569 [==============================] - 43s 2ms/step - loss: 0.5351 - acc: 0.9370 - f1: 0.4649 - val_loss: 0.5815 - val_acc: 0.9190 - val_f1: 0.4185
#
# Epoch 00135: val_loss did not improve from 0.57053
#
# Epoch 00135: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 136/200
# 25569/25569 [==============================] - 40s 2ms/step - loss: 0.5327 - acc: 0.9376 - f1: 0.4673 - val_loss: 0.5802 - val_acc: 0.9183 - val_f1: 0.4198
#
# Epoch 00136: val_loss did not improve from 0.57053
#
# Epoch 00136: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 137/200
# 25569/25569 [==============================] - 38s 1ms/step - loss: 0.5313 - acc: 0.9383 - f1: 0.4687 - val_loss: 0.5817 - val_acc: 0.9198 - val_f1: 0.4183
#
# Epoch 00137: val_loss did not improve from 0.57053
#
# Epoch 00137: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 138/200
# 25569/25569 [==============================] - 37s 1ms/step - loss: 0.5258 - acc: 0.9376 - f1: 0.4742 - val_loss: 0.5820 - val_acc: 0.9190 - val_f1: 0.4180
#
# Epoch 00138: val_loss did not improve from 0.57053
#
# Epoch 00138: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 139/200
# 25569/25569 [==============================] - 37s 1ms/step - loss: 0.5488 - acc: 0.9375 - f1: 0.4512 - val_loss: 0.5828 - val_acc: 0.9171 - val_f1: 0.4172
#
# Epoch 00139: val_loss did not improve from 0.57053
#
# Epoch 00139: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 140/200
# 25569/25569 [==============================] - 44s 2ms/step - loss: 0.5310 - acc: 0.9375 - f1: 0.4690 - val_loss: 0.5834 - val_acc: 0.9174 - val_f1: 0.4166
#
# Epoch 00140: val_loss did not improve from 0.57053
#
# Epoch 00140: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 141/200
# 25569/25569 [==============================] - 46s 2ms/step - loss: 0.5316 - acc: 0.9380 - f1: 0.4684 - val_loss: 0.5825 - val_acc: 0.9173 - val_f1: 0.4175
#
# Epoch 00141: val_loss did not improve from 0.57053
#
# Epoch 00141: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 142/200
# 25569/25569 [==============================] - 37s 1ms/step - loss: 0.5311 - acc: 0.9359 - f1: 0.4689 - val_loss: 0.5817 - val_acc: 0.9173 - val_f1: 0.4183
#
# Epoch 00142: val_loss did not improve from 0.57053
#
# Epoch 00142: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 143/200
# 25569/25569 [==============================] - 36s 1ms/step - loss: 0.5390 - acc: 0.9356 - f1: 0.4610 - val_loss: 0.5812 - val_acc: 0.9169 - val_f1: 0.4188
#
# Epoch 00143: val_loss did not improve from 0.57053
#
# Epoch 00143: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 144/200
# 25569/25569 [==============================] - 36s 1ms/step - loss: 0.5433 - acc: 0.9339 - f1: 0.4567 - val_loss: 0.5796 - val_acc: 0.9168 - val_f1: 0.4204
#
# Epoch 00144: val_loss did not improve from 0.57053
#
# Epoch 00144: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 145/200
# 25569/25569 [==============================] - 36s 1ms/step - loss: 0.5482 - acc: 0.9350 - f1: 0.4518 - val_loss: 0.5798 - val_acc: 0.9165 - val_f1: 0.4202
#
# Epoch 00145: val_loss did not improve from 0.57053
#
# Epoch 00145: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 146/200
# 25569/25569 [==============================] - 36s 1ms/step - loss: 0.5315 - acc: 0.9367 - f1: 0.4685 - val_loss: 0.5781 - val_acc: 0.9162 - val_f1: 0.4219
#
# Epoch 00146: val_loss did not improve from 0.57053
#
# Epoch 00146: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 147/200
# 25569/25569 [==============================] - 37s 1ms/step - loss: 0.5426 - acc: 0.9343 - f1: 0.4574 - val_loss: 0.5793 - val_acc: 0.9168 - val_f1: 0.4207
#
# Epoch 00147: val_loss did not improve from 0.57053
#
# Epoch 00147: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 148/200
# 25569/25569 [==============================] - 36s 1ms/step - loss: 0.5404 - acc: 0.9360 - f1: 0.4596 - val_loss: 0.5804 - val_acc: 0.9165 - val_f1: 0.4196
#
# Epoch 00148: val_loss did not improve from 0.57053
#
# Epoch 00148: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 149/200
# 25569/25569 [==============================] - 37s 1ms/step - loss: 0.5441 - acc: 0.9355 - f1: 0.4559 - val_loss: 0.5815 - val_acc: 0.9174 - val_f1: 0.4185
#
# Epoch 00149: val_loss did not improve from 0.57053
#
# Epoch 00149: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 150/200
# 25569/25569 [==============================] - 36s 1ms/step - loss: 0.5433 - acc: 0.9380 - f1: 0.4567 - val_loss: 0.5800 - val_acc: 0.9177 - val_f1: 0.4200
#
# Epoch 00150: val_loss did not improve from 0.57053
#
# Epoch 00150: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 151/200
# 25569/25569 [==============================] - 36s 1ms/step - loss: 0.5310 - acc: 0.9371 - f1: 0.4690 - val_loss: 0.5790 - val_acc: 0.9180 - val_f1: 0.4210
#
# Epoch 00151: val_loss did not improve from 0.57053
#
# Epoch 00151: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 152/200
# 25569/25569 [==============================] - 37s 1ms/step - loss: 0.5450 - acc: 0.9381 - f1: 0.4550 - val_loss: 0.5792 - val_acc: 0.9177 - val_f1: 0.4208
#
# Epoch 00152: val_loss did not improve from 0.57053
#
# Epoch 00152: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 153/200
# 25569/25569 [==============================] - 36s 1ms/step - loss: 0.5327 - acc: 0.9379 - f1: 0.4673 - val_loss: 0.5789 - val_acc: 0.9177 - val_f1: 0.4211
#
# Epoch 00153: val_loss did not improve from 0.57053
#
# Epoch 00153: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 154/200
# 25569/25569 [==============================] - 36s 1ms/step - loss: 0.5255 - acc: 0.9384 - f1: 0.4745 - val_loss: 0.5791 - val_acc: 0.9177 - val_f1: 0.4209
#
# Epoch 00154: val_loss did not improve from 0.57053
#
# Epoch 00154: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 155/200
# 25569/25569 [==============================] - 37s 1ms/step - loss: 0.5329 - acc: 0.9383 - f1: 0.4671 - val_loss: 0.5793 - val_acc: 0.9177 - val_f1: 0.4207
#
# Epoch 00155: val_loss did not improve from 0.57053
#
# Epoch 00155: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 156/200
# 25569/25569 [==============================] - 36s 1ms/step - loss: 0.5319 - acc: 0.9382 - f1: 0.4681 - val_loss: 0.5795 - val_acc: 0.9176 - val_f1: 0.4205
#
# Epoch 00156: val_loss did not improve from 0.57053
#
# Epoch 00156: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 157/200
# 25569/25569 [==============================] - 36s 1ms/step - loss: 0.5178 - acc: 0.9389 - f1: 0.4822 - val_loss: 0.5796 - val_acc: 0.9176 - val_f1: 0.4204
#
# Epoch 00157: val_loss did not improve from 0.57053
#
# Epoch 00157: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 158/200
# 25569/25569 [==============================] - 37s 1ms/step - loss: 0.5309 - acc: 0.9384 - f1: 0.4691 - val_loss: 0.5793 - val_acc: 0.9176 - val_f1: 0.4207
#
# Epoch 00158: val_loss did not improve from 0.57053
#
# Epoch 00158: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 159/200
# 25569/25569 [==============================] - 36s 1ms/step - loss: 0.5261 - acc: 0.9373 - f1: 0.4739 - val_loss: 0.5796 - val_acc: 0.9179 - val_f1: 0.4204
#
# Epoch 00159: val_loss did not improve from 0.57053
#
# Epoch 00159: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 160/200
# 25569/25569 [==============================] - 36s 1ms/step - loss: 0.5482 - acc: 0.9364 - f1: 0.4518 - val_loss: 0.5798 - val_acc: 0.9176 - val_f1: 0.4202
#
# Epoch 00160: val_loss did not improve from 0.57053
#
# Epoch 00160: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 161/200
# 25569/25569 [==============================] - 36s 1ms/step - loss: 0.5425 - acc: 0.9373 - f1: 0.4575 - val_loss: 0.5801 - val_acc: 0.9180 - val_f1: 0.4199
#
# Epoch 00161: val_loss did not improve from 0.57053
#
# Epoch 00161: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 162/200
# 25569/25569 [==============================] - 37s 1ms/step - loss: 0.5254 - acc: 0.9386 - f1: 0.4746 - val_loss: 0.5802 - val_acc: 0.9180 - val_f1: 0.4198
#
# Epoch 00162: val_loss did not improve from 0.57053
#
# Epoch 00162: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 163/200
# 25569/25569 [==============================] - 37s 1ms/step - loss: 0.5288 - acc: 0.9383 - f1: 0.4712 - val_loss: 0.5803 - val_acc: 0.9177 - val_f1: 0.4197
#
# Epoch 00163: val_loss did not improve from 0.57053
#
# Epoch 00163: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 164/200
# 25569/25569 [==============================] - 36s 1ms/step - loss: 0.5373 - acc: 0.9378 - f1: 0.4627 - val_loss: 0.5806 - val_acc: 0.9179 - val_f1: 0.4194
#
# Epoch 00164: val_loss did not improve from 0.57053
#
# Epoch 00164: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 165/200
# 25569/25569 [==============================] - 37s 1ms/step - loss: 0.5404 - acc: 0.9383 - f1: 0.4596 - val_loss: 0.5803 - val_acc: 0.9177 - val_f1: 0.4197
#
# Epoch 00165: val_loss did not improve from 0.57053
#
# Epoch 00165: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 166/200
# 25569/25569 [==============================] - 36s 1ms/step - loss: 0.5302 - acc: 0.9374 - f1: 0.4698 - val_loss: 0.5803 - val_acc: 0.9177 - val_f1: 0.4197
#
# Epoch 00166: val_loss did not improve from 0.57053
#
# Epoch 00166: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 167/200
# 25569/25569 [==============================] - 36s 1ms/step - loss: 0.5270 - acc: 0.9393 - f1: 0.4730 - val_loss: 0.5801 - val_acc: 0.9177 - val_f1: 0.4199
#
# Epoch 00167: val_loss did not improve from 0.57053
#
# Epoch 00167: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 168/200
# 25569/25569 [==============================] - 37s 1ms/step - loss: 0.5453 - acc: 0.9388 - f1: 0.4547 - val_loss: 0.5800 - val_acc: 0.9180 - val_f1: 0.4200
#
# Epoch 00168: val_loss did not improve from 0.57053
#
# Epoch 00168: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 169/200
# 25569/25569 [==============================] - 37s 1ms/step - loss: 0.5376 - acc: 0.9374 - f1: 0.4624 - val_loss: 0.5801 - val_acc: 0.9180 - val_f1: 0.4199
#
# Epoch 00169: val_loss did not improve from 0.57053
#
# Epoch 00169: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 170/200
# 25569/25569 [==============================] - 36s 1ms/step - loss: 0.5328 - acc: 0.9380 - f1: 0.4672 - val_loss: 0.5799 - val_acc: 0.9180 - val_f1: 0.4201
#
# Epoch 00170: val_loss did not improve from 0.57053
#
# Epoch 00170: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 171/200
# 25569/25569 [==============================] - 37s 1ms/step - loss: 0.5412 - acc: 0.9389 - f1: 0.4588 - val_loss: 0.5799 - val_acc: 0.9180 - val_f1: 0.4201
#
# Epoch 00171: val_loss did not improve from 0.57053
#
# Epoch 00171: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 172/200
# 25569/25569 [==============================] - 36s 1ms/step - loss: 0.5408 - acc: 0.9378 - f1: 0.4592 - val_loss: 0.5800 - val_acc: 0.9180 - val_f1: 0.4200
#
# Epoch 00172: val_loss did not improve from 0.57053
#
# Epoch 00172: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 173/200
# 25569/25569 [==============================] - 37s 1ms/step - loss: 0.5442 - acc: 0.9380 - f1: 0.4558 - val_loss: 0.5801 - val_acc: 0.9180 - val_f1: 0.4199
#
# Epoch 00173: val_loss did not improve from 0.57053
#
# Epoch 00173: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 174/200
# 25569/25569 [==============================] - 38s 2ms/step - loss: 0.5306 - acc: 0.9379 - f1: 0.4694 - val_loss: 0.5802 - val_acc: 0.9180 - val_f1: 0.4198
#
# Epoch 00174: val_loss did not improve from 0.57053
#
# Epoch 00174: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 175/200
# 25569/25569 [==============================] - 37s 1ms/step - loss: 0.5342 - acc: 0.9386 - f1: 0.4658 - val_loss: 0.5799 - val_acc: 0.9179 - val_f1: 0.4201
#
# Epoch 00175: val_loss did not improve from 0.57053
#
# Epoch 00175: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 176/200
# 25569/25569 [==============================] - 36s 1ms/step - loss: 0.5370 - acc: 0.9388 - f1: 0.4630 - val_loss: 0.5796 - val_acc: 0.9179 - val_f1: 0.4204
#
# Epoch 00176: val_loss did not improve from 0.57053
#
# Epoch 00176: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 177/200
# 25569/25569 [==============================] - 36s 1ms/step - loss: 0.5327 - acc: 0.9372 - f1: 0.4673 - val_loss: 0.5794 - val_acc: 0.9179 - val_f1: 0.4206
#
# Epoch 00177: val_loss did not improve from 0.57053
#
# Epoch 00177: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 178/200
# 25569/25569 [==============================] - 36s 1ms/step - loss: 0.5354 - acc: 0.9358 - f1: 0.4646 - val_loss: 0.5795 - val_acc: 0.9179 - val_f1: 0.4205
#
# Epoch 00178: val_loss did not improve from 0.57053
#
# Epoch 00178: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 179/200
# 25569/25569 [==============================] - 36s 1ms/step - loss: 0.5262 - acc: 0.9380 - f1: 0.4738 - val_loss: 0.5794 - val_acc: 0.9179 - val_f1: 0.4206
#
# Epoch 00179: val_loss did not improve from 0.57053
#
# Epoch 00179: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 180/200
# 25569/25569 [==============================] - 36s 1ms/step - loss: 0.5383 - acc: 0.9388 - f1: 0.4617 - val_loss: 0.5789 - val_acc: 0.9180 - val_f1: 0.4211
#
# Epoch 00180: val_loss did not improve from 0.57053
#
# Epoch 00180: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 181/200
# 25569/25569 [==============================] - 36s 1ms/step - loss: 0.5243 - acc: 0.9384 - f1: 0.4757 - val_loss: 0.5787 - val_acc: 0.9182 - val_f1: 0.4213
#
# Epoch 00181: val_loss did not improve from 0.57053
#
# Epoch 00181: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 182/200
# 25569/25569 [==============================] - 37s 1ms/step - loss: 0.5453 - acc: 0.9372 - f1: 0.4547 - val_loss: 0.5789 - val_acc: 0.9180 - val_f1: 0.4211
#
# Epoch 00182: val_loss did not improve from 0.57053
#
# Epoch 00182: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 183/200
# 25569/25569 [==============================] - 36s 1ms/step - loss: 0.5449 - acc: 0.9376 - f1: 0.4551 - val_loss: 0.5788 - val_acc: 0.9182 - val_f1: 0.4212
#
# Epoch 00183: val_loss did not improve from 0.57053
#
# Epoch 00183: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 184/200
# 25569/25569 [==============================] - 36s 1ms/step - loss: 0.5429 - acc: 0.9387 - f1: 0.4571 - val_loss: 0.5788 - val_acc: 0.9182 - val_f1: 0.4212
#
# Epoch 00184: val_loss did not improve from 0.57053
#
# Epoch 00184: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 185/200
# 25569/25569 [==============================] - 36s 1ms/step - loss: 0.5311 - acc: 0.9376 - f1: 0.4689 - val_loss: 0.5782 - val_acc: 0.9183 - val_f1: 0.4218
#
# Epoch 00185: val_loss did not improve from 0.57053
#
# Epoch 00185: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 186/200
# 25569/25569 [==============================] - 36s 1ms/step - loss: 0.5386 - acc: 0.9378 - f1: 0.4614 - val_loss: 0.5784 - val_acc: 0.9182 - val_f1: 0.4216
#
# Epoch 00186: val_loss did not improve from 0.57053
#
# Epoch 00186: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 187/200
# 25569/25569 [==============================] - 36s 1ms/step - loss: 0.5321 - acc: 0.9375 - f1: 0.4679 - val_loss: 0.5785 - val_acc: 0.9182 - val_f1: 0.4215
#
# Epoch 00187: val_loss did not improve from 0.57053
#
# Epoch 00187: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 188/200
# 25569/25569 [==============================] - 36s 1ms/step - loss: 0.5461 - acc: 0.9375 - f1: 0.4539 - val_loss: 0.5785 - val_acc: 0.9182 - val_f1: 0.4215
#
# Epoch 00188: val_loss did not improve from 0.57053
#
# Epoch 00188: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 189/200
# 25569/25569 [==============================] - 36s 1ms/step - loss: 0.5239 - acc: 0.9377 - f1: 0.4761 - val_loss: 0.5786 - val_acc: 0.9182 - val_f1: 0.4214
#
# Epoch 00189: val_loss did not improve from 0.57053
#
# Epoch 00189: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 190/200
# 25569/25569 [==============================] - 36s 1ms/step - loss: 0.5425 - acc: 0.9387 - f1: 0.4575 - val_loss: 0.5787 - val_acc: 0.9182 - val_f1: 0.4213
#
# Epoch 00190: val_loss did not improve from 0.57053
#
# Epoch 00190: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 191/200
# 25569/25569 [==============================] - 36s 1ms/step - loss: 0.5287 - acc: 0.9366 - f1: 0.4713 - val_loss: 0.5789 - val_acc: 0.9182 - val_f1: 0.4211
#
# Epoch 00191: val_loss did not improve from 0.57053
#
# Epoch 00191: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 192/200
# 25569/25569 [==============================] - 36s 1ms/step - loss: 0.5387 - acc: 0.9377 - f1: 0.4613 - val_loss: 0.5789 - val_acc: 0.9182 - val_f1: 0.4211
#
# Epoch 00192: val_loss did not improve from 0.57053
#
# Epoch 00192: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 193/200
# 25569/25569 [==============================] - 36s 1ms/step - loss: 0.5348 - acc: 0.9377 - f1: 0.4652 - val_loss: 0.5785 - val_acc: 0.9182 - val_f1: 0.4215
#
# Epoch 00193: val_loss did not improve from 0.57053
#
# Epoch 00193: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 194/200
# 25569/25569 [==============================] - 36s 1ms/step - loss: 0.5355 - acc: 0.9384 - f1: 0.4645 - val_loss: 0.5781 - val_acc: 0.9180 - val_f1: 0.4219
#
# Epoch 00194: val_loss did not improve from 0.57053
#
# Epoch 00194: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 195/200
# 25569/25569 [==============================] - 36s 1ms/step - loss: 0.5294 - acc: 0.9372 - f1: 0.4706 - val_loss: 0.5780 - val_acc: 0.9180 - val_f1: 0.4220
#
# Epoch 00195: val_loss did not improve from 0.57053
#
# Epoch 00195: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 196/200
# 25569/25569 [==============================] - 36s 1ms/step - loss: 0.5325 - acc: 0.9377 - f1: 0.4675 - val_loss: 0.5778 - val_acc: 0.9180 - val_f1: 0.4222
#
# Epoch 00196: val_loss did not improve from 0.57053
#
# Epoch 00196: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 197/200
# 25569/25569 [==============================] - 36s 1ms/step - loss: 0.5338 - acc: 0.9377 - f1: 0.4662 - val_loss: 0.5780 - val_acc: 0.9180 - val_f1: 0.4220
#
# Epoch 00197: val_loss did not improve from 0.57053
#
# Epoch 00197: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 198/200
# 25569/25569 [==============================] - 36s 1ms/step - loss: 0.5483 - acc: 0.9373 - f1: 0.4517 - val_loss: 0.5778 - val_acc: 0.9180 - val_f1: 0.4222
#
# Epoch 00198: val_loss did not improve from 0.57053
#
# Epoch 00198: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 199/200
# 25569/25569 [==============================] - 36s 1ms/step - loss: 0.5399 - acc: 0.9372 - f1: 0.4601 - val_loss: 0.5778 - val_acc: 0.9180 - val_f1: 0.4222
#
# Epoch 00199: val_loss did not improve from 0.57053
#
# Epoch 00199: saving model to ../model_wehigts/6_ch.hdf5
# Epoch 200/200
# 25569/25569 [==============================] - 36s 1ms/step - loss: 0.5337 - acc: 0.9367 - f1: 0.4663 - val_loss: 0.5778 - val_acc: 0.9179 - val_f1: 0.4222
#
# Epoch 00200: val_loss did not improve from 0.57053
#
# Epoch 00200: saving model to ../model_wehigts/6_ch.hdf5

# %%
from sklearn.metrics import f1_score

#Load best model
model.load_weights(checkpoint_path)
y_pred = model.predict(x_val, batch_size=1)
y_pred = np.where(y_pred > 0.5, 1, 0)

print("Neural Network f1_sklearn: {}".format(f1_score(y_val, y_pred)))
# Out:
# Neural Network f1_sklearn: 0.4846225535880708
