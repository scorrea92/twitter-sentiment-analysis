# %%
import re
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt 
import seaborn as sns
import string
import nltk
import warnings 
import sys

sys.path.append("../") 
from personal_library.NPL.preprocess import (
    remove_pattern,
    rm_pun_num_esp_cha,
    rm_length_word,
    tokenize,
    stemmer,
    join_tokenize,
    hashtag_extract,
    count_caps,
    hashtag_rm
)

from personal_library.NPL.data_analysis import(
    plot_labels_wordcloud,
    plot_hashtag_hist,
)

warnings.filterwarnings("ignore", category=DeprecationWarning)

# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
from ast import literal_eval

df = pd.read_csv('../data/pandas_data_frame.csv', index_col=0)
all_data = df.where((pd.notnull(df)), '')
all_data['hashtag'] = all_data['hashtag'].apply(literal_eval)

# %%
plot_labels_wordcloud(all_data, 'tidy_tweet', 'label', add_all=True)
# Out:
# All data Wordcloud
# Label 0.0 Wordcloud
# Label 1.0 Wordcloud
# Label test Wordcloud

# %%
# extracting hashtags from non racist/sexist tweets
HT_regular = sum(all_data['hashtag'][all_data['label'] == 0], [])

# extracting hashtags from racist/sexist tweets
HT_negative = sum(all_data['hashtag'][all_data['label'] == 1], [])

print('hashtags from non racist/sexist tweets')
plot_hashtag_hist(HT_regular)

print('hashtags from racist/sexist tweets')
plot_hashtag_hist(HT_negative)
# Out:
# hashtags from non racist/sexist tweets
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-4-ae7ad9120683> in <module>()
#       6
#       7 print('hashtags from non racist/sexist tweets')
# ----> 8 plot_hashtag_hist(HT_regular)
#       9
#      10 print('hashtags from racist/sexist tweets')
#
# ~/Documents/PythonProjects/twitter-sentiment-analysis/personal_library/NPL/data_analysis.py in plot_hashtag_hist(hashtags)
#      73     hash_pd = hash_pd.nlargest(columns="Count", n=10)
#      74     plt.figure(figsize=(16, 5))
# ---> 75     ax = sns.barplot(data=hash_pd, x="Hashtag", y="Count")
#      76     ax.set(ylabel='Count')
#      77     plt.show()
#
# ...
